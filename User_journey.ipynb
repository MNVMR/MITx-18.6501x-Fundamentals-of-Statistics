# %% [markdown]
# # User Journey Analysis

# %% [markdown]
# ## Preprocessing the Data

# %% [markdown]
# In this project, we are provided with data containing the user journeys of people who bought our product. We need to create Python programs to analyze the sequence of visited pages with the objective of improving the front page flow and identifying which pages are important.
#
# But before analyzing this data, we must first clean it and prepare it for the next step.
#
# For this part of the process, we must create a Python program with three functions to help transform the data into a more analysis-ready state and then export this new data to a CSV.
#
# To begin, inspect the CSV itself and see if there is any need to clean the data. After inspection, we should notice that some user journey strings have multiple duplicate pages, one after another. While the Homepage reference in journeys like Homepage-Pricing-Homepage might be helpful for the analysis, the repeating reference in Homepage-Homepage-Homepage-Pricing is not.
#
# The first function we need to create removes sequences of repeating pages. It should leave just a single entity in the place of the sequence. But it should only apply where the duplicate page is replicated sequentially. So, it should do nothing in the first example (Homepage-Pricing-Homepage) while replacing the second (Homepage-Homepage-Homepage-Pricing) with Homepage-Pricing. This operation should be done for each row of data.

# %%
# Import pandas for data manipulation and analysis.
import pandas as pd

# %%
# Load the dataset
data = pd.read_csv('user_journey_raw.csv')

# Display the first few rows to understand the features and their data types
data_info = data.info()
data_head = data.head()

data_info, data_head
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9935 entries, 0 to 9934
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            9935 non-null   int64
#  1   session_id         9935 non-null   int64
#  2   subscription_type  9935 non-null   object
#  3   user_journey       9935 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 310.6+ KB
# (None,
#     user_id  session_id subscription_type  \
#  0     1516     2980231            Annual
#  1     1516     2980248            Annual
#  2     1516     2992252            Annual
#  3     1516     3070491            Annual
#  4     1516     3709807            Annual
#
#                                          user_journey
#  0  Homepage-Log in-Log in-Log in-Log in-Log in-Lo...
#  1  Other-Sign up-Sign up-Sign up-Sign up-Sign up-...
#  2          Log in-Log in-Log in-Log in-Log in-Log in
#  3  Homepage-Log in-Log in-Log in-Log in-Log in-Lo...
#  4  Log in-Log in-Log in-Log in-Log in-Log in-Log ...  )

# %%
def remove_page_duplicates(data, target_column='user_journey'):
    # Create a copy of the dataframe to ensure the original dataframe is not modified
    data_cleaned = data.copy()
    
    # Function to remove consecutive duplicates from a string of journey pages
    def remove_consecutive_duplicates(journey):
        # Split the journey string into a list of pages
        pages = journey.split('-')
        # Use a list comprehension to keep a page if it's not the same as the next one
        cleaned_pages = [pages[i] for i in range(len(pages) - 1) if pages[i] != pages[i+1]] + [pages[-1]]
        # Join the cleaned list back into a string
        return '-'.join(cleaned_pages)
    
    # Apply the function to the target column of the dataframe
    data_cleaned[target_column] = data_cleaned[target_column].apply(remove_consecutive_duplicates)
    
    return data_cleaned

# Apply the function to the loaded data
cleaned_data = remove_page_duplicates(data)

# Display the first few rows of the cleaned dataframe to verify the changes
cleaned_data.head()
# Out:
#    user_id  session_id subscription_type           user_journey
# 0     1516     2980231            Annual  Homepage-Log in-Other
# 1     1516     2980248            Annual   Other-Sign up-Log in
# 2     1516     2992252            Annual                 Log in
# 3     1516     3070491            Annual        Homepage-Log in
# 4     1516     3709807            Annual                 Log in

# %% [markdown]
# Next, we will look at the structure of the data. Currently, there is a row for every session of the user. But when considering a user’s journey, we’re interested in the page sequences instead of the specific sessions. To prepare the data for the analysis, we'll need to group a single user's journey strings into one big string—which is what the second function will do.

# %%
def group_by(data, group_column='user_id', target_column='user_journey', sessions='All', count_from='last'):
    data_sorted = data.sort_values(by=[group_column, 'session_id'])
    def group_journeys(sub_df):
        if sessions == 'All':
            journeys = sub_df[target_column].tolist()
        else:
            if count_from == 'first':
                journeys = sub_df[target_column].head(sessions).tolist()
            else:  # count_from == 'last'
                journeys = sub_df[target_column].tail(sessions).tolist()
        return '-'.join(journeys)
    grouped_data = data_sorted.groupby(group_column).apply(group_journeys).reset_index(name=target_column)
    return grouped_data

# Group all sessions for each user
grouped_data_all = group_by(cleaned_data)

# Display the first few rows of the grouped dataframe
grouped_data_all.head()
# Out:
#    user_id                                       user_journey
# 0     1516  Homepage-Log in-Other-Other-Sign up-Log in-Log...
# 1     3395  Other-Pricing-Sign up-Log in-Homepage-Pricing-...
# 2    10107  Homepage-Homepage-Career tracks-Homepage-Caree...
# 3    11145  Homepage-Log in-Homepage-Log in-Homepage-Log i...
# 4    12400  Homepage-Career tracks-Sign up-Log in-Other-Ca...

# %% [markdown]
# The final function that remains removes unnecessary pages from the data. (Not all pages are essential in a user journey analysis.) Perhaps prompts like ‘log in’ should be removed. But this is not something we can hardcode into the preprocessing because it’s a decision that the data scientist can make and tinker with. That’s why we should create a function that can be called upon later if needed.

# %%
def remove_pages(data, pages, target_column='user_journey'):
    # Create a copy of the dataframe to ensure the original dataframe is not modified
    data_cleaned = data.copy()
    
    # Function to remove specified pages from a journey string
    def remove_specified_pages(journey):
        # Split the journey string into a list of pages
        journey_list = journey.split('-')
        # Remove the specified pages
        cleaned_journey_list = [page for page in journey_list if page not in pages]
        # Join the cleaned list back into a string
        return '-'.join(cleaned_journey_list)
    
    # Apply the function to remove specified pages from the target column
    data_cleaned[target_column] = data_cleaned[target_column].apply(remove_specified_pages)
    
    return data_cleaned

# Example usage: Remove "Log in" pages from the user journey
pages_to_remove = ["Log in"]
data_without_login_pages = remove_pages(grouped_data_all, pages_to_remove)

# Display the first few rows of the dataframe with removed pages
data_without_login_pages.head()
# Out:
#    user_id                                       user_journey
# 0     1516  Homepage-Other-Other-Sign up-Homepage-Checkout...
# 1     3395  Other-Pricing-Sign up-Homepage-Pricing-Pricing...
# 2    10107  Homepage-Homepage-Career tracks-Homepage-Caree...
# 3    11145  Homepage-Homepage-Homepage-Homepage-Homepage-H...
# 4    12400  Homepage-Career tracks-Sign up-Other-Career tr...

# %% [markdown]
# ## Data Analyzing

# %% [markdown]
# Given the preprocessed data, you can begin your analysis in a new notebook to keep matters clean. Now is the time to think what metrics we can generate to obtain valuable statistics about the behavior of purchasing customers. Please take your time and think of as many such metrics as possible.

# %%
# Re-defining the essential functions for setup
def page_count(data, target_column='user_journey', subscription_type_column='subscription_type', plan=None):
    if plan:
        data_filtered = data[data[subscription_type_column] == plan]
    else:
        data_filtered = data
    
    page_counts = {}
    
    for journey in data_filtered[target_column]:
        pages = journey.split('-')
        for page in pages:
            if page not in page_counts:
                page_counts[page] = 1
            else:
                page_counts[page] += 1
    
    sorted_counts = sorted(page_counts.items(), key=lambda x: x[1], reverse=True)
    
    return sorted_counts

# Placeholder to indicate the function's readiness; actual data application will follow "Function `page_count` re-defined. Awaiting data to apply."

# %% [markdown]
# The function page_count has been re-defined and is ready for application on the data. This function will count the occurrences of each page across all user journeys, with the option to filter by subscription plan.

# %%
# Define the function for Page Presence
def page_presence(data, target_column='user_journey', subscription_type_column='subscription_type', plan=None):
    if plan:
        data_filtered = data[data[subscription_type_column] == plan]
    else:
        data_filtered = data
    
    page_presence_dict = {}
    
    for journey in data_filtered[target_column]:
        # Using a set to ensure each page in a journey is counted only once
        pages = set(journey.split('-'))
        for page in pages:
            if page not in page_presence_dict:
                page_presence_dict[page] = 1
            else:
                page_presence_dict[page] += 1
    
    sorted_presence = sorted(page_presence_dict.items(), key=lambda x: x[1], reverse=True)
    
    return sorted_presence

# %% [markdown]
# Page Presence aims to count how many unique journeys include each page at least once, regardless of how many times the page appears within a single journey.
# The process for this function involves filtering the dataset based on a specified subscription plan (if any), iterating through each user journey to identify unique pages, and then counting the presence of each unique page across all journeys. The results are sorted by the frequency of page presence to highlight the most common pages that appear in user journeys.

# %%
def page_destination(data, target_column='user_journey', subscription_type_column='subscription_type', plan=None):
    # Filter data by subscription plan if specified
    if plan:
        data_filtered = data[data[subscription_type_column] == plan]
    else:
        data_filtered = data

    # Initialize a dictionary to hold the follow-up page counts
    destination_counts = {}

    # Iterate through each journey in the filtered data
    for journey in data_filtered[target_column]:
        pages = journey.split('-')
        for i in range(len(pages) - 1):
            current_page = pages[i]
            next_page = pages[i + 1]
            if current_page not in destination_counts:
                destination_counts[current_page] = {next_page: 1}
            else:
                if next_page not in destination_counts[current_page]:
                    destination_counts[current_page][next_page] = 1
                else:
                    destination_counts[current_page][next_page] += 1

    # For analysis, convert counts to a more readable format or sort them
    for page, destinations in destination_counts.items():
        sorted_destinations = sorted(destinations.items(), key=lambda x: x[1], reverse=True)
        destination_counts[page] = sorted_destinations

    return destination_counts

# %% [markdown]
# The function page_destination calculates how often each page is followed by another, providing insights into user navigation patterns.
# It filters the journeys based on a specific subscription plan if provided.
# The function iterates through each user journey, tracking the sequence of pages and counting the transitions from one page to the next.
# It organizes the counts in a nested dictionary structure, where each key is a page and its value is another dictionary of pages that follow it, along with the counts of those transitions.
# The output is adjusted to provide sorted lists of follow-up pages for each page, making it easier to identify the most common next steps users take after visiting a specific page.

# %%
def page_sequences(data, sequence_length, target_column='user_journey', subscription_type_column='subscription_type', plan=None):
    # Filter data by subscription plan if specified
    if plan:
        data_filtered = data[data[subscription_type_column] == plan]
    else:
        data_filtered = data

    # Initialize a dictionary to hold counts of each page sequence
    sequence_counts = {}

    # Iterate through each journey in the filtered data
    for journey in data_filtered[target_column]:
        pages = journey.split('-')
        # Generate sequences of the specified length
        for i in range(len(pages) - sequence_length + 1):
            sequence = '-'.join(pages[i:i + sequence_length])
            if sequence not in sequence_counts:
                sequence_counts[sequence] = 1
            else:
                sequence_counts[sequence] += 1

    # Sort sequences by their counts in descending order
    sorted_sequences = sorted(sequence_counts.items(), key=lambda x: x[1], reverse=True)

    return sorted_sequences

# %% [markdown]
# This function, page_sequences, is designed to uncover patterns in user navigation by identifying and counting the occurrences of sequences of a specified length (N pages).
# It filters journeys based on a specific subscription plan if provided, allowing for targeted analysis.
# The function iterates through each user journey, extracting sequences of N consecutive pages and counting their occurrences across all journeys.
# The output is a sorted list of these sequences, with the most common sequences appearing first. This sorting makes it easier to identify the most frequently traveled paths.
#
# Use Cases
#
# Identifying Common Paths: Understand common navigation paths users take, which can be useful for optimizing user flow or enhancing popular content.
#
# Content Strategy: By recognizing the sequences that lead to conversions or high engagement, you can tailor your content strategy to reinforce these paths.
#
# User Experience Optimization: Identifying popular sequences can help in streamlining navigation, removing unnecessary steps, or highlighting key pathways to improve user experience.

# %%
def journey_length(data, target_column='user_journey', subscription_type_column='subscription_type', plan=None):
    # Filter data by subscription plan if specified
    if plan:
        data_filtered = data[data[subscription_type_column] == plan]
    else:
        data_filtered = data

    # Initialize a list to hold the lengths of all journeys
    journey_lengths = []

    # Iterate through each journey in the filtered data
    for journey in data_filtered[target_column]:
        # Count the number of pages in the journey
        pages = journey.split('-')
        journey_length = len(pages)
        journey_lengths.append(journey_length)

    # Calculate the average journey length
    if journey_lengths:
        avg_journey_length = sum(journey_lengths) / len(journey_lengths)
    else:
        avg_journey_length = 0

    return avg_journey_length

# %% [markdown]
# The function journey_length calculates the average number of pages visited in user journeys, providing an aggregate measure of engagement and navigation depth.
# It supports filtering by subscription plan, enabling comparisons of journey complexity across different user segments.
# By iterating through each journey, the function counts pages and computes the average length, offering insights into the overall user experience and the efficiency of the website's structure.
#
# Use Cases
#
# Evaluating User Engagement: Longer journeys might indicate higher engagement but can also suggest a convoluted path to conversion.
#
# Optimizing Navigation Paths: Understanding the average journey length helps in optimizing the site layout to either streamline paths to important actions or enhance user exploration, depending on the strategic goals.
#
# Segment Analysis: Comparing journey lengths across different subscription plans can reveal how different segments interact with the site, highlighting opportunities for tailored content or features.

# %%
page_count(data)
# Out:
# [('Checkout', 17896),
#  ('Log in', 17265),
#  ('Coupon', 11855),
#  ('Courses', 7149),
#  ('Sign up', 6824),
#  ('Other', 6820),
#  ('Career tracks', 4910),
#  ('Homepage', 3808),
#  ('Career track certificate', 3044),
#  ('Resources center', 2266),
#  ('Pricing', 2262),
#  ('Course certificate', 1114),
#  ('Success stories', 604),
#  ('Upcoming courses', 188),
#  ('Instructors', 76),
#  ('Blog', 36),
#  ('About us', 33)]

# %%
page_presence(data)
# Out:
# [('Log in', 3798),
#  ('Homepage', 2396),
#  ('Checkout', 2021),
#  ('Other', 1535),
#  ('Sign up', 1210),
#  ('Coupon', 1041),
#  ('Pricing', 929),
#  ('Courses', 908),
#  ('Career tracks', 747),
#  ('Career track certificate', 355),
#  ('Resources center', 339),
#  ('Course certificate', 191),
#  ('Upcoming courses', 101),
#  ('Success stories', 49),
#  ('Instructors', 26),
#  ('About us', 22),
#  ('Blog', 15)]

# %%
page_destination(data)
# Out:
# {'Homepage': [('Homepage', 1070),
#   ('Log in', 947),
#   ('Pricing', 442),
#   ('Career tracks', 349),
#   ('Sign up', 340),
#   ('Courses', 244),
#   ('Career track certificate', 116),
#   ('Course certificate', 65),
#   ('Resources center', 50),
#   ('Instructors', 25),
#   ('Other', 23),
#   ('Upcoming courses', 10),
#   ('About us', 5),
#   ('Success stories', 4),
#   ('Blog', 4),
#   ('Checkout', 1),
#   ('Coupon', 1)],
#  'Log in': [('Log in', 13389),
#   ('Sign up', 107),
#   ('Other', 90),
#   ('Homepage', 28),
#   ('Courses', 5),
#   ('Pricing', 5),
#   ('Career tracks', 4),
#   ('Career track certificate', 3),
#   ('Resources center', 1)],
#  'Other': [('Other', 5057),
#   ('Resources center', 248),
#   ('Log in', 79),
#   ('Sign up', 45),
#   ('Pricing', 45),
#   ('Courses', 29),
#   ('Coupon', 26),
#   ('Career track certificate', 22),
#   ('Career tracks', 19),
#   ('Homepage', 16),
#   ('Success stories', 14),
#   ('Course certificate', 13),
#   ('Blog', 6),
#   ('Upcoming courses', 4),
#   ('About us', 4)],
#  'Sign up': [('Sign up', 5521),
#   ('Log in', 238),
#   ('Homepage', 58),
#   ('Career tracks', 37),
#   ('Career track certificate', 33),
#   ('Courses', 29),
#   ('Pricing', 26),
#   ('Course certificate', 8),
#   ('Upcoming courses', 1),
#   ('Other', 1),
#   ('Checkout', 1)],
#  'Checkout': [('Checkout', 15832),
#   ('Pricing', 82),
#   ('Homepage', 28),
#   ('Courses', 3),
#   ('Success stories', 1),
#   ('Sign up', 1)],
#  'Coupon': [('Coupon', 10814), ('Homepage', 12)],
#  'Pricing': [('Pricing', 1168),
#   ('Checkout', 286),
#   ('Sign up', 128),
#   ('Courses', 99),
#   ('Log in', 80),
#   ('Career track certificate', 58),
#   ('Career tracks', 53),
#   ('Homepage', 49),
#   ('Resources center', 32),
#   ('Course certificate', 22),
#   ('Upcoming courses', 13),
#   ('Other', 13),
#   ('Success stories', 4),
#   ('Blog', 2),
#   ('Instructors', 1)],
#  'Career tracks': [('Career tracks', 3775),
#   ('Courses', 341),
#   ('Sign up', 194),
#   ('Homepage', 106),
#   ('Career track certificate', 81),
#   ('Pricing', 77),
#   ('Log in', 37),
#   ('Upcoming courses', 22),
#   ('Resources center', 15),
#   ('Course certificate', 12),
#   ('Success stories', 7),
#   ('Other', 7),
#   ('Instructors', 1)],
#  'Resources center': [('Resources center', 1686),
#   ('Other', 337),
#   ('Courses', 28),
#   ('Log in', 27),
#   ('Pricing', 17),
#   ('Homepage', 17),
#   ('Career track certificate', 16),
#   ('Course certificate', 14),
#   ('Career tracks', 13),
#   ('Upcoming courses', 8),
#   ('Sign up', 6),
#   ('Success stories', 4),
#   ('About us', 2),
#   ('Instructors', 1)],
#  'Courses': [('Courses', 5962),
#   ('Career tracks', 260),
#   ('Sign up', 209),
#   ('Pricing', 90),
#   ('Log in', 60),
#   ('Homepage', 53),
#   ('Career track certificate', 38),
#   ('Upcoming courses', 26),
#   ('Course certificate', 25),
#   ('Resources center', 19),
#   ('Other', 6),
#   ('Success stories', 5),
#   ('Blog', 2)],
#  'Career track certificate': [('Career track certificate', 2563),
#   ('Career tracks', 164),
#   ('Sign up', 65),
#   ('Pricing', 42),
#   ('Courses', 35),
#   ('Course certificate', 34),
#   ('Resources center', 18),
#   ('Log in', 14),
#   ('Homepage', 7),
#   ('Upcoming courses', 4),
#   ('Success stories', 3),
#   ('Other', 2),
#   ('Instructors', 2),
#   ('Coupon', 1),
#   ('About us', 1)],
#  'Instructors': [('Instructors', 33),
#   ('Homepage', 20),
#   ('Courses', 7),
#   ('Pricing', 5),
#   ('Other', 2),
#   ('About us', 2),
#   ('Career track certificate', 2),
#   ('Log in', 1)],
#  'Course certificate': [('Course certificate', 897),
#   ('Career track certificate', 47),
#   ('Courses', 35),
#   ('Sign up', 26),
#   ('Pricing', 17),
#   ('Upcoming courses', 14),
#   ('Career tracks', 12),
#   ('Resources center', 10),
#   ('Log in', 9),
#   ('Homepage', 6),
#   ('Other', 3)],
#  'Success stories': [('Success stories', 551),
#   ('Resources center', 6),
#   ('Career tracks', 5),
#   ('Homepage', 4),
#   ('Career track certificate', 4),
#   ('Pricing', 3),
#   ('Sign up', 3),
#   ('Other', 3),
#   ('Blog', 2),
#   ('Log in', 2),
#   ('Upcoming courses', 2),
#   ('Courses', 1),
#   ('About us', 1)],
#  'Upcoming courses': [('Upcoming courses', 74),
#   ('Courses', 32),
#   ('Career tracks', 23),
#   ('Resources center', 10),
#   ('Pricing', 7),
#   ('Course certificate', 7),
#   ('Career track certificate', 7),
#   ('Other', 5),
#   ('Log in', 2),
#   ('Success stories', 2),
#   ('Homepage', 2),
#   ('About us', 1),
#   ('Sign up', 1)],
#  'Blog': [('Blog', 16),
#   ('Other', 9),
#   ('Homepage', 2),
#   ('Log in', 1),
#   ('Courses', 1),
#   ('Pricing', 1)],
#  'About us': [('About us', 11),
#   ('Other', 5),
#   ('Resources center', 2),
#   ('Pricing', 2),
#   ('Sign up', 1),
#   ('Career track certificate', 1),
#   ('Instructors', 1),
#   ('Courses', 1),
#   ('Upcoming courses', 1),
#   ('Success stories', 1),
#   ('Homepage', 1)]}

# %%
page_sequences(data,2)
# Out:
# [('Checkout-Checkout', 15832),
#  ('Log in-Log in', 13389),
#  ('Coupon-Coupon', 10814),
#  ('Courses-Courses', 5962),
#  ('Sign up-Sign up', 5521),
#  ('Other-Other', 5057),
#  ('Career tracks-Career tracks', 3775),
#  ('Career track certificate-Career track certificate', 2563),
#  ('Resources center-Resources center', 1686),
#  ('Pricing-Pricing', 1168),
#  ('Homepage-Homepage', 1070),
#  ('Homepage-Log in', 947),
#  ('Course certificate-Course certificate', 897),
#  ('Success stories-Success stories', 551),
#  ('Homepage-Pricing', 442),
#  ('Homepage-Career tracks', 349),
#  ('Career tracks-Courses', 341),
#  ('Homepage-Sign up', 340),
#  ('Resources center-Other', 337),
#  ('Pricing-Checkout', 286),
#  ('Courses-Career tracks', 260),
#  ('Other-Resources center', 248),
#  ('Homepage-Courses', 244),
#  ('Sign up-Log in', 238),
#  ('Courses-Sign up', 209),
#  ('Career tracks-Sign up', 194),
#  ('Career track certificate-Career tracks', 164),
#  ('Pricing-Sign up', 128),
#  ('Homepage-Career track certificate', 116),
#  ('Log in-Sign up', 107),
#  ('Career tracks-Homepage', 106),
#  ('Pricing-Courses', 99),
#  ('Log in-Other', 90),
#  ('Courses-Pricing', 90),
#  ('Checkout-Pricing', 82),
#  ('Career tracks-Career track certificate', 81),
#  ('Pricing-Log in', 80),
#  ('Other-Log in', 79),
#  ('Career tracks-Pricing', 77),
#  ('Upcoming courses-Upcoming courses', 74),
#  ('Homepage-Course certificate', 65),
#  ('Career track certificate-Sign up', 65),
#  ('Courses-Log in', 60),
#  ('Sign up-Homepage', 58),
#  ('Pricing-Career track certificate', 58),
#  ('Pricing-Career tracks', 53),
#  ('Courses-Homepage', 53),
#  ('Homepage-Resources center', 50),
#  ('Pricing-Homepage', 49),
#  ('Course certificate-Career track certificate', 47),
#  ('Other-Sign up', 45),
#  ('Other-Pricing', 45),
#  ('Career track certificate-Pricing', 42),
#  ('Courses-Career track certificate', 38),
#  ('Career tracks-Log in', 37),
#  ('Sign up-Career tracks', 37),
#  ('Course certificate-Courses', 35),
#  ('Career track certificate-Courses', 35),
#  ('Career track certificate-Course certificate', 34),
#  ('Instructors-Instructors', 33),
#  ('Sign up-Career track certificate', 33),
#  ('Upcoming courses-Courses', 32),
#  ('Pricing-Resources center', 32),
#  ('Sign up-Courses', 29),
#  ('Other-Courses', 29),
#  ('Resources center-Courses', 28),
#  ('Checkout-Homepage', 28),
#  ('Log in-Homepage', 28),
#  ('Resources center-Log in', 27),
#  ('Sign up-Pricing', 26),
#  ('Other-Coupon', 26),
#  ('Courses-Upcoming courses', 26),
#  ('Course certificate-Sign up', 26),
#  ('Homepage-Instructors', 25),
#  ('Courses-Course certificate', 25),
#  ('Homepage-Other', 23),
#  ('Upcoming courses-Career tracks', 23),
#  ('Other-Career track certificate', 22),
#  ('Pricing-Course certificate', 22),
#  ('Career tracks-Upcoming courses', 22),
#  ('Instructors-Homepage', 20),
#  ('Courses-Resources center', 19),
#  ('Other-Career tracks', 19),
#  ('Career track certificate-Resources center', 18),
#  ('Resources center-Pricing', 17),
#  ('Resources center-Homepage', 17),
#  ('Course certificate-Pricing', 17),
#  ('Other-Homepage', 16),
#  ('Resources center-Career track certificate', 16),
#  ('Blog-Blog', 16),
#  ('Career tracks-Resources center', 15),
#  ('Career track certificate-Log in', 14),
#  ('Course certificate-Upcoming courses', 14),
#  ('Other-Success stories', 14),
#  ('Resources center-Course certificate', 14),
#  ('Pricing-Upcoming courses', 13),
#  ('Pricing-Other', 13),
#  ('Resources center-Career tracks', 13),
#  ('Other-Course certificate', 13),
#  ('Career tracks-Course certificate', 12),
#  ('Course certificate-Career tracks', 12),
#  ('Coupon-Homepage', 12),
#  ('About us-About us', 11),
#  ('Course certificate-Resources center', 10),
#  ('Homepage-Upcoming courses', 10),
#  ('Upcoming courses-Resources center', 10),
#  ('Course certificate-Log in', 9),
#  ('Blog-Other', 9),
#  ('Sign up-Course certificate', 8),
#  ('Resources center-Upcoming courses', 8),
#  ('Upcoming courses-Pricing', 7),
#  ('Upcoming courses-Course certificate', 7),
#  ('Career tracks-Success stories', 7),
#  ('Career tracks-Other', 7),
#  ('Career track certificate-Homepage', 7),
#  ('Upcoming courses-Career track certificate', 7),
#  ('Instructors-Courses', 7),
#  ('Resources center-Sign up', 6),
#  ('Success stories-Resources center', 6),
#  ('Course certificate-Homepage', 6),
#  ('Courses-Other', 6),
#  ('Other-Blog', 6),
#  ('Instructors-Pricing', 5),
#  ('Log in-Courses', 5),
#  ('Log in-Pricing', 5),
#  ('Homepage-About us', 5),
#  ('About us-Other', 5),
#  ('Upcoming courses-Other', 5),
#  ('Courses-Success stories', 5),
#  ('Success stories-Career tracks', 5),
#  ('Homepage-Success stories', 4),
#  ('Pricing-Success stories', 4),
#  ('Success stories-Homepage', 4),
#  ('Career track certificate-Upcoming courses', 4),
#  ('Log in-Career tracks', 4),
#  ('Success stories-Career track certificate', 4),
#  ('Resources center-Success stories', 4),
#  ('Other-Upcoming courses', 4),
#  ('Homepage-Blog', 4),
#  ('Other-About us', 4),
#  ('Success stories-Pricing', 3),
#  ('Course certificate-Other', 3),
#  ('Checkout-Courses', 3),
#  ('Log in-Career track certificate', 3),
#  ('Success stories-Sign up', 3),
#  ('Career track certificate-Success stories', 3),
#  ('Success stories-Other', 3),
#  ('Upcoming courses-Log in', 2),
#  ('Pricing-Blog', 2),
#  ('Upcoming courses-Success stories', 2),
#  ('Resources center-About us', 2),
#  ('Career track certificate-Other', 2),
#  ('Instructors-Other', 2),
#  ('Success stories-Blog', 2),
#  ('Blog-Homepage', 2),
#  ('Instructors-About us', 2),
#  ('Success stories-Log in', 2),
#  ('About us-Resources center', 2),
#  ('About us-Pricing', 2),
#  ('Upcoming courses-Homepage', 2),
#  ('Courses-Blog', 2),
#  ('Success stories-Upcoming courses', 2),
#  ('Instructors-Career track certificate', 2),
#  ('Career track certificate-Instructors', 2),
#  ('Sign up-Upcoming courses', 1),
#  ('Sign up-Other', 1),
#  ('Blog-Log in', 1),
#  ('Checkout-Success stories', 1),
#  ('Success stories-Courses', 1),
#  ('Instructors-Log in', 1),
#  ('Homepage-Checkout', 1),
#  ('Log in-Resources center', 1),
#  ('About us-Sign up', 1),
#  ('Checkout-Sign up', 1),
#  ('Sign up-Checkout', 1),
#  ('Resources center-Instructors', 1),
#  ('Career track certificate-Coupon', 1),
#  ('Career track certificate-About us', 1),
#  ('About us-Career track certificate', 1),
#  ('Upcoming courses-About us', 1),
#  ('About us-Instructors', 1),
#  ('About us-Courses', 1),
#  ('About us-Upcoming courses', 1),
#  ('Upcoming courses-Sign up', 1),
#  ('Pricing-Instructors', 1),
#  ('About us-Success stories', 1),
#  ('Homepage-Coupon', 1),
#  ('Blog-Courses', 1),
#  ('Blog-Pricing', 1),
#  ('Success stories-About us', 1),
#  ('About us-Homepage', 1),
#  ('Career tracks-Instructors', 1)]

# %%
page_sequences(data,3)
# Out:
# [('Checkout-Checkout-Checkout', 13939),
#  ('Coupon-Coupon-Coupon', 9774),
#  ('Log in-Log in-Log in', 9757),
#  ('Courses-Courses-Courses', 5040),
#  ('Sign up-Sign up-Sign up', 4568),
#  ('Other-Other-Other', 3870),
#  ('Career tracks-Career tracks-Career tracks', 2894),
#  ('Career track certificate-Career track certificate-Career track certificate',
#   2163),
#  ('Resources center-Resources center-Resources center', 1271),
#  ('Homepage-Log in-Log in', 827),
#  ('Homepage-Homepage-Homepage', 711),
#  ('Course certificate-Course certificate-Course certificate', 705),
#  ('Pricing-Pricing-Pricing', 557),
#  ('Success stories-Success stories-Success stories', 505),
#  ('Homepage-Pricing-Pricing', 327),
#  ('Homepage-Career tracks-Career tracks', 300),
#  ('Career tracks-Courses-Courses', 299),
#  ('Career tracks-Career tracks-Courses', 270),
#  ('Homepage-Sign up-Sign up', 250),
#  ('Resources center-Resources center-Other', 246),
#  ('Other-Resources center-Resources center', 234),
#  ('Homepage-Courses-Courses', 232),
#  ('Courses-Career tracks-Career tracks', 218),
#  ('Sign up-Log in-Log in', 210),
#  ('Courses-Courses-Career tracks', 210),
#  ('Sign up-Sign up-Log in', 203),
#  ('Resources center-Other-Resources center', 185),
#  ('Pricing-Pricing-Checkout', 168),
#  ('Courses-Sign up-Sign up', 145),
#  ('Career track certificate-Career tracks-Career tracks', 143),
#  ('Career tracks-Career tracks-Sign up', 139),
#  ('Career track certificate-Career track certificate-Career tracks', 133),
#  ('Courses-Courses-Sign up', 130),
#  ('Career tracks-Sign up-Sign up', 128),
#  ('Pricing-Checkout-Checkout', 118),
#  ('Homepage-Homepage-Career tracks', 111),
#  ('Homepage-Career track certificate-Career track certificate', 107),
#  ('Pricing-Sign up-Sign up', 98),
#  ('Pricing-Courses-Courses', 93),
#  ('Log in-Sign up-Sign up', 93),
#  ('Pricing-Pricing-Sign up', 84),
#  ('Log in-Log in-Other', 80),
#  ('Pricing-Checkout-Pricing', 74),
#  ('Career tracks-Career tracks-Homepage', 70),
#  ('Pricing-Log in-Log in', 70),
#  ('Other-Log in-Log in', 70),
#  ('Log in-Log in-Sign up', 70),
#  ('Courses-Pricing-Pricing', 64),
#  ('Pricing-Pricing-Courses', 63),
#  ('Homepage-Course certificate-Course certificate', 62),
#  ('Career tracks-Homepage-Homepage', 60),
#  ('Resources center-Other-Other', 60),
#  ('Career tracks-Career track certificate-Career track certificate', 59),
#  ('Career tracks-Career tracks-Pricing', 59),
#  ('Career tracks-Career tracks-Career track certificate', 56),
#  ('Courses-Courses-Pricing', 56),
#  ('Pricing-Career track certificate-Career track certificate', 56),
#  ('Career tracks-Pricing-Pricing', 54),
#  ('Career track certificate-Career track certificate-Sign up', 53),
#  ('Pricing-Career tracks-Career tracks', 49),
#  ('Courses-Log in-Log in', 48),
#  ('Homepage-Resources center-Resources center', 47),
#  ('Course certificate-Career track certificate-Career track certificate', 45),
#  ('Courses-Courses-Homepage', 45),
#  ('Homepage-Sign up-Homepage', 44),
#  ('Course certificate-Course certificate-Career track certificate', 43),
#  ('Pricing-Pricing-Career track certificate', 43),
#  ('Other-Other-Resources center', 42),
#  ('Courses-Homepage-Homepage', 42),
#  ('Career tracks-Homepage-Career tracks', 39),
#  ('Courses-Career tracks-Courses', 39),
#  ('Homepage-Homepage-Pricing', 38),
#  ('Other-Sign up-Sign up', 37),
#  ('Courses-Career track certificate-Career track certificate', 37),
#  ('Other-Pricing-Pricing', 37),
#  ('Homepage-Career tracks-Homepage', 36),
#  ('Pricing-Pricing-Homepage', 35),
#  ('Career tracks-Sign up-Career tracks', 35),
#  ('Career track certificate-Pricing-Pricing', 34),
#  ('Checkout-Pricing-Checkout', 34),
#  ('Course certificate-Course certificate-Courses', 34),
#  ('Pricing-Pricing-Career tracks', 33),
#  ('Pricing-Pricing-Log in', 33),
#  ('Career track certificate-Course certificate-Course certificate', 33),
#  ('Career track certificate-Courses-Courses', 33),
#  ('Career track certificate-Career track certificate-Pricing', 32),
#  ('Career track certificate-Career track certificate-Course certificate', 32),
#  ('Course certificate-Courses-Courses', 31),
#  ('Career track certificate-Sign up-Sign up', 31),
#  ('Courses-Courses-Career track certificate', 30),
#  ('Career tracks-Log in-Log in', 29),
#  ('Upcoming courses-Courses-Courses', 29),
#  ('Pricing-Homepage-Homepage', 29),
#  ('Career track certificate-Career track certificate-Courses', 29),
#  ('Career tracks-Courses-Career tracks', 28),
#  ('Other-Other-Log in', 27),
#  ('Courses-Courses-Log in', 27),
#  ('Pricing-Resources center-Resources center', 27),
#  ('Resources center-Log in-Log in', 26),
#  ('Other-Courses-Courses', 26),
#  ('Other-Coupon-Coupon', 25),
#  ('Upcoming courses-Upcoming courses-Courses', 25),
#  ('Resources center-Courses-Courses', 25),
#  ('Pricing-Pricing-Resources center', 25),
#  ('Sign up-Homepage-Homepage', 24),
#  ('Other-Other-Coupon', 24),
#  ('Career track certificate-Sign up-Career track certificate', 24),
#  ('Courses-Course certificate-Course certificate', 24),
#  ('Instructors-Instructors-Instructors', 24),
#  ('Sign up-Career tracks-Career tracks', 23),
#  ('Homepage-Homepage-Courses', 23),
#  ('Courses-Sign up-Courses', 23),
#  ('Resources center-Resources center-Courses', 22),
#  ('Courses-Courses-Upcoming courses', 22),
#  ('Checkout-Checkout-Homepage', 22),
#  ('Upcoming courses-Career tracks-Career tracks', 21),
#  ('Other-Career track certificate-Career track certificate', 20),
#  ('Career tracks-Career track certificate-Career tracks', 20),
#  ('Pricing-Course certificate-Course certificate', 20),
#  ('Course certificate-Course certificate-Sign up', 20),
#  ('Sign up-Career track certificate-Career track certificate', 20),
#  ('Career tracks-Career tracks-Upcoming courses', 20),
#  ('Homepage-Other-Other', 19),
#  ('Courses-Upcoming courses-Upcoming courses', 19),
#  ('Career tracks-Career tracks-Log in', 19),
#  ('Upcoming courses-Upcoming courses-Career tracks', 19),
#  ('Career track certificate-Career tracks-Career track certificate', 18),
#  ('Homepage-Homepage-Sign up', 18),
#  ('Log in-Homepage-Log in', 18),
#  ('Other-Career tracks-Career tracks', 18),
#  ('Homepage-Instructors-Homepage', 18),
#  ('Homepage-Homepage-Log in', 17),
#  ('Courses-Courses-Resources center', 17),
#  ('Courses-Courses-Course certificate', 17),
#  ('Career track certificate-Resources center-Resources center', 16),
#  ('Resources center-Career track certificate-Career track certificate', 16),
#  ('Course certificate-Sign up-Sign up', 16),
#  ('Courses-Resources center-Resources center', 16),
#  ('Homepage-Log in-Homepage', 16),
#  ('Career track certificate-Career track certificate-Resources center', 15),
#  ('Log in-Other-Log in', 15),
#  ('Sign up-Courses-Courses', 15),
#  ('Checkout-Homepage-Homepage', 15),
#  ('Checkout-Pricing-Pricing', 15),
#  ('Career tracks-Upcoming courses-Upcoming courses', 15),
#  ('Instructors-Homepage-Homepage', 14),
#  ('Resources center-Pricing-Pricing', 14),
#  ('Homepage-Homepage-Career track certificate', 14),
#  ('Other-Other-Pricing', 14),
#  ('Other-Success stories-Success stories', 14),
#  ('Resources center-Course certificate-Course certificate', 14),
#  ('Course certificate-Pricing-Pricing', 14),
#  ('Homepage-Homepage-Instructors', 14),
#  ('Resources center-Career tracks-Career tracks', 13),
#  ('Career track certificate-Career track certificate-Log in', 13),
#  ('Career tracks-Career tracks-Resources center', 13),
#  ('Career tracks-Resources center-Resources center', 13),
#  ('Pricing-Pricing-Course certificate', 13),
#  ('Course certificate-Course certificate-Pricing', 13),
#  ('Pricing-Sign up-Pricing', 12),
#  ('Other-Other-Homepage', 12),
#  ('Resources center-Resources center-Homepage', 12),
#  ('Sign up-Pricing-Pricing', 12),
#  ('Career track certificate-Log in-Log in', 12),
#  ('Career tracks-Course certificate-Course certificate', 12),
#  ('Other-Course certificate-Course certificate', 12),
#  ('Homepage-Pricing-Homepage', 12),
#  ('Course certificate-Course certificate-Upcoming courses', 12),
#  ('Course certificate-Course certificate-Career tracks', 12),
#  ('Course certificate-Career tracks-Career tracks', 12),
#  ('Coupon-Coupon-Homepage', 12),
#  ('Resources center-Resources center-Course certificate', 12),
#  ('Log in-Log in-Homepage', 12),
#  ('Pricing-Upcoming courses-Upcoming courses', 11),
#  ('Resources center-Homepage-Homepage', 11),
#  ('Resources center-Resources center-Career track certificate', 11),
#  ('Homepage-Homepage-Other', 11),
#  ('Homepage-Homepage-Resources center', 11),
#  ('Resources center-Resources center-Career tracks', 11),
#  ('Course certificate-Course certificate-Resources center', 10),
#  ('Course certificate-Resources center-Resources center', 10),
#  ('Resources center-Resources center-Pricing', 10),
#  ('Resources center-Resources center-Log in', 10),
#  ('Sign up-Homepage-Pricing', 9),
#  ('Pricing-Other-Other', 9),
#  ('Upcoming courses-Upcoming courses-Resources center', 9),
#  ('Upcoming courses-Resources center-Resources center', 9),
#  ('Other-Homepage-Homepage', 9),
#  ('Pricing-Homepage-Pricing', 9),
#  ('Log in-Other-Other', 9),
#  ('Pricing-Pricing-Upcoming courses', 9),
#  ('Sign up-Sign up-Homepage', 9),
#  ('Sign up-Sign up-Pricing', 8),
#  ('Other-Other-Sign up', 8),
#  ('Checkout-Checkout-Pricing', 8),
#  ('Career tracks-Career tracks-Course certificate', 8),
#  ('Course certificate-Course certificate-Log in', 8),
#  ('Other-Other-Success stories', 8),
#  ('Career tracks-Pricing-Career tracks', 7),
#  ('Other-Other-Courses', 7),
#  ('Checkout-Homepage-Log in', 7),
#  ('Course certificate-Log in-Log in', 7),
#  ('Course certificate-Upcoming courses-Upcoming courses', 7),
#  ('Courses-Pricing-Courses', 7),
#  ('Career tracks-Career tracks-Other', 7),
#  ('Upcoming courses-Upcoming courses-Career track certificate', 7),
#  ('Upcoming courses-Career track certificate-Career track certificate', 7),
#  ('Instructors-Courses-Courses', 7),
#  ('Checkout-Pricing-Courses', 6),
#  ('Sign up-Homepage-Log in', 6),
#  ('Upcoming courses-Pricing-Pricing', 6),
#  ('Course certificate-Sign up-Course certificate', 6),
#  ('Blog-Blog-Other', 6),
#  ('Success stories-Success stories-Resources center', 6),
#  ('Homepage-Upcoming courses-Upcoming courses', 6),
#  ('Other-Other-Career tracks', 6),
#  ('Upcoming courses-Course certificate-Course certificate', 6),
#  ('Resources center-Upcoming courses-Upcoming courses', 6),
#  ('Checkout-Pricing-Sign up', 6),
#  ('Sign up-Sign up-Career track certificate', 6),
#  ('Instructors-Homepage-Instructors', 6),
#  ('Sign up-Pricing-Sign up', 5),
#  ('Pricing-Pricing-Other', 5),
#  ('Log in-Courses-Courses', 5),
#  ('Sign up-Homepage-Career tracks', 5),
#  ('About us-About us-Other', 5),
#  ('Sign up-Courses-Pricing', 5),
#  ('Sign up-Homepage-Courses', 5),
#  ('Sign up-Log in-Sign up', 5),
#  ('Log in-Sign up-Log in', 5),
#  ('Upcoming courses-Other-Other', 5),
#  ('Career tracks-Other-Other', 5),
#  ('Career track certificate-Career track certificate-Homepage', 5),
#  ('Resources center-Resources center-Upcoming courses', 5),
#  ('Courses-Success stories-Success stories', 5),
#  ('Homepage-Instructors-Instructors', 4),
#  ('Homepage-Success stories-Success stories', 4),
#  ('Sign up-Sign up-Courses', 4),
#  ('Courses-Sign up-Log in', 4),
#  ('Pricing-Success stories-Success stories', 4),
#  ('Blog-Other-Other', 4),
#  ('Career track certificate-Career track certificate-Upcoming courses', 4),
#  ('Course certificate-Upcoming courses-Course certificate', 4),
#  ('Upcoming courses-Upcoming courses-Pricing', 4),
#  ('Course certificate-Course certificate-Homepage', 4),
#  ('Success stories-Career track certificate-Career track certificate', 4),
#  ('Career tracks-Career tracks-Success stories', 4),
#  ('Career tracks-Success stories-Success stories', 4),
#  ('Courses-Other-Other', 4),
#  ('Resources center-Success stories-Success stories', 4),
#  ('Log in-Homepage-Homepage', 4),
#  ('Homepage-Homepage-Course certificate', 4),
#  ('Homepage-Courses-Homepage', 4),
#  ('Log in-Other-Sign up', 4),
#  ('Checkout-Pricing-Log in', 4),
#  ('Other-Other-Upcoming courses', 4),
#  ('Courses-Upcoming courses-Courses', 4),
#  ('Resources center-Sign up-Sign up', 4),
#  ('Sign up-Career tracks-Pricing', 4),
#  ('Checkout-Pricing-Career track certificate', 4),
#  ('Career track certificate-Homepage-Homepage', 4),
#  ('Sign up-Career track certificate-Pricing', 4),
#  ('Success stories-Career tracks-Career tracks', 4),
#  ('Career tracks-Homepage-Sign up', 3),
#  ('Other-Homepage-Log in', 3),
#  ('Success stories-Success stories-Pricing', 3),
#  ('Success stories-Pricing-Pricing', 3),
#  ('Sign up-Homepage-Course certificate', 3),
#  ('Resources center-Resources center-Sign up', 3),
#  ('Sign up-Pricing-Courses', 3),
#  ('Pricing-Pricing-Success stories', 3),
#  ('Success stories-Success stories-Homepage', 3),
#  ('Log in-Pricing-Pricing', 3),
#  ('Log in-Career tracks-Career tracks', 3),
#  ('Success stories-Success stories-Career track certificate', 3),
#  ('Success stories-Homepage-Homepage', 3),
#  ('Courses-Courses-Other', 3),
#  ('Career track certificate-Upcoming courses-Upcoming courses', 3),
#  ('Resources center-Homepage-Resources center', 3),
#  ('Coupon-Homepage-Sign up', 3),
#  ('Checkout-Pricing-Career tracks', 3),
#  ('Pricing-Checkout-Homepage', 3),
#  ('Pricing-Checkout-Courses', 3),
#  ('Log in-Career track certificate-Career track certificate', 3),
#  ('Courses-Sign up-Homepage', 3),
#  ('Pricing-Courses-Pricing', 3),
#  ('Sign up-Career tracks-Career track certificate', 3),
#  ('Sign up-Homepage-Career track certificate', 3),
#  ('Courses-Courses-Success stories', 3),
#  ('Success stories-Success stories-Sign up', 3),
#  ('Coupon-Homepage-Homepage', 3),
#  ('Sign up-Career track certificate-Career tracks', 3),
#  ('Sign up-Course certificate-Pricing', 3),
#  ('Career track certificate-Success stories-Success stories', 3),
#  ('Blog-Blog-Blog', 3),
#  ('Homepage-Blog-Blog', 3),
#  ('Other-About us-About us', 3),
#  ('Upcoming courses-Upcoming courses-Other', 3),
#  ('Success stories-Success stories-Other', 3),
#  ('Other-Blog-Other', 3),
#  ('Blog-Other-Blog', 3),
#  ('Sign up-Career track certificate-Courses', 3),
#  ('Success stories-Resources center-Resources center', 3),
#  ('Upcoming courses-Upcoming courses-Course certificate', 3),
#  ('Instructors-Instructors-Homepage', 2),
#  ('Sign up-Pricing-Checkout', 2),
#  ('Instructors-Pricing-Pricing', 2),
#  ('Checkout-Pricing-Upcoming courses', 2),
#  ('Upcoming courses-Log in-Log in', 2),
#  ('Log in-Log in-Courses', 2),
#  ('Other-Pricing-Other', 2),
#  ('Other-Resources center-Other', 2),
#  ('Pricing-Pricing-Blog', 2),
#  ('Pricing-Blog-Blog', 2),
#  ('Checkout-Pricing-Course certificate', 2),
#  ('Coupon-Homepage-Log in', 2),
#  ('Upcoming courses-Success stories-Success stories', 2),
#  ('Resources center-Resources center-About us', 2),
#  ('About us-Other-Other', 2),
#  ('Course certificate-Other-Other', 2),
#  ('Checkout-Pricing-Other', 2),
#  ('Homepage-Resources center-Homepage', 2),
#  ('Career track certificate-Other-Other', 2),
#  ('Homepage-Other-Homepage', 2),
#  ('Homepage-Sign up-Log in', 2),
#  ('Resources center-Resources center-Success stories', 2),
#  ('Checkout-Pricing-Homepage', 2),
#  ('Homepage-Course certificate-Homepage', 2),
#  ('Course certificate-Homepage-Courses', 2),
#  ('Courses-Homepage-Sign up', 2),
#  ('Courses-Homepage-Courses', 2),
#  ('Instructors-Other-Other', 2),
#  ('Success stories-Blog-Blog', 2),
#  ('Sign up-Homepage-Sign up', 2),
#  ('Log in-Homepage-Pricing', 2),
#  ('Coupon-Homepage-Pricing', 2),
#  ('Sign up-Career tracks-Log in', 2),
#  ('Instructors-About us-About us', 2),
#  ('Sign up-Courses-Sign up', 2),
#  ('Sign up-Courses-Log in', 2),
#  ('Sign up-Courses-Career tracks', 2),
#  ('Sign up-Course certificate-Sign up', 2),
#  ('Career tracks-Homepage-Courses', 2),
#  ('Success stories-Success stories-Log in', 2),
#  ('Success stories-Log in-Log in', 2),
#  ('Career tracks-Upcoming courses-Career tracks', 2),
#  ('About us-Pricing-Pricing', 2),
#  ('Homepage-Career track certificate-Homepage', 2),
#  ('Upcoming courses-Courses-Upcoming courses', 2),
#  ('Career track certificate-Career track certificate-Success stories', 2),
#  ('Homepage-About us-About us', 2),
#  ('Sign up-Sign up-Career tracks', 2),
#  ('Sign up-Career tracks-Sign up', 2),
#  ('Pricing-Other-Coupon', 2),
#  ('Career tracks-Other-Career tracks', 2),
#  ('Sign up-Career tracks-Courses', 2),
#  ('Success stories-Success stories-Career tracks', 2),
#  ('Homepage-Homepage-Blog', 2),
#  ('Other-Other-Career track certificate', 2),
#  ('Other-Upcoming courses-Upcoming courses', 2),
#  ('Success stories-Other-Other', 2),
#  ('Other-Blog-Blog', 2),
#  ('Courses-Blog-Blog', 2),
#  ('Career track certificate-Sign up-Log in', 2),
#  ('Success stories-Success stories-Upcoming courses', 2),
#  ('Success stories-Upcoming courses-Upcoming courses', 2),
#  ('Instructors-Career track certificate-Career track certificate', 2),
#  ('Checkout-Courses-Courses', 2),
#  ('Career track certificate-Instructors-Instructors', 2),
#  ('Other-Other-Course certificate', 2),
#  ('Checkout-Pricing-Resources center', 2),
#  ('Instructors-Instructors-Courses', 2),
#  ('Sign up-Course certificate-Course certificate', 2),
#  ('Career tracks-Upcoming courses-Courses', 2),
#  ('Log in-Homepage-Resources center', 2),
#  ('Courses-Homepage-Career tracks', 2),
#  ('Career tracks-Sign up-Log in', 1),
#  ('Career tracks-Sign up-Homepage', 1),
#  ('Pricing-Career tracks-Pricing', 1),
#  ('Sign up-Career track certificate-Resources center', 1),
#  ('Resources center-Courses-Resources center', 1),
#  ('Courses-Resources center-Courses', 1),
#  ('Career track certificate-Pricing-Course certificate', 1),
#  ('Homepage-Homepage-Upcoming courses', 1),
#  ('Homepage-Upcoming courses-Log in', 1),
#  ('Sign up-Sign up-Upcoming courses', 1),
#  ('Sign up-Upcoming courses-Pricing', 1),
#  ('Upcoming courses-Upcoming courses-Upcoming courses', 1),
#  ('Pricing-Other-Pricing', 1),
#  ('Success stories-Homepage-Pricing', 1),
#  ('Sign up-Sign up-Other', 1),
#  ('Sign up-Other-Sign up', 1),
#  ('Sign up-Course certificate-Log in', 1),
#  ('Blog-Log in-Log in', 1),
#  ('Upcoming courses-Course certificate-Upcoming courses', 1),
#  ('Log in-Log in-Pricing', 1),
#  ('Course certificate-Homepage-Pricing', 1),
#  ('Upcoming courses-Resources center-Upcoming courses', 1),
#  ('Resources center-Upcoming courses-Success stories', 1),
#  ('Resources center-About us-About us', 1),
#  ('Course certificate-Course certificate-Other', 1),
#  ('Pricing-Checkout-Success stories', 1),
#  ('Checkout-Success stories-Success stories', 1),
#  ('Other-Career track certificate-Other', 1),
#  ('Pricing-Homepage-Career tracks', 1),
#  ('Other-Homepage-Pricing', 1),
#  ('Pricing-Course certificate-Pricing', 1),
#  ('Course certificate-Pricing-Course certificate', 1),
#  ('Course certificate-Career track certificate-Sign up', 1),
#  ('Sign up-Career track certificate-Log in', 1),
#  ('Career track certificate-Career tracks-Courses', 1),
#  ('Success stories-Success stories-Courses', 1),
#  ('Success stories-Courses-Courses', 1),
#  ('Course certificate-Homepage-Course certificate', 1),
#  ('Other-Course certificate-Other', 1),
#  ('Course certificate-Other-Courses', 1),
#  ('Courses-Log in-Courses', 1),
#  ('Log in-Homepage-Sign up', 1),
#  ('Log in-Other-Homepage', 1),
#  ('Resources center-Other-Sign up', 1),
#  ('Career track certificate-Resources center-Career track certificate', 1),
#  ('Career tracks-Courses-Homepage', 1),
#  ('Instructors-Instructors-Other', 1),
#  ('Other-Upcoming courses-Career tracks', 1),
#  ('Blog-Blog-Homepage', 1),
#  ('Courses-Career tracks-Success stories', 1),
#  ('Career tracks-Success stories-Homepage', 1),
#  ('Checkout-Courses-Course certificate', 1),
#  ('Sign up-Career tracks-Course certificate', 1),
#  ('Sign up-Log in-Other', 1),
#  ('Other-Resources center-Log in', 1),
#  ('Other-Log in-Other', 1),
#  ('Pricing-Homepage-Sign up', 1),
#  ('Instructors-Log in-Log in', 1),
#  ('Pricing-Homepage-Courses', 1),
#  ('Other-Log in-Sign up', 1),
#  ('Career track certificate-Pricing-Career track certificate', 1),
#  ('Homepage-Pricing-Upcoming courses', 1),
#  ('Career tracks-Homepage-Pricing', 1),
#  ('Checkout-Homepage-Courses', 1),
#  ('Course certificate-Courses-Course certificate', 1),
#  ('Checkout-Homepage-Checkout', 1),
#  ('Homepage-Checkout-Homepage', 1),
#  ('Log in-Resources center-Resources center', 1),
#  ('Course certificate-Homepage-Homepage', 1),
#  ('About us-Sign up-Sign up', 1),
#  ('About us-Resources center-Resources center', 1),
#  ('Courses-Homepage-Log in', 1),
#  ('Pricing-Checkout-Sign up', 1),
#  ('Checkout-Sign up-Pricing', 1),
#  ('Log in-Homepage-Career track certificate', 1),
#  ('Career track certificate-Homepage-Log in', 1),
#  ('Career track certificate-Homepage-Course certificate', 1),
#  ('About us-About us-Pricing', 1),
#  ('Sign up-Courses-Course certificate', 1),
#  ('Resources center-About us-Resources center', 1),
#  ('About us-Resources center-Other', 1),
#  ('Career tracks-Sign up-Career track certificate', 1),
#  ('Career tracks-Homepage-Resources center', 1),
#  ('Homepage-Instructors-Other', 1),
#  ('Homepage-Pricing-Other', 1),
#  ('Course certificate-Homepage-Upcoming courses', 1),
#  ('Courses-Homepage-Resources center', 1),
#  ('Homepage-Sign up-Checkout', 1),
#  ('Sign up-Checkout-Homepage', 1),
#  ('Coupon-Homepage-Course certificate', 1),
#  ('Upcoming courses-Upcoming courses-Homepage', 1),
#  ('Upcoming courses-Homepage-Homepage', 1),
#  ('Instructors-Instructors-Pricing', 1),
#  ('Career tracks-Pricing-Career track certificate', 1),
#  ('Resources center-Resources center-Instructors', 1),
#  ('Career track certificate-Career track certificate-Coupon', 1),
#  ('Career track certificate-Coupon-Coupon', 1),
#  ('Career tracks-Career track certificate-Pricing', 1),
#  ('Pricing-Career track certificate-Courses', 1),
#  ('Other-Other-Blog', 1),
#  ('Coupon-Homepage-Career track certificate', 1),
#  ('Courses-Courses-Blog', 1),
#  ('Sign up-Courses-Homepage', 1),
#  ('Career track certificate-Career track certificate-About us', 1),
#  ('About us-Career track certificate-Career track certificate', 1),
#  ('Upcoming courses-Upcoming courses-About us', 1),
#  ('Upcoming courses-About us-About us', 1),
#  ('About us-About us-Instructors', 1),
#  ('About us-Instructors-Instructors', 1),
#  ('Instructors-Instructors-Career track certificate', 1),
#  ('Career track certificate-Homepage-Career track certificate', 1),
#  ('Course certificate-Career track certificate-Course certificate', 1),
#  ('Career track certificate-Course certificate-Career track certificate', 1),
#  ('Homepage-Blog-Homepage', 1),
#  ('Blog-Homepage-Success stories', 1),
#  ('Success stories-Success stories-Blog', 1),
#  ('Sign up-Courses-Career track certificate', 1),
#  ('Sign up-Pricing-Log in', 1),
#  ('Courses-Homepage-Pricing', 1),
#  ('Courses-Homepage-Career track certificate', 1),
#  ('Career track certificate-Career track certificate-Instructors', 1),
#  ('Instructors-Instructors-About us', 1),
#  ('About us-About us-About us', 1),
#  ('About us-Courses-Courses', 1),
#  ('Courses-Career track certificate-Career tracks', 1),
#  ('Courses-Pricing-Sign up', 1),
#  ('Sign up-Sign up-Course certificate', 1),
#  ('Career track certificate-Sign up-Course certificate', 1),
#  ('Resources center-Homepage-Career track certificate', 1),
#  ('Career tracks-Courses-Career track certificate', 1),
#  ('Upcoming courses-Career tracks-Upcoming courses', 1),
#  ('Checkout-Homepage-Sign up', 1),
#  ('Courses-Career tracks-Pricing', 1),
#  ('Career tracks-Success stories-Career tracks', 1),
#  ('Success stories-Career tracks-Success stories', 1),
#  ('Success stories-Resources center-Success stories', 1),
#  ('Career track certificate-Sign up-Pricing', 1),
#  ('About us-Upcoming courses-Upcoming courses', 1),
#  ('Sign up-Homepage-Resources center', 1),
#  ('Resources center-Homepage-Log in', 1),
#  ('Homepage-Career tracks-Sign up', 1),
#  ('Courses-Upcoming courses-Sign up', 1),
#  ('Upcoming courses-Sign up-Sign up', 1),
#  ('Career tracks-Courses-Sign up', 1),
#  ('Instructors-Pricing-Instructors', 1),
#  ('Pricing-Instructors-Courses', 1),
#  ('Career tracks-Log in-Career tracks', 1),
#  ('Log in-Career tracks-Sign up', 1),
#  ('About us-About us-Success stories', 1),
#  ('About us-Success stories-Success stories', 1),
#  ('Homepage-Homepage-Coupon', 1),
#  ('Homepage-Coupon-Coupon', 1),
#  ('Blog-Courses-Courses', 1),
#  ('Courses-Upcoming courses-Success stories', 1),
#  ('Blog-Blog-Pricing', 1),
#  ('Pricing-Resources center-Pricing', 1),
#  ('Resources center-Pricing-Resources center', 1),
#  ('Other-Resources center-Success stories', 1),
#  ('Success stories-Success stories-About us', 1),
#  ('Success stories-About us-About us', 1),
#  ('About us-About us-Homepage', 1),
#  ('Sign up-Career track certificate-Sign up', 1),
#  ('Pricing-Sign up-Homepage', 1),
#  ('Career track certificate-Sign up-Courses', 1),
#  ('Other-Career tracks-Instructors', 1),
#  ('Career tracks-Instructors-Instructors', 1),
#  ('Homepage-Upcoming courses-Homepage', 1),
#  ('Upcoming courses-Homepage-Upcoming courses', 1)]

# %%
page_sequences(data,4)
# Out:
# [('Checkout-Checkout-Checkout-Checkout', 12560),
#  ('Coupon-Coupon-Coupon-Coupon', 8960),
#  ('Log in-Log in-Log in-Log in', 7534),
#  ('Courses-Courses-Courses-Courses', 4245),
#  ('Sign up-Sign up-Sign up-Sign up', 3770),
#  ('Other-Other-Other-Other', 3319),
#  ('Career tracks-Career tracks-Career tracks-Career tracks', 2161),
#  ('Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   1820),
#  ('Resources center-Resources center-Resources center-Resources center', 912),
#  ('Homepage-Log in-Log in-Log in', 818),
#  ('Course certificate-Course certificate-Course certificate-Course certificate',
#   552),
#  ('Success stories-Success stories-Success stories-Success stories', 464),
#  ('Homepage-Homepage-Homepage-Homepage', 446),
#  ('Pricing-Pricing-Pricing-Pricing', 348),
#  ('Career tracks-Courses-Courses-Courses', 274),
#  ('Homepage-Career tracks-Career tracks-Career tracks', 264),
#  ('Career tracks-Career tracks-Career tracks-Courses', 250),
#  ('Career tracks-Career tracks-Courses-Courses', 243),
#  ('Resources center-Resources center-Resources center-Other', 237),
#  ('Other-Resources center-Resources center-Resources center', 217),
#  ('Homepage-Courses-Courses-Courses', 199),
#  ('Homepage-Sign up-Sign up-Sign up', 190),
#  ('Sign up-Sign up-Log in-Log in', 184),
#  ('Resources center-Other-Resources center-Resources center', 183),
#  ('Courses-Career tracks-Career tracks-Career tracks', 181),
#  ('Sign up-Log in-Log in-Log in', 178),
#  ('Courses-Courses-Courses-Career tracks', 176),
#  ('Resources center-Resources center-Other-Resources center', 176),
#  ('Courses-Courses-Career tracks-Career tracks', 174),
#  ('Courses-Sign up-Sign up-Sign up', 129),
#  ('Career track certificate-Career track certificate-Career track certificate-Career tracks',
#   127),
#  ('Career track certificate-Career tracks-Career tracks-Career tracks', 127),
#  ('Career track certificate-Career track certificate-Career tracks-Career tracks',
#   116),
#  ('Career tracks-Sign up-Sign up-Sign up', 110),
#  ('Pricing-Checkout-Checkout-Checkout', 105),
#  ('Courses-Courses-Courses-Sign up', 104),
#  ('Homepage-Homepage-Homepage-Career tracks', 103),
#  ('Homepage-Pricing-Pricing-Checkout', 98),
#  ('Homepage-Homepage-Career tracks-Career tracks', 97),
#  ('Homepage-Pricing-Pricing-Pricing', 97),
#  ('Career tracks-Career tracks-Career tracks-Sign up', 96),
#  ('Pricing-Sign up-Sign up-Sign up', 94),
#  ('Courses-Courses-Sign up-Sign up', 93),
#  ('Homepage-Career track certificate-Career track certificate-Career track certificate',
#   92),
#  ('Career tracks-Career tracks-Sign up-Sign up', 90),
#  ('Log in-Log in-Log in-Other', 79),
#  ('Sign up-Sign up-Sign up-Log in', 79),
#  ('Pricing-Courses-Courses-Courses', 79),
#  ('Log in-Sign up-Sign up-Sign up', 76),
#  ('Pricing-Log in-Log in-Log in', 67),
#  ('Pricing-Pricing-Sign up-Sign up', 66),
#  ('Career tracks-Career tracks-Career tracks-Homepage', 64),
#  ('Log in-Log in-Sign up-Sign up', 63),
#  ('Pricing-Pricing-Checkout-Checkout', 61),
#  ('Other-Log in-Log in-Log in', 60),
#  ('Pricing-Pricing-Courses-Courses', 60),
#  ('Career tracks-Career track certificate-Career track certificate-Career track certificate',
#   51),
#  ('Career tracks-Career tracks-Career tracks-Career track certificate', 51),
#  ('Career tracks-Career tracks-Homepage-Homepage', 50),
#  ('Pricing-Career track certificate-Career track certificate-Career track certificate',
#   50),
#  ('Career tracks-Career tracks-Career tracks-Pricing', 49),
#  ('Homepage-Sign up-Sign up-Log in', 49),
#  ('Career tracks-Homepage-Homepage-Homepage', 48),
#  ('Pricing-Pricing-Checkout-Pricing', 47),
#  ('Homepage-Course certificate-Course certificate-Course certificate', 46),
#  ('Courses-Courses-Courses-Pricing', 46),
#  ('Resources center-Resources center-Other-Other', 45),
#  ('Career tracks-Career tracks-Career track certificate-Career track certificate',
#   43),
#  ('Career tracks-Career tracks-Pricing-Pricing', 43),
#  ('Pricing-Career tracks-Career tracks-Career tracks', 42),
#  ('Courses-Log in-Log in-Log in', 42),
#  ('Log in-Log in-Log in-Sign up', 42),
#  ('Pricing-Pricing-Career track certificate-Career track certificate', 42),
#  ('Course certificate-Course certificate-Career track certificate-Career track certificate',
#   41),
#  ('Homepage-Pricing-Pricing-Sign up', 41),
#  ('Courses-Courses-Pricing-Pricing', 41),
#  ('Homepage-Resources center-Resources center-Resources center', 38),
#  ('Course certificate-Career track certificate-Career track certificate-Career track certificate',
#   38),
#  ('Resources center-Other-Other-Resources center', 38),
#  ('Courses-Courses-Homepage-Homepage', 36),
#  ('Other-Other-Resources center-Resources center', 35),
#  ('Courses-Courses-Courses-Homepage', 34),
#  ('Homepage-Homepage-Homepage-Pricing', 33),
#  ('Courses-Courses-Career tracks-Courses', 33),
#  ('Course certificate-Course certificate-Course certificate-Career track certificate',
#   33),
#  ('Courses-Homepage-Homepage-Homepage', 33),
#  ('Courses-Career track certificate-Career track certificate-Career track certificate',
#   32),
#  ('Career track certificate-Career track certificate-Course certificate-Course certificate',
#   32),
#  ('Pricing-Pricing-Career tracks-Career tracks', 31),
#  ('Homepage-Homepage-Pricing-Pricing', 30),
#  ('Career track certificate-Career track certificate-Career track certificate-Pricing',
#   30),
#  ('Pricing-Pricing-Log in-Log in', 30),
#  ('Courses-Career tracks-Courses-Courses', 30),
#  ('Pricing-Checkout-Pricing-Checkout', 30),
#  ('Course certificate-Course certificate-Courses-Courses', 30),
#  ('Other-Sign up-Sign up-Sign up', 29),
#  ('Courses-Courses-Courses-Career track certificate', 29),
#  ('Courses-Courses-Career track certificate-Career track certificate', 29),
#  ('Career tracks-Homepage-Career tracks-Career tracks', 29),
#  ('Career track certificate-Career track certificate-Career track certificate-Sign up',
#   28),
#  ('Career tracks-Career tracks-Sign up-Career tracks', 28),
#  ('Career track certificate-Career track certificate-Sign up-Sign up', 28),
#  ('Career track certificate-Career track certificate-Courses-Courses', 28),
#  ('Career track certificate-Course certificate-Course certificate-Course certificate',
#   28),
#  ('Career track certificate-Career track certificate-Career track certificate-Course certificate',
#   28),
#  ('Career tracks-Log in-Log in-Log in', 27),
#  ('Course certificate-Course certificate-Course certificate-Courses', 27),
#  ('Pricing-Pricing-Pricing-Courses', 27),
#  ('Career track certificate-Career track certificate-Career track certificate-Courses',
#   27),
#  ('Homepage-Career tracks-Homepage-Career tracks', 26),
#  ('Resources center-Log in-Log in-Log in', 26),
#  ('Other-Other-Log in-Log in', 26),
#  ('Career track certificate-Courses-Courses-Courses', 26),
#  ('Career track certificate-Career track certificate-Pricing-Pricing', 25),
#  ('Course certificate-Courses-Courses-Courses', 25),
#  ('Career track certificate-Sign up-Sign up-Sign up', 25),
#  ('Other-Other-Coupon-Coupon', 24),
#  ('Upcoming courses-Upcoming courses-Courses-Courses', 24),
#  ('Courses-Pricing-Pricing-Pricing', 24),
#  ('Pricing-Pricing-Homepage-Homepage', 24),
#  ('Courses-Courses-Log in-Log in', 24),
#  ('Career tracks-Courses-Career tracks-Career tracks', 23),
#  ('Other-Other-Other-Coupon', 23),
#  ('Upcoming courses-Courses-Courses-Courses', 23),
#  ('Homepage-Career tracks-Career tracks-Sign up', 22),
#  ('Pricing-Pricing-Pricing-Checkout', 22),
#  ('Career tracks-Sign up-Career tracks-Career tracks', 22),
#  ('Pricing-Resources center-Resources center-Resources center', 22),
#  ('Resources center-Courses-Courses-Courses', 21),
#  ('Resources center-Resources center-Courses-Courses', 21),
#  ('Homepage-Homepage-Courses-Courses', 21),
#  ('Other-Courses-Courses-Courses', 21),
#  ('Pricing-Pricing-Resources center-Resources center', 21),
#  ('Instructors-Instructors-Instructors-Instructors', 21),
#  ('Career tracks-Career tracks-Courses-Career tracks', 20),
#  ('Homepage-Pricing-Pricing-Log in', 20),
#  ('Courses-Courses-Courses-Log in', 20),
#  ('Courses-Course certificate-Course certificate-Course certificate', 20),
#  ('Sign up-Homepage-Homepage-Homepage', 19),
#  ('Other-Coupon-Coupon-Coupon', 19),
#  ('Homepage-Pricing-Pricing-Homepage', 19),
#  ('Career tracks-Pricing-Pricing-Pricing', 19),
#  ('Upcoming courses-Career tracks-Career tracks-Career tracks', 18),
#  ('Career tracks-Career track certificate-Career tracks-Career tracks', 17),
#  ('Career track certificate-Career track certificate-Sign up-Career track certificate',
#   17),
#  ('Pricing-Course certificate-Course certificate-Course certificate', 17),
#  ('Pricing-Homepage-Homepage-Homepage', 17),
#  ('Career tracks-Career tracks-Log in-Log in', 17),
#  ('Upcoming courses-Upcoming courses-Career tracks-Career tracks', 17),
#  ('Homepage-Pricing-Pricing-Courses', 17),
#  ('Sign up-Career track certificate-Career track certificate-Career track certificate',
#   17),
#  ('Career track certificate-Resources center-Resources center-Resources center',
#   16),
#  ('Homepage-Homepage-Log in-Log in', 16),
#  ('Courses-Courses-Courses-Upcoming courses', 16),
#  ('Courses-Courses-Upcoming courses-Upcoming courses', 16),
#  ('Career tracks-Career tracks-Career tracks-Log in', 16),
#  ('Courses-Courses-Course certificate-Course certificate', 16),
#  ('Homepage-Homepage-Homepage-Courses', 16),
#  ('Other-Career track certificate-Career track certificate-Career track certificate',
#   16),
#  ('Career tracks-Sign up-Sign up-Log in', 15),
#  ('Courses-Sign up-Sign up-Log in', 15),
#  ('Courses-Courses-Courses-Resources center', 15),
#  ('Pricing-Pricing-Pricing-Career track certificate', 15),
#  ('Sign up-Career tracks-Career tracks-Career tracks', 15),
#  ('Courses-Courses-Courses-Course certificate', 15),
#  ('Pricing-Checkout-Pricing-Pricing', 15),
#  ('Courses-Courses-Resources center-Resources center', 15),
#  ('Career tracks-Career tracks-Upcoming courses-Upcoming courses', 15),
#  ('Career track certificate-Career track certificate-Resources center-Resources center',
#   14),
#  ('Pricing-Pricing-Pricing-Sign up', 14),
#  ('Career track certificate-Career track certificate-Career tracks-Career track certificate',
#   14),
#  ('Homepage-Sign up-Homepage-Homepage', 14),
#  ('Sign up-Courses-Courses-Courses', 14),
#  ('Checkout-Pricing-Checkout-Pricing', 14),
#  ('Resources center-Resources center-Resources center-Courses', 14),
#  ('Resources center-Career track certificate-Career track certificate-Career track certificate',
#   14),
#  ('Course certificate-Course certificate-Sign up-Sign up', 14),
#  ('Career track certificate-Career track certificate-Career track certificate-Resources center',
#   14),
#  ('Log in-Homepage-Log in-Log in', 14),
#  ('Other-Career tracks-Career tracks-Career tracks', 14),
#  ('Log in-Sign up-Sign up-Log in', 14),
#  ('Career tracks-Career tracks-Career tracks-Upcoming courses', 14),
#  ('Career track certificate-Pricing-Pricing-Pricing', 13),
#  ('Homepage-Pricing-Pricing-Career tracks', 13),
#  ('Career tracks-Career tracks-Homepage-Career tracks', 13),
#  ('Log in-Log in-Other-Log in', 13),
#  ('Log in-Other-Log in-Log in', 13),
#  ('Homepage-Homepage-Career track certificate-Career track certificate', 13),
#  ('Other-Other-Pricing-Pricing', 13),
#  ('Other-Pricing-Pricing-Pricing', 13),
#  ('Career tracks-Career tracks-Career tracks-Resources center', 13),
#  ('Pricing-Pricing-Pricing-Resources center', 13),
#  ('Courses-Pricing-Pricing-Checkout', 13),
#  ('Pricing-Pricing-Pricing-Career tracks', 13),
#  ('Pricing-Checkout-Checkout-Homepage', 13),
#  ('Homepage-Homepage-Homepage-Instructors', 13),
#  ('Homepage-Homepage-Instructors-Homepage', 13),
#  ('Career tracks-Career tracks-Career track certificate-Career tracks', 12),
#  ('Career tracks-Courses-Courses-Sign up', 12),
#  ('Checkout-Pricing-Checkout-Checkout', 12),
#  ('Course certificate-Course certificate-Career tracks-Career tracks', 12),
#  ('Career tracks-Career tracks-Resources center-Resources center', 12),
#  ('Resources center-Resources center-Course certificate-Course certificate',
#   12),
#  ('Courses-Courses-Sign up-Courses', 12),
#  ('Other-Success stories-Success stories-Success stories', 12),
#  ('Homepage-Instructors-Homepage-Homepage', 12),
#  ('Instructors-Homepage-Homepage-Homepage', 12),
#  ('Homepage-Homepage-Career tracks-Homepage', 11),
#  ('Homepage-Homepage-Homepage-Career track certificate', 11),
#  ('Resources center-Career tracks-Career tracks-Career tracks', 11),
#  ('Career track certificate-Career track certificate-Log in-Log in', 11),
#  ('Career track certificate-Log in-Log in-Log in', 11),
#  ('Resources center-Resources center-Career track certificate-Career track certificate',
#   11),
#  ('Course certificate-Course certificate-Course certificate-Sign up', 11),
#  ('Course certificate-Course certificate-Course certificate-Upcoming courses',
#   11),
#  ('Homepage-Homepage-Resources center-Resources center', 11),
#  ('Resources center-Course certificate-Course certificate-Course certificate',
#   11),
#  ('Homepage-Log in-Homepage-Log in', 11),
#  ('Career track certificate-Sign up-Career track certificate-Career track certificate',
#   11),
#  ('Course certificate-Course certificate-Pricing-Pricing', 11),
#  ('Pricing-Pricing-Course certificate-Course certificate', 11),
#  ('Resources center-Resources center-Career tracks-Career tracks', 11),
#  ('Homepage-Courses-Courses-Career tracks', 11),
#  ('Course certificate-Sign up-Sign up-Sign up', 11),
#  ('Homepage-Career tracks-Homepage-Homepage', 10),
#  ('Course certificate-Course certificate-Resources center-Resources center',
#   10),
#  ('Resources center-Resources center-Pricing-Pricing', 10),
#  ('Homepage-Homepage-Other-Other', 10),
#  ('Courses-Upcoming courses-Upcoming courses-Courses', 10),
#  ('Other-Other-Other-Log in', 10),
#  ('Other-Course certificate-Course certificate-Course certificate', 10),
#  ('Course certificate-Course certificate-Course certificate-Career tracks',
#   10),
#  ('Course certificate-Career tracks-Career tracks-Career tracks', 10),
#  ('Courses-Resources center-Resources center-Resources center', 10),
#  ('Homepage-Homepage-Homepage-Resources center', 10),
#  ('Homepage-Homepage-Sign up-Sign up', 10),
#  ('Homepage-Pricing-Pricing-Career track certificate', 10),
#  ('Course certificate-Course certificate-Course certificate-Pricing', 10),
#  ('Checkout-Checkout-Homepage-Homepage', 10),
#  ('Career tracks-Homepage-Career tracks-Homepage', 9),
#  ('Homepage-Other-Other-Other', 9),
#  ('Course certificate-Course certificate-Course certificate-Resources center',
#   9),
#  ('Career track certificate-Career tracks-Career track certificate-Career track certificate',
#   9),
#  ('Homepage-Sign up-Homepage-Pricing', 9),
#  ('Resources center-Resources center-Homepage-Homepage', 9),
#  ('Resources center-Resources center-Resources center-Log in', 9),
#  ('Resources center-Resources center-Log in-Log in', 9),
#  ('Career tracks-Pricing-Pricing-Checkout', 9),
#  ('Career track certificate-Career track certificate-Career track certificate-Log in',
#   9),
#  ('Career tracks-Course certificate-Course certificate-Course certificate', 9),
#  ('Checkout-Checkout-Checkout-Homepage', 9),
#  ('Homepage-Homepage-Homepage-Other', 9),
#  ('Career tracks-Resources center-Resources center-Resources center', 9),
#  ('Resources center-Resources center-Resources center-Course certificate', 9),
#  ('Courses-Sign up-Courses-Courses', 9),
#  ('Log in-Log in-Log in-Homepage', 9),
#  ('Checkout-Pricing-Pricing-Pricing', 9),
#  ('Sign up-Homepage-Pricing-Pricing', 8),
#  ('Pricing-Pricing-Pricing-Homepage', 8),
#  ('Checkout-Checkout-Checkout-Pricing', 8),
#  ('Upcoming courses-Upcoming courses-Resources center-Resources center', 8),
#  ('Career track certificate-Career tracks-Career tracks-Sign up', 8),
#  ('Career tracks-Career tracks-Course certificate-Course certificate', 8),
#  ('Homepage-Homepage-Homepage-Log in', 8),
#  ('Other-Resources center-Resources center-Other', 8),
#  ('Homepage-Pricing-Homepage-Pricing', 8),
#  ('Homepage-Career tracks-Career tracks-Pricing', 8),
#  ('Homepage-Homepage-Homepage-Sign up', 8),
#  ('Log in-Log in-Other-Other', 8),
#  ('Pricing-Pricing-Upcoming courses-Upcoming courses', 8),
#  ('Career tracks-Pricing-Pricing-Sign up', 8),
#  ('Other-Other-Success stories-Success stories', 8),
#  ('Courses-Pricing-Pricing-Courses', 8),
#  ('Career track certificate-Career tracks-Career track certificate-Career tracks',
#   8),
#  ('Resources center-Resources center-Resources center-Pricing', 7),
#  ('Resources center-Resources center-Resources center-Homepage', 7),
#  ('Career track certificate-Pricing-Pricing-Checkout', 7),
#  ('Pricing-Pricing-Sign up-Pricing', 7),
#  ('Career tracks-Career tracks-Career tracks-Course certificate', 7),
#  ('Other-Other-Homepage-Homepage', 7),
#  ('Course certificate-Log in-Log in-Log in', 7),
#  ('Coupon-Coupon-Coupon-Homepage', 7),
#  ('Resources center-Pricing-Pricing-Pricing', 7),
#  ('Other-Sign up-Sign up-Log in', 7),
#  ('Homepage-Log in-Log in-Sign up', 7),
#  ('Other-Pricing-Pricing-Sign up', 7),
#  ('Log in-Log in-Homepage-Log in', 7),
#  ('Sign up-Sign up-Homepage-Homepage', 7),
#  ('Homepage-Career track certificate-Career track certificate-Sign up', 7),
#  ('Upcoming courses-Upcoming courses-Career track certificate-Career track certificate',
#   7),
#  ('Upcoming courses-Career track certificate-Career track certificate-Career track certificate',
#   7),
#  ('Instructors-Courses-Courses-Courses', 7),
#  ('Pricing-Pricing-Pricing-Log in', 6),
#  ('Career tracks-Career tracks-Pricing-Career tracks', 6),
#  ('Pricing-Checkout-Pricing-Courses', 6),
#  ('Checkout-Pricing-Courses-Courses', 6),
#  ('Career tracks-Pricing-Career tracks-Career tracks', 6),
#  ('Course certificate-Resources center-Resources center-Resources center', 6),
#  ('Courses-Career tracks-Courses-Career tracks', 6),
#  ('Sign up-Homepage-Log in-Log in', 6),
#  ('Resources center-Homepage-Homepage-Homepage', 6),
#  ('Other-Other-Courses-Courses', 6),
#  ('Sign up-Sign up-Pricing-Pricing', 6),
#  ('Other-Other-Sign up-Sign up', 6),
#  ('Upcoming courses-Resources center-Resources center-Resources center', 6),
#  ('Checkout-Checkout-Homepage-Log in', 6),
#  ('Checkout-Homepage-Log in-Log in', 6),
#  ('Other-Pricing-Pricing-Checkout', 6),
#  ('Career tracks-Courses-Courses-Career tracks', 6),
#  ('Pricing-Courses-Courses-Career tracks', 6),
#  ('Other-Other-Career tracks-Career tracks', 6),
#  ('Sign up-Log in-Log in-Sign up', 6),
#  ('Upcoming courses-Course certificate-Course certificate-Course certificate',
#   6),
#  ('Course certificate-Course certificate-Course certificate-Log in', 6),
#  ('Course certificate-Course certificate-Log in-Log in', 6),
#  ('Sign up-Sign up-Career track certificate-Career track certificate', 6),
#  ('Pricing-Homepage-Pricing-Pricing', 6),
#  ('Homepage-Instructors-Homepage-Instructors', 6),
#  ('Career tracks-Career tracks-Career tracks-Other', 6),
#  ('Courses-Pricing-Pricing-Sign up', 6),
#  ('Other-Other-Other-Pricing', 6),
#  ('Homepage-Courses-Courses-Homepage', 6),
#  ('Resources center-Resources center-Resources center-Career tracks', 6),
#  ('Course certificate-Course certificate-Upcoming courses-Upcoming courses',
#   6),
#  ('Homepage-Courses-Courses-Pricing', 5),
#  ('Career tracks-Courses-Career tracks-Courses', 5),
#  ('Pricing-Pricing-Other-Other', 5),
#  ('Resources center-Other-Other-Sign up', 5),
#  ('Sign up-Homepage-Career tracks-Career tracks', 5),
#  ('Course certificate-Course certificate-Sign up-Course certificate', 5),
#  ('Pricing-Homepage-Homepage-Courses', 5),
#  ('Courses-Pricing-Courses-Courses', 5),
#  ('Pricing-Other-Other-Other', 5),
#  ('Homepage-Pricing-Pricing-Resources center', 5),
#  ('Homepage-Pricing-Pricing-Course certificate', 5),
#  ('Courses-Sign up-Courses-Pricing', 5),
#  ('Course certificate-Pricing-Pricing-Pricing', 5),
#  ('Pricing-Pricing-Pricing-Course certificate', 5),
#  ('Homepage-Course certificate-Course certificate-Career track certificate',
#   5),
#  ('Log in-Other-Other-Homepage', 5),
#  ('Career track certificate-Career tracks-Career tracks-Courses', 5),
#  ('Sign up-Sign up-Sign up-Homepage', 5),
#  ('Pricing-Checkout-Pricing-Sign up', 5),
#  ('Career tracks-Career tracks-Other-Other', 5),
#  ('Career tracks-Pricing-Pricing-Career tracks', 5),
#  ('Courses-Career tracks-Career tracks-Upcoming courses', 5),
#  ('Homepage-Course certificate-Course certificate-Sign up', 5),
#  ('Courses-Career tracks-Career tracks-Sign up', 5),
#  ('Career track certificate-Sign up-Sign up-Log in', 5),
#  ('Courses-Success stories-Success stories-Success stories', 5),
#  ('Career tracks-Upcoming courses-Upcoming courses-Courses', 5),
#  ('Career tracks-Upcoming courses-Upcoming courses-Career tracks', 5),
#  ('Success stories-Success stories-Success stories-Resources center', 5),
#  ('Pricing-Sign up-Sign up-Log in', 4),
#  ('Pricing-Sign up-Pricing-Sign up', 4),
#  ('Sign up-Pricing-Sign up-Sign up', 4),
#  ('Homepage-Success stories-Success stories-Success stories', 4),
#  ('Pricing-Upcoming courses-Upcoming courses-Courses', 4),
#  ('Homepage-Sign up-Homepage-Log in', 4),
#  ('Sign up-Sign up-Courses-Courses', 4),
#  ('Checkout-Checkout-Pricing-Checkout', 4),
#  ('Resources center-Resources center-Resources center-Career track certificate',
#   4),
#  ('Courses-Sign up-Log in-Log in', 4),
#  ('Sign up-Pricing-Pricing-Checkout', 4),
#  ('Homepage-Courses-Courses-Log in', 4),
#  ('Homepage-Career track certificate-Career track certificate-Log in', 4),
#  ('Resources center-Other-Other-Log in', 4),
#  ('Homepage-Homepage-Sign up-Homepage', 4),
#  ('Homepage-Sign up-Homepage-Career tracks', 4),
#  ('Other-Homepage-Homepage-Homepage', 4),
#  ('Pricing-Success stories-Success stories-Success stories', 4),
#  ('Blog-Blog-Other-Other', 4),
#  ('Course certificate-Course certificate-Upcoming courses-Course certificate',
#   4),
#  ('Success stories-Career track certificate-Career track certificate-Career track certificate',
#   4),
#  ('Career tracks-Career tracks-Career tracks-Success stories', 4),
#  ('Career tracks-Success stories-Success stories-Success stories', 4),
#  ('Homepage-Career tracks-Career tracks-Courses', 4),
#  ('Career track certificate-Pricing-Pricing-Career track certificate', 4),
#  ('Courses-Career track certificate-Career track certificate-Sign up', 4),
#  ('Pricing-Courses-Courses-Sign up', 4),
#  ('Sign up-Courses-Pricing-Pricing', 4),
#  ('Courses-Career tracks-Career tracks-Courses', 4),
#  ('Checkout-Homepage-Homepage-Homepage', 4),
#  ('Homepage-Homepage-Course certificate-Course certificate', 4),
#  ('Homepage-Sign up-Homepage-Courses', 4),
#  ('Sign up-Homepage-Courses-Courses', 4),
#  ('Courses-Pricing-Pricing-Career track certificate', 4),
#  ('Log in-Log in-Other-Sign up', 4),
#  ('Log in-Other-Sign up-Sign up', 4),
#  ('Checkout-Pricing-Sign up-Sign up', 4),
#  ('Courses-Career tracks-Career tracks-Career track certificate', 4),
#  ('Checkout-Pricing-Log in-Log in', 4),
#  ('Homepage-Sign up-Sign up-Pricing', 4),
#  ('Resources center-Sign up-Sign up-Sign up', 4),
#  ('Career tracks-Sign up-Career tracks-Pricing', 4),
#  ('Pricing-Career tracks-Career tracks-Sign up', 4),
#  ('Pricing-Checkout-Pricing-Career track certificate', 4),
#  ('Checkout-Pricing-Career track certificate-Career track certificate', 4),
#  ('Course certificate-Career track certificate-Career track certificate-Sign up',
#   4),
#  ('Career track certificate-Career track certificate-Homepage-Homepage', 4),
#  ('Career track certificate-Homepage-Homepage-Homepage', 4),
#  ('Career track certificate-Sign up-Career track certificate-Pricing', 4),
#  ('Resources center-Resources center-Upcoming courses-Upcoming courses', 4),
#  ('Courses-Log in-Log in-Sign up', 4),
#  ('Resources center-Pricing-Pricing-Checkout', 4),
#  ('Homepage-Pricing-Homepage-Homepage', 4),
#  ('Career tracks-Career tracks-Homepage-Sign up', 3),
#  ('Other-Other-Other-Homepage', 3),
#  ('Success stories-Success stories-Success stories-Pricing', 3),
#  ('Success stories-Success stories-Pricing-Pricing', 3),
#  ('Homepage-Sign up-Homepage-Course certificate', 3),
#  ('Sign up-Homepage-Course certificate-Course certificate', 3),
#  ('Sign up-Pricing-Pricing-Sign up', 3),
#  ('Sign up-Sign up-Sign up-Courses', 3),
#  ('Resources center-Resources center-Resources center-Sign up', 3),
#  ('Other-Pricing-Pricing-Log in', 3),
#  ('Log in-Courses-Courses-Courses', 3),
#  ('Homepage-Course certificate-Course certificate-Courses', 3),
#  ('Sign up-Pricing-Courses-Courses', 3),
#  ('Career tracks-Pricing-Pricing-Log in', 3),
#  ('Resources center-Other-Other-Other', 3),
#  ('Pricing-Homepage-Homepage-Sign up', 3),
#  ('Homepage-Other-Other-Homepage', 3),
#  ('Pricing-Pricing-Success stories-Success stories', 3),
#  ('Success stories-Success stories-Success stories-Homepage', 3),
#  ('Career track certificate-Career track certificate-Career track certificate-Upcoming courses',
#   3),
#  ('Homepage-Resources center-Resources center-Courses', 3),
#  ('Upcoming courses-Upcoming courses-Pricing-Pricing', 3),
#  ('Log in-Career tracks-Career tracks-Career tracks', 3),
#  ('Course certificate-Course certificate-Course certificate-Homepage', 3),
#  ('Courses-Upcoming courses-Upcoming courses-Resources center', 3),
#  ('Success stories-Success stories-Success stories-Career track certificate',
#   3),
#  ('Success stories-Success stories-Career track certificate-Career track certificate',
#   3),
#  ('Career tracks-Pricing-Pricing-Homepage', 3),
#  ('Courses-Career tracks-Career tracks-Homepage', 3),
#  ('Courses-Courses-Pricing-Courses', 3),
#  ('Courses-Courses-Courses-Other', 3),
#  ('Courses-Courses-Other-Other', 3),
#  ('Career track certificate-Career track certificate-Upcoming courses-Upcoming courses',
#   3),
#  ('Career track certificate-Pricing-Pricing-Courses', 3),
#  ('Resources center-Other-Other-Pricing', 3),
#  ('Coupon-Coupon-Homepage-Sign up', 3),
#  ('Log in-Other-Other-Sign up', 3),
#  ('Pricing-Checkout-Pricing-Career tracks', 3),
#  ('Checkout-Pricing-Career tracks-Career tracks', 3),
#  ('Other-Pricing-Pricing-Career track certificate', 3),
#  ('Resources center-Success stories-Success stories-Success stories', 3),
#  ('Log in-Log in-Homepage-Homepage', 3),
#  ('Course certificate-Upcoming courses-Course certificate-Course certificate',
#   3),
#  ('Pricing-Pricing-Pricing-Upcoming courses', 3),
#  ('Pricing-Upcoming courses-Upcoming courses-Career tracks', 3),
#  ('Career track certificate-Courses-Courses-Career tracks', 3),
#  ('Log in-Homepage-Log in-Homepage', 3),
#  ('Homepage-Homepage-Homepage-Course certificate', 3),
#  ('Course certificate-Pricing-Pricing-Checkout', 3),
#  ('Other-Homepage-Homepage-Log in', 3),
#  ('Homepage-Courses-Homepage-Homepage', 3),
#  ('Sign up-Log in-Sign up-Log in', 3),
#  ('Pricing-Pricing-Pricing-Other', 3),
#  ('Resources center-Other-Other-Success stories', 3),
#  ('Checkout-Homepage-Homepage-Sign up', 3),
#  ('Upcoming courses-Other-Other-Other', 3),
#  ('Career tracks-Other-Other-Other', 3),
#  ('Pricing-Pricing-Checkout-Courses', 3),
#  ('Homepage-Courses-Courses-Sign up', 3),
#  ('Courses-Courses-Sign up-Homepage', 3),
#  ('Career track certificate-Pricing-Pricing-Sign up', 3),
#  ('Career tracks-Career track certificate-Career track certificate-Career tracks',
#   3),
#  ('Courses-Courses-Upcoming courses-Courses', 3),
#  ('Course certificate-Pricing-Pricing-Courses', 3),
#  ('Sign up-Career tracks-Pricing-Pricing', 3),
#  ('Career tracks-Pricing-Pricing-Career track certificate', 3),
#  ('Pricing-Sign up-Pricing-Pricing', 3),
#  ('Career tracks-Sign up-Career tracks-Career track certificate', 3),
#  ('Sign up-Career tracks-Career track certificate-Career track certificate',
#   3),
#  ('Upcoming courses-Courses-Courses-Career tracks', 3),
#  ('Career track certificate-Career track certificate-Career track certificate-Homepage',
#   3),
#  ('Instructors-Homepage-Instructors-Homepage', 3),
#  ('Homepage-Sign up-Homepage-Career track certificate', 3),
#  ('Sign up-Homepage-Career track certificate-Career track certificate', 3),
#  ('Courses-Courses-Courses-Success stories', 3),
#  ('Courses-Courses-Success stories-Success stories', 3),
#  ('Success stories-Success stories-Success stories-Sign up', 3),
#  ('Coupon-Coupon-Homepage-Homepage', 3),
#  ('Homepage-Sign up-Sign up-Career track certificate', 3),
#  ('Career track certificate-Sign up-Career track certificate-Career tracks',
#   3),
#  ('Sign up-Career track certificate-Career tracks-Career tracks', 3),
#  ('Sign up-Career track certificate-Pricing-Pricing', 3),
#  ('Course certificate-Sign up-Course certificate-Pricing', 3),
#  ('Sign up-Course certificate-Pricing-Pricing', 3),
#  ('Career track certificate-Success stories-Success stories-Success stories',
#   3),
#  ('Log in-Homepage-Homepage-Homepage', 3),
#  ('Homepage-Other-Other-Success stories', 3),
#  ('Success stories-Career tracks-Career tracks-Career tracks', 3),
#  ('Upcoming courses-Upcoming courses-Other-Other', 3),
#  ('Success stories-Success stories-Success stories-Other', 3),
#  ('Career tracks-Upcoming courses-Upcoming courses-Career track certificate',
#   3),
#  ('Other-Blog-Other-Blog', 3),
#  ('Career track certificate-Sign up-Career track certificate-Courses', 3),
#  ('Sign up-Career track certificate-Courses-Courses', 3),
#  ('Career tracks-Career track certificate-Career tracks-Career track certificate',
#   3),
#  ('Success stories-Success stories-Resources center-Resources center', 3),
#  ('Success stories-Resources center-Resources center-Resources center', 3),
#  ('Upcoming courses-Upcoming courses-Course certificate-Course certificate',
#   3),
#  ('Career tracks-Homepage-Homepage-Career tracks', 2),
#  ('Homepage-Instructors-Instructors-Homepage', 2),
#  ('Instructors-Instructors-Homepage-Homepage', 2),
#  ('Pricing-Sign up-Pricing-Checkout', 2),
#  ('Other-Other-Homepage-Log in', 2),
#  ('Other-Homepage-Log in-Log in', 2),
#  ('Pricing-Checkout-Pricing-Upcoming courses', 2),
#  ('Other-Pricing-Pricing-Career tracks', 2),
#  ('Other-Courses-Courses-Sign up', 2),
#  ('Upcoming courses-Log in-Log in-Log in', 2),
#  ('Upcoming courses-Pricing-Pricing-Pricing', 2),
#  ('Log in-Log in-Log in-Courses', 2),
#  ('Log in-Log in-Courses-Courses', 2),
#  ('Resources center-Homepage-Homepage-Other', 2),
#  ('Homepage-Other-Other-Pricing', 2),
#  ('Pricing-Sign up-Pricing-Courses', 2),
#  ('Other-Other-Resources center-Other', 2),
#  ('Career track certificate-Course certificate-Course certificate-Sign up', 2),
#  ('Course certificate-Sign up-Sign up-Log in', 2),
#  ('Pricing-Pricing-Pricing-Blog', 2),
#  ('Pricing-Pricing-Blog-Blog', 2),
#  ('Course certificate-Upcoming courses-Upcoming courses-Career tracks', 2),
#  ('Checkout-Pricing-Course certificate-Course certificate', 2),
#  ('Log in-Pricing-Pricing-Pricing', 2),
#  ('Homepage-Upcoming courses-Upcoming courses-Pricing', 2),
#  ('Upcoming courses-Pricing-Pricing-Checkout', 2),
#  ('Coupon-Coupon-Homepage-Log in', 2),
#  ('Upcoming courses-Success stories-Success stories-Success stories', 2),
#  ('Resources center-Resources center-Resources center-About us', 2),
#  ('About us-About us-Other-Other', 2),
#  ('About us-Other-Other-Other', 2),
#  ('Career tracks-Career tracks-Success stories-Success stories', 2),
#  ('Success stories-Success stories-Homepage-Homepage', 2),
#  ('Success stories-Homepage-Homepage-Homepage', 2),
#  ('Pricing-Checkout-Pricing-Other', 2),
#  ('Checkout-Pricing-Other-Other', 2),
#  ('Other-Other-Other-Courses', 2),
#  ('Other-Other-Other-Career tracks', 2),
#  ('Coupon-Homepage-Sign up-Sign up', 2),
#  ('Homepage-Sign up-Log in-Log in', 2),
#  ('Sign up-Career track certificate-Career track certificate-Sign up', 2),
#  ('Resources center-Resources center-Resources center-Success stories', 2),
#  ('Resources center-Resources center-Success stories-Success stories', 2),
#  ('Pricing-Log in-Log in-Sign up', 2),
#  ('Pricing-Checkout-Pricing-Homepage', 2),
#  ('Course certificate-Homepage-Courses-Courses', 2),
#  ('Pricing-Pricing-Checkout-Homepage', 2),
#  ('Pricing-Checkout-Homepage-Homepage', 2),
#  ('Courses-Other-Other-Pricing', 2),
#  ('Courses-Courses-Homepage-Sign up', 2),
#  ('Courses-Homepage-Homepage-Sign up', 2),
#  ('Courses-Homepage-Courses-Homepage', 2),
#  ('Resources center-Upcoming courses-Upcoming courses-Career tracks', 2),
#  ('Sign up-Sign up-Homepage-Log in', 2),
#  ('Courses-Course certificate-Course certificate-Career track certificate', 2),
#  ('Course certificate-Sign up-Sign up-Career track certificate', 2),
#  ('Checkout-Checkout-Pricing-Log in', 2),
#  ('Other-Other-Other-Upcoming courses', 2),
#  ('Sign up-Log in-Sign up-Sign up', 2),
#  ('Homepage-Sign up-Homepage-Sign up', 2),
#  ('Pricing-Career track certificate-Career track certificate-Sign up', 2),
#  ('Homepage-Log in-Homepage-Pricing', 2),
#  ('Courses-Pricing-Pricing-Homepage', 2),
#  ('Coupon-Coupon-Homepage-Pricing', 2),
#  ('Coupon-Homepage-Pricing-Pricing', 2),
#  ('Courses-Homepage-Homepage-Log in', 2),
#  ('Career tracks-Sign up-Career tracks-Log in', 2),
#  ('Sign up-Career tracks-Log in-Log in', 2),
#  ('Courses-Course certificate-Course certificate-Courses', 2),
#  ('Log in-Career track certificate-Career track certificate-Career track certificate',
#   2),
#  ('Homepage-Homepage-Courses-Homepage', 2),
#  ('Pricing-Checkout-Pricing-Log in', 2),
#  ('Courses-Sign up-Courses-Sign up', 2),
#  ('Courses-Pricing-Courses-Pricing', 2),
#  ('Resources center-Upcoming courses-Upcoming courses-Courses', 2),
#  ('Courses-Upcoming courses-Courses-Courses', 2),
#  ('Career tracks-Courses-Courses-Upcoming courses', 2),
#  ('Homepage-Sign up-Sign up-Homepage', 2),
#  ('Sign up-Homepage-Homepage-Pricing', 2),
#  ('Homepage-Upcoming courses-Upcoming courses-Courses', 2),
#  ('Resources center-Resources center-Sign up-Sign up', 2),
#  ('Other-Career tracks-Career tracks-Sign up', 2),
#  ('Other-Career track certificate-Career track certificate-Sign up', 2),
#  ('Other-Courses-Courses-Career tracks', 2),
#  ('Courses-Sign up-Courses-Log in', 2),
#  ('Sign up-Courses-Log in-Log in', 2),
#  ('Courses-Sign up-Courses-Career tracks', 2),
#  ('Sign up-Courses-Career tracks-Career tracks', 2),
#  ('Course certificate-Sign up-Course certificate-Sign up', 2),
#  ('Course certificate-Pricing-Pricing-Career track certificate', 2),
#  ('Career tracks-Career tracks-Homepage-Courses', 2),
#  ('Career tracks-Homepage-Courses-Courses', 2),
#  ('Upcoming courses-Pricing-Pricing-Courses', 2),
#  ('Success stories-Success stories-Success stories-Log in', 2),
#  ('Success stories-Success stories-Log in-Log in', 2),
#  ('Success stories-Log in-Log in-Log in', 2),
#  ('Resources center-Career track certificate-Career track certificate-Sign up',
#   2),
#  ('Course certificate-Courses-Courses-Upcoming courses', 2),
#  ('Career tracks-Upcoming courses-Career tracks-Career tracks', 2),
#  ('Resources center-Resources center-Resources center-Upcoming courses', 2),
#  ('Career tracks-Homepage-Sign up-Homepage', 2),
#  ('Courses-Upcoming courses-Courses-Upcoming courses', 2),
#  ('Course certificate-Resources center-Resources center-Career tracks', 2),
#  ('Career track certificate-Career track certificate-Career track certificate-Success stories',
#   2),
#  ('Career track certificate-Career track certificate-Success stories-Success stories',
#   2),
#  ('Other-Resources center-Resources center-Homepage', 2),
#  ('Pricing-Upcoming courses-Upcoming courses-Resources center', 2),
#  ('Career tracks-Career tracks-Other-Career tracks', 2),
#  ('Checkout-Homepage-Homepage-Log in', 2),
#  ('Career tracks-Sign up-Career tracks-Courses', 2),
#  ('Sign up-Career tracks-Courses-Courses', 2),
#  ('Career tracks-Resources center-Resources center-Upcoming courses', 2),
#  ('Homepage-Resources center-Resources center-Homepage', 2),
#  ('Success stories-Success stories-Success stories-Career tracks', 2),
#  ('Success stories-Success stories-Career tracks-Career tracks', 2),
#  ('Homepage-Homepage-Blog-Blog', 2),
#  ('Homepage-Blog-Blog-Other', 2),
#  ('Other-Other-Career track certificate-Career track certificate', 2),
#  ('Other-Other-Upcoming courses-Upcoming courses', 2),
#  ('Instructors-Homepage-Instructors-Instructors', 2),
#  ('Upcoming courses-Courses-Courses-Sign up', 2),
#  ('Other-About us-About us-Other', 2),
#  ('Course certificate-Upcoming courses-Upcoming courses-Other', 2),
#  ('Success stories-Success stories-Other-Other', 2),
#  ('Success stories-Other-Other-Other', 2),
#  ('Log in-Sign up-Log in-Log in', 2),
#  ('Career tracks-Courses-Courses-Pricing', 2),
#  ('Courses-Pricing-Pricing-Upcoming courses', 2),
#  ('Career track certificate-Career track certificate-Sign up-Log in', 2),
#  ('Career track certificate-Sign up-Log in-Log in', 2),
#  ('Homepage-Homepage-Pricing-Homepage', 2),
#  ('Sign up-Sign up-Sign up-Pricing', 2),
#  ('Success stories-Success stories-Upcoming courses-Upcoming courses', 2),
#  ('Success stories-Upcoming courses-Upcoming courses-Career tracks', 2),
#  ('Instructors-Career track certificate-Career track certificate-Career track certificate',
#   2),
#  ('Career tracks-Upcoming courses-Upcoming courses-Resources center', 2),
#  ('Blog-Other-Blog-Other', 2),
#  ('Career tracks-Pricing-Pricing-Upcoming courses', 2),
#  ('Courses-Pricing-Pricing-Resources center', 2),
#  ('Pricing-Checkout-Courses-Courses', 2),
#  ('Career track certificate-Instructors-Instructors-Instructors', 2),
#  ('Pricing-Other-Other-Upcoming courses', 2),
#  ('Other-Other-Course certificate-Course certificate', 2),
#  ('Career track certificate-Courses-Courses-Homepage', 2),
#  ('Pricing-Checkout-Pricing-Resources center', 2),
#  ('Instructors-Instructors-Courses-Courses', 2),
#  ('Sign up-Course certificate-Course certificate-Course certificate', 2),
#  ('Career tracks-Upcoming courses-Courses-Courses', 2),
#  ('Log in-Log in-Homepage-Resources center', 2),
#  ('Log in-Homepage-Resources center-Resources center', 2),
#  ('Courses-Resources center-Resources center-Career track certificate', 2),
#  ('Course certificate-Upcoming courses-Upcoming courses-Courses', 2),
#  ('Courses-Courses-Homepage-Career tracks', 2),
#  ('Courses-Homepage-Career tracks-Career tracks', 2),
#  ('Courses-Upcoming courses-Upcoming courses-Course certificate', 2),
#  ('Resources center-Other-Other-Courses', 2),
#  ('Career tracks-Career tracks-Sign up-Log in', 1),
#  ('Career tracks-Sign up-Log in-Log in', 1),
#  ('Other-Career track certificate-Career track certificate-Resources center',
#   1),
#  ('Instructors-Homepage-Homepage-Log in', 1),
#  ('Career tracks-Career tracks-Sign up-Homepage', 1),
#  ('Career tracks-Sign up-Homepage-Homepage', 1),
#  ('Career tracks-Pricing-Career tracks-Pricing', 1),
#  ('Career tracks-Homepage-Sign up-Sign up', 1),
#  ('Sign up-Pricing-Checkout-Checkout', 1),
#  ('Resources center-Pricing-Pricing-Log in', 1),
#  ('Instructors-Pricing-Pricing-Pricing', 1),
#  ('Success stories-Pricing-Pricing-Pricing', 1),
#  ('Homepage-Pricing-Pricing-Other', 1),
#  ('Pricing-Other-Other-Courses', 1),
#  ('Courses-Sign up-Sign up-Pricing', 1),
#  ('Career track certificate-Sign up-Career track certificate-Resources center',
#   1),
#  ('Resources center-Courses-Resources center-Courses', 1),
#  ('Courses-Resources center-Courses-Courses', 1),
#  ('Career track certificate-Career track certificate-Pricing-Course certificate',
#   1),
#  ('Career track certificate-Pricing-Course certificate-Course certificate', 1),
#  ('Homepage-Homepage-Homepage-Upcoming courses', 1),
#  ('Homepage-Homepage-Upcoming courses-Log in', 1),
#  ('Homepage-Upcoming courses-Log in-Log in', 1),
#  ('Sign up-Sign up-Sign up-Upcoming courses', 1),
#  ('Sign up-Sign up-Upcoming courses-Pricing', 1),
#  ('Sign up-Upcoming courses-Pricing-Pricing', 1),
#  ('Courses-Upcoming courses-Upcoming courses-Upcoming courses', 1),
#  ('Upcoming courses-Upcoming courses-Upcoming courses-Resources center', 1),
#  ('Other-Pricing-Other-Pricing', 1),
#  ('Other-Resources center-Other-Resources center', 1),
#  ('Homepage-Courses-Courses-Upcoming courses', 1),
#  ('Homepage-Log in-Log in-Other', 1),
#  ('Other-Career track certificate-Career track certificate-Course certificate',
#   1),
#  ('Courses-Pricing-Pricing-Success stories', 1),
#  ('Success stories-Success stories-Homepage-Pricing', 1),
#  ('Sign up-Sign up-Sign up-Other', 1),
#  ('Sign up-Sign up-Other-Sign up', 1),
#  ('Sign up-Other-Sign up-Sign up', 1),
#  ('Course certificate-Sign up-Course certificate-Log in', 1),
#  ('Sign up-Course certificate-Log in-Log in', 1),
#  ('Blog-Log in-Log in-Log in', 1),
#  ('Pricing-Blog-Blog-Other', 1),
#  ('Blog-Other-Other-Other', 1),
#  ('Course certificate-Upcoming courses-Course certificate-Upcoming courses',
#   1),
#  ('Upcoming courses-Course certificate-Upcoming courses-Upcoming courses', 1),
#  ('Homepage-Career track certificate-Career track certificate-Course certificate',
#   1),
#  ('Other-Success stories-Success stories-Resources center', 1),
#  ('Pricing-Checkout-Pricing-Course certificate', 1),
#  ('Homepage-Log in-Log in-Pricing', 1),
#  ('Log in-Log in-Pricing-Pricing', 1),
#  ('Pricing-Resources center-Resources center-Log in', 1),
#  ('Coupon-Homepage-Log in-Log in', 1),
#  ('Course certificate-Course certificate-Homepage-Pricing', 1),
#  ('Course certificate-Homepage-Pricing-Pricing', 1),
#  ('Pricing-Courses-Courses-Upcoming courses', 1),
#  ('Upcoming courses-Upcoming courses-Resources center-Upcoming courses', 1),
#  ('Upcoming courses-Resources center-Upcoming courses-Success stories', 1),
#  ('Resources center-Upcoming courses-Success stories-Success stories', 1),
#  ('Resources center-Resources center-About us-About us', 1),
#  ('Resources center-About us-About us-Other', 1),
#  ('Career track certificate-Course certificate-Course certificate-Other', 1),
#  ('Course certificate-Course certificate-Other-Other', 1),
#  ('Course certificate-Other-Other-Courses', 1),
#  ('Pricing-Pricing-Checkout-Success stories', 1),
#  ('Pricing-Checkout-Success stories-Success stories', 1),
#  ('Pricing-Resources center-Resources center-Career track certificate', 1),
#  ('Pricing-Career track certificate-Career track certificate-Upcoming courses',
#   1),
#  ('Career track certificate-Upcoming courses-Upcoming courses-Career tracks',
#   1),
#  ('Homepage-Resources center-Homepage-Resources center', 1),
#  ('Resources center-Homepage-Resources center-Resources center', 1),
#  ('Other-Career track certificate-Other-Other', 1),
#  ('Resources center-Resources center-Homepage-Resources center', 1),
#  ('Resources center-Other-Other-Homepage', 1),
#  ('Pricing-Pricing-Homepage-Career tracks', 1),
#  ('Pricing-Homepage-Career tracks-Homepage', 1),
#  ('Homepage-Other-Homepage-Pricing', 1),
#  ('Pricing-Pricing-Course certificate-Pricing', 1),
#  ('Pricing-Course certificate-Pricing-Course certificate', 1),
#  ('Course certificate-Pricing-Course certificate-Course certificate', 1),
#  ('Other-Pricing-Pricing-Courses', 1),
#  ('Coupon-Homepage-Sign up-Log in', 1),
#  ('Course certificate-Course certificate-Career track certificate-Sign up', 1),
#  ('Course certificate-Career track certificate-Sign up-Career track certificate',
#   1),
#  ('Pricing-Log in-Log in-Homepage', 1),
#  ('Log in-Homepage-Homepage-Career tracks', 1),
#  ('Career track certificate-Course certificate-Course certificate-Upcoming courses',
#   1),
#  ('Career track certificate-Sign up-Career track certificate-Log in', 1),
#  ('Sign up-Career track certificate-Log in-Log in', 1),
#  ('Sign up-Career tracks-Career tracks-Homepage', 1),
#  ('Career track certificate-Career track certificate-Career tracks-Courses',
#   1),
#  ('Career track certificate-Pricing-Pricing-Success stories', 1),
#  ('Success stories-Success stories-Success stories-Courses', 1),
#  ('Success stories-Success stories-Courses-Courses', 1),
#  ('Success stories-Courses-Courses-Courses', 1),
#  ('Career tracks-Resources center-Resources center-Career track certificate',
#   1),
#  ('Pricing-Courses-Courses-Homepage', 1),
#  ('Homepage-Other-Homepage-Homepage', 1),
#  ('Homepage-Courses-Courses-Career track certificate', 1),
#  ('Checkout-Homepage-Homepage-Career tracks', 1),
#  ('Homepage-Course certificate-Homepage-Course certificate', 1),
#  ('Course certificate-Homepage-Course certificate-Course certificate', 1),
#  ('Other-Course certificate-Other-Courses', 1),
#  ('Course certificate-Other-Courses-Courses', 1),
#  ('Pricing-Course certificate-Course certificate-Homepage', 1),
#  ('Course certificate-Course certificate-Homepage-Courses', 1),
#  ('Checkout-Pricing-Checkout-Homepage', 1),
#  ('Pricing-Career track certificate-Career track certificate-Course certificate',
#   1),
#  ('Career track certificate-Courses-Courses-Log in', 1),
#  ('Courses-Courses-Log in-Courses', 1),
#  ('Courses-Log in-Courses-Courses', 1),
#  ('Homepage-Resources center-Resources center-Career tracks', 1),
#  ('Homepage-Log in-Homepage-Sign up', 1),
#  ('Log in-Homepage-Sign up-Homepage', 1),
#  ('Courses-Homepage-Sign up-Homepage', 1),
#  ('Homepage-Courses-Homepage-Courses', 1),
#  ('Log in-Log in-Other-Homepage', 1),
#  ('Log in-Other-Homepage-Log in', 1),
#  ('Log in-Sign up-Log in-Sign up', 1),
#  ('Other-Log in-Log in-Sign up', 1),
#  ('Other-Resources center-Other-Sign up', 1),
#  ('Resources center-Other-Sign up-Sign up', 1),
#  ('Log in-Pricing-Pricing-Courses', 1),
#  ('Career track certificate-Career track certificate-Resources center-Career track certificate',
#   1),
#  ('Career track certificate-Resources center-Career track certificate-Career track certificate',
#   1),
#  ('Homepage-Course certificate-Course certificate-Pricing', 1),
#  ('Career tracks-Pricing-Pricing-Course certificate', 1),
#  ('Courses-Homepage-Homepage-Career tracks', 1),
#  ('Career tracks-Career tracks-Courses-Homepage', 1),
#  ('Career tracks-Courses-Homepage-Homepage', 1),
#  ('Career tracks-Courses-Courses-Log in', 1),
#  ('Homepage-Instructors-Instructors-Other', 1),
#  ('Instructors-Instructors-Other-Other', 1),
#  ('Instructors-Other-Other-Other', 1),
#  ('Other-Other-Upcoming courses-Career tracks', 1),
#  ('Other-Upcoming courses-Career tracks-Career tracks', 1),
#  ('Success stories-Blog-Blog-Homepage', 1),
#  ('Log in-Homepage-Pricing-Pricing', 1),
#  ('Pricing-Course certificate-Course certificate-Log in', 1),
#  ('Courses-Courses-Career tracks-Success stories', 1),
#  ('Courses-Career tracks-Success stories-Homepage', 1),
#  ('Career tracks-Success stories-Homepage-Homepage', 1),
#  ('Courses-Resources center-Resources center-Courses', 1),
#  ('Resources center-Courses-Courses-Homepage', 1),
#  ('Instructors-About us-About us-Other', 1),
#  ('Pricing-Checkout-Courses-Course certificate', 1),
#  ('Checkout-Courses-Course certificate-Course certificate', 1),
#  ('Career tracks-Sign up-Career tracks-Course certificate', 1),
#  ('Sign up-Career tracks-Course certificate-Course certificate', 1),
#  ('Sign up-Sign up-Log in-Other', 1),
#  ('Sign up-Log in-Other-Log in', 1),
#  ('Instructors-Pricing-Pricing-Sign up', 1),
#  ('Resources center-Other-Resources center-Log in', 1),
#  ('Other-Resources center-Log in-Log in', 1),
#  ('Courses-Upcoming courses-Upcoming courses-Pricing', 1),
#  ('Course certificate-Sign up-Sign up-Homepage', 1),
#  ('Sign up-Homepage-Homepage-Courses', 1),
#  ('Courses-Sign up-Homepage-Courses', 1),
#  ('Checkout-Pricing-Homepage-Homepage', 1),
#  ('Sign up-Courses-Sign up-Log in', 1),
#  ('Career track certificate-Career tracks-Career tracks-Career track certificate',
#   1),
#  ('Log in-Other-Log in-Other', 1),
#  ('Other-Log in-Other-Log in', 1),
#  ('Pricing-Pricing-Courses-Pricing', 1),
#  ('Pricing-Courses-Pricing-Courses', 1),
#  ('Courses-Courses-Sign up-Log in', 1),
#  ('Pricing-Checkout-Homepage-Log in', 1),
#  ('Log in-Courses-Courses-Course certificate', 1),
#  ('Pricing-Pricing-Homepage-Sign up', 1),
#  ('Checkout-Homepage-Homepage-Resources center', 1),
#  ('Upcoming courses-Courses-Courses-Pricing', 1),
#  ('Instructors-Log in-Log in-Log in', 1),
#  ('Pricing-Career track certificate-Career track certificate-Courses', 1),
#  ('Homepage-Course certificate-Homepage-Courses', 1),
#  ('Homepage-Career tracks-Career tracks-Course certificate', 1),
#  ('Pricing-Pricing-Homepage-Courses', 1),
#  ('Pricing-Homepage-Courses-Courses', 1),
#  ('Log in-Other-Log in-Sign up', 1),
#  ('Other-Log in-Sign up-Sign up', 1),
#  ('Other-Course certificate-Course certificate-Pricing', 1),
#  ('Career track certificate-Career track certificate-Pricing-Career track certificate',
#   1),
#  ('Career track certificate-Pricing-Career track certificate-Career track certificate',
#   1),
#  ('Homepage-Homepage-Pricing-Upcoming courses', 1),
#  ('Homepage-Pricing-Upcoming courses-Upcoming courses', 1),
#  ('Career tracks-Career tracks-Homepage-Pricing', 1),
#  ('Career tracks-Homepage-Pricing-Pricing', 1),
#  ('Checkout-Checkout-Homepage-Courses', 1),
#  ('Checkout-Homepage-Courses-Courses', 1),
#  ('Courses-Resources center-Resources center-Course certificate', 1),
#  ('Course certificate-Courses-Courses-Resources center', 1),
#  ('Career tracks-Course certificate-Course certificate-Courses', 1),
#  ('Course certificate-Course certificate-Courses-Course certificate', 1),
#  ('Course certificate-Courses-Course certificate-Course certificate', 1),
#  ('Pricing-Pricing-Pricing-Success stories', 1),
#  ('Checkout-Checkout-Homepage-Checkout', 1),
#  ('Checkout-Homepage-Checkout-Homepage', 1),
#  ('Homepage-Checkout-Homepage-Homepage', 1),
#  ('Checkout-Homepage-Homepage-Career track certificate', 1),
#  ('Log in-Resources center-Resources center-Resources center', 1),
#  ('Course certificate-Courses-Courses-Sign up', 1),
#  ('Courses-Resources center-Resources center-Pricing', 1),
#  ('Course certificate-Course certificate-Homepage-Homepage', 1),
#  ('Course certificate-Homepage-Homepage-Homepage', 1),
#  ('Homepage-Resources center-Resources center-Course certificate', 1),
#  ('Career track certificate-Upcoming courses-Upcoming courses-Pricing', 1),
#  ('About us-Sign up-Sign up-Sign up', 1),
#  ('About us-Resources center-Resources center-Resources center', 1),
#  ('Courses-Courses-Homepage-Log in', 1),
#  ('Courses-Homepage-Log in-Log in', 1),
#  ('About us-Pricing-Pricing-Homepage', 1),
#  ('Upcoming courses-Resources center-Resources center-Career track certificate',
#   1),
#  ('Resources center-Course certificate-Course certificate-Career track certificate',
#   1),
#  ('Career tracks-Sign up-Sign up-Pricing', 1),
#  ('Pricing-Pricing-Checkout-Sign up', 1),
#  ('Pricing-Checkout-Sign up-Pricing', 1),
#  ('Homepage-Sign up-Sign up-Courses', 1),
#  ('Coupon-Homepage-Homepage-Homepage', 1),
#  ('Pricing-Homepage-Homepage-Career track certificate', 1),
#  ('Homepage-Log in-Homepage-Career track certificate', 1),
#  ('Log in-Homepage-Career track certificate-Homepage', 1),
#  ('Homepage-Career track certificate-Homepage-Log in', 1),
#  ('Career track certificate-Homepage-Log in-Homepage', 1),
#  ('Upcoming courses-Courses-Upcoming courses-Courses', 1),
#  ('Career track certificate-Career track certificate-Homepage-Course certificate',
#   1),
#  ('Career track certificate-Homepage-Course certificate-Course certificate',
#   1),
#  ('Homepage-Course certificate-Course certificate-Resources center', 1),
#  ('Pricing-Resources center-Resources center-Upcoming courses', 1),
#  ('Resources center-Upcoming courses-Upcoming courses-Career track certificate',
#   1),
#  ('Homepage-About us-About us-Pricing', 1),
#  ('About us-About us-Pricing-Pricing', 1),
#  ('About us-Pricing-Pricing-Pricing', 1),
#  ('Career tracks-Sign up-Sign up-Homepage', 1),
#  ('Courses-Sign up-Courses-Course certificate', 1),
#  ('Sign up-Courses-Course certificate-Course certificate', 1),
#  ('Sign up-Career tracks-Pricing-Career tracks', 1),
#  ('Career tracks-Pricing-Pricing-Resources center', 1),
#  ('Resources center-Resources center-About us-Resources center', 1),
#  ('Resources center-About us-Resources center-Other', 1),
#  ('Career tracks-Sign up-Career track certificate-Career track certificate',
#   1),
#  ('Resources center-Career tracks-Career tracks-Sign up', 1),
#  ('Sign up-Sign up-Sign up-Career tracks', 1),
#  ('Sign up-Sign up-Career tracks-Sign up', 1),
#  ('Sign up-Career tracks-Sign up-Sign up', 1),
#  ('Career tracks-Career tracks-Homepage-Resources center', 1),
#  ('Career tracks-Homepage-Resources center-Resources center', 1),
#  ('Homepage-Homepage-Instructors-Other', 1),
#  ('Homepage-Instructors-Other-Other', 1),
#  ('Instructors-Other-Other-Resources center', 1),
#  ('Resources center-Homepage-Homepage-Career track certificate', 1),
#  ('Homepage-Pricing-Pricing-Upcoming courses', 1),
#  ('Homepage-Courses-Courses-Course certificate', 1),
#  ('Homepage-Pricing-Other-Coupon', 1),
#  ('Pricing-Other-Coupon-Coupon', 1),
#  ('Other-Coupon-Coupon-Homepage', 1),
#  ('Coupon-Homepage-Homepage-Pricing', 1),
#  ('Checkout-Homepage-Homepage-Pricing', 1),
#  ('Pricing-Blog-Blog-Blog', 1),
#  ('Career track certificate-Pricing-Pricing-Homepage', 1),
#  ('Career tracks-Other-Career tracks-Career tracks', 1),
#  ('Other-Career tracks-Career tracks-Homepage', 1),
#  ('Career tracks-Resources center-Resources center-Career tracks', 1),
#  ('Resources center-Upcoming courses-Upcoming courses-Resources center', 1),
#  ('Upcoming courses-Resources center-Resources center-Other', 1),
#  ('Other-Other-Other-Success stories', 1),
#  ('Success stories-Pricing-Pricing-Sign up', 1),
#  ('Sign up-Pricing-Pricing-Resources center', 1),
#  ('Pricing-Resources center-Resources center-Course certificate', 1),
#  ('Course certificate-Course certificate-Homepage-Upcoming courses', 1),
#  ('Courses-Courses-Homepage-Resources center', 1),
#  ('Courses-Homepage-Resources center-Resources center', 1),
#  ('Homepage-Homepage-Sign up-Checkout', 1),
#  ('Homepage-Sign up-Checkout-Homepage', 1),
#  ('Sign up-Checkout-Homepage-Homepage', 1),
#  ('Homepage-Homepage-Homepage-Blog', 1),
#  ('Blog-Other-Other-Career track certificate', 1),
#  ('Homepage-Sign up-Sign up-Career tracks', 1),
#  ('Sign up-Sign up-Career tracks-Career tracks', 1),
#  ('Career track certificate-Pricing-Pricing-Upcoming courses', 1),
#  ('Coupon-Coupon-Homepage-Course certificate', 1),
#  ('Coupon-Homepage-Course certificate-Course certificate', 1),
#  ('Other-Resources center-Resources center-Career tracks', 1),
#  ('Other-Upcoming courses-Upcoming courses-Homepage', 1),
#  ('Upcoming courses-Upcoming courses-Homepage-Homepage', 1),
#  ('Upcoming courses-Homepage-Homepage-Sign up', 1),
#  ('Homepage-Instructors-Instructors-Pricing', 1),
#  ('Courses-Other-Other-Other', 1),
#  ('Courses-Resources center-Resources center-Homepage', 1),
#  ('Career tracks-Career tracks-Pricing-Career track certificate', 1),
#  ('Career tracks-Pricing-Career track certificate-Career track certificate',
#   1),
#  ('Pricing-Career track certificate-Career track certificate-Homepage', 1),
#  ('Resources center-Pricing-Pricing-Homepage', 1),
#  ('Upcoming courses-Resources center-Resources center-Instructors', 1),
#  ('Homepage-Career track certificate-Career track certificate-Courses', 1),
#  ('Sign up-Homepage-Sign up-Sign up', 1),
#  ('Career track certificate-Career track certificate-Career track certificate-Coupon',
#   1),
#  ('Career track certificate-Career track certificate-Coupon-Coupon', 1),
#  ('Career track certificate-Coupon-Coupon-Coupon', 1),
#  ('Career track certificate-Career tracks-Career track certificate-Pricing',
#   1),
#  ('Career tracks-Career track certificate-Pricing-Pricing', 1),
#  ('Upcoming courses-Other-Other-Career tracks', 1),
#  ('Career track certificate-Other-Other-Other', 1),
#  ('Pricing-Pricing-Career track certificate-Courses', 1),
#  ('Course certificate-Career track certificate-Career track certificate-Course certificate',
#   1),
#  ('Blog-Other-Other-Blog', 1),
#  ('Other-Other-Blog-Blog', 1),
#  ('Other-Blog-Blog-Other', 1),
#  ('Coupon-Coupon-Homepage-Career track certificate', 1),
#  ('Coupon-Homepage-Career track certificate-Career track certificate', 1),
#  ('Career track certificate-Pricing-Pricing-Resources center', 1),
#  ('Resources center-Career tracks-Career tracks-Upcoming courses', 1),
#  ('Log in-Log in-Sign up-Log in', 1),
#  ('Career tracks-Course certificate-Course certificate-Career track certificate',
#   1),
#  ('Career tracks-Career track certificate-Career track certificate-Homepage',
#   1),
#  ('Homepage-Upcoming courses-Upcoming courses-Career tracks', 1),
#  ('Upcoming courses-Career tracks-Career tracks-Courses', 1),
#  ('Courses-Career tracks-Career tracks-Other', 1),
#  ('Career tracks-Other-Other-Career tracks', 1),
#  ('Checkout-Checkout-Pricing-Course certificate', 1),
#  ('Career tracks-Course certificate-Course certificate-Career tracks', 1),
#  ('Resources center-Course certificate-Course certificate-Courses', 1),
#  ('Courses-Courses-Courses-Blog', 1),
#  ('Courses-Courses-Blog-Blog', 1),
#  ('Courses-Blog-Blog-Other', 1),
#  ('Pricing-Resources center-Resources center-Courses', 1),
#  ('Homepage-Log in-Homepage-Homepage', 1),
#  ('Sign up-Sign up-Pricing-Sign up', 1),
#  ('Courses-Sign up-Courses-Homepage', 1),
#  ('Sign up-Courses-Homepage-Homepage', 1),
#  ('Career track certificate-Upcoming courses-Upcoming courses-Career track certificate',
#   1),
#  ('Other-Success stories-Success stories-Upcoming courses', 1),
#  ('Career track certificate-Career track certificate-Career track certificate-About us',
#   1),
#  ('About us-Career track certificate-Career track certificate-Career track certificate',
#   1),
#  ('Course certificate-Upcoming courses-Upcoming courses-Career track certificate',
#   1),
#  ('Upcoming courses-Courses-Upcoming courses-Upcoming courses', 1),
#  ('Courses-Upcoming courses-Upcoming courses-About us', 1),
#  ('Upcoming courses-Upcoming courses-About us-About us', 1),
#  ('Upcoming courses-About us-About us-Instructors', 1),
#  ('About us-About us-Instructors-Instructors', 1),
#  ('About us-Instructors-Instructors-Instructors', 1),
#  ('Instructors-Instructors-Instructors-Career track certificate', 1),
#  ('Instructors-Instructors-Career track certificate-Career track certificate',
#   1),
#  ...]

# %%
page_sequences(data,5)
# Out:
# [('Checkout-Checkout-Checkout-Checkout-Checkout', 11209),
#  ('Coupon-Coupon-Coupon-Coupon-Coupon', 8146),
#  ('Log in-Log in-Log in-Log in-Log in', 5911),
#  ('Courses-Courses-Courses-Courses-Courses', 3599),
#  ('Sign up-Sign up-Sign up-Sign up-Sign up', 3104),
#  ('Other-Other-Other-Other-Other', 2774),
#  ('Career tracks-Career tracks-Career tracks-Career tracks-Career tracks',
#   1652),
#  ('Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   1517),
#  ('Resources center-Resources center-Resources center-Resources center-Resources center',
#   735),
#  ('Success stories-Success stories-Success stories-Success stories-Success stories',
#   424),
#  ('Course certificate-Course certificate-Course certificate-Course certificate-Course certificate',
#   413),
#  ('Homepage-Log in-Log in-Log in-Log in', 386),
#  ('Homepage-Homepage-Homepage-Homepage-Homepage', 307),
#  ('Career tracks-Career tracks-Career tracks-Courses-Courses', 225),
#  ('Career tracks-Career tracks-Courses-Courses-Courses', 221),
#  ('Career tracks-Courses-Courses-Courses-Courses', 194),
#  ('Pricing-Pricing-Pricing-Pricing-Pricing', 193),
#  ('Homepage-Career tracks-Career tracks-Career tracks-Career tracks', 188),
#  ('Career tracks-Career tracks-Career tracks-Career tracks-Courses', 182),
#  ('Resources center-Other-Resources center-Resources center-Resources center',
#   178),
#  ('Resources center-Resources center-Resources center-Other-Resources center',
#   176),
#  ('Homepage-Courses-Courses-Courses-Courses', 175),
#  ('Resources center-Resources center-Other-Resources center-Resources center',
#   174),
#  ('Homepage-Sign up-Sign up-Sign up-Sign up', 161),
#  ('Sign up-Sign up-Log in-Log in-Log in', 158),
#  ('Other-Resources center-Resources center-Resources center-Other', 158),
#  ('Courses-Courses-Career tracks-Career tracks-Career tracks', 144),
#  ('Courses-Courses-Courses-Career tracks-Career tracks', 142),
#  ('Courses-Courses-Courses-Courses-Career tracks', 132),
#  ('Sign up-Log in-Log in-Log in-Log in', 116),
#  ('Career track certificate-Career track certificate-Career track certificate-Career tracks-Career tracks',
#   111),
#  ('Courses-Career tracks-Career tracks-Career tracks-Career tracks', 105),
#  ('Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career tracks',
#   103),
#  ('Career track certificate-Career track certificate-Career tracks-Career tracks-Career tracks',
#   101),
#  ('Courses-Sign up-Sign up-Sign up-Sign up', 97),
#  ('Career track certificate-Career tracks-Career tracks-Career tracks-Career tracks',
#   93),
#  ('Courses-Courses-Courses-Courses-Sign up', 91),
#  ('Homepage-Homepage-Career tracks-Career tracks-Career tracks', 90),
#  ('Homepage-Homepage-Homepage-Career tracks-Career tracks', 90),
#  ('Homepage-Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   87),
#  ('Career tracks-Sign up-Sign up-Sign up-Sign up', 86),
#  ('Career tracks-Career tracks-Career tracks-Career tracks-Sign up', 85),
#  ('Courses-Courses-Sign up-Sign up-Sign up', 82),
#  ('Courses-Courses-Courses-Sign up-Sign up', 78),
#  ('Pricing-Checkout-Checkout-Checkout-Checkout', 77),
#  ('Career tracks-Career tracks-Sign up-Sign up-Sign up', 77),
#  ('Pricing-Sign up-Sign up-Sign up-Sign up', 76),
#  ('Log in-Log in-Log in-Log in-Other', 73),
#  ('Sign up-Sign up-Sign up-Log in-Log in', 73),
#  ('Resources center-Resources center-Resources center-Resources center-Other',
#   72),
#  ('Homepage-Pricing-Pricing-Pricing-Pricing', 72),
#  ('Pricing-Courses-Courses-Courses-Courses', 69),
#  ('Career tracks-Career tracks-Career tracks-Sign up-Sign up', 67),
#  ('Log in-Sign up-Sign up-Sign up-Sign up', 65),
#  ('Pricing-Pricing-Sign up-Sign up-Sign up', 63),
#  ('Sign up-Sign up-Sign up-Sign up-Log in', 61),
#  ('Other-Resources center-Resources center-Resources center-Resources center',
#   55),
#  ('Log in-Log in-Sign up-Sign up-Sign up', 55),
#  ('Courses-Career tracks-Career tracks-Career tracks-Courses', 52),
#  ('Pricing-Pricing-Courses-Courses-Courses', 52),
#  ('Pricing-Pricing-Checkout-Checkout-Checkout', 51),
#  ('Pricing-Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   48),
#  ('Career tracks-Career tracks-Career tracks-Homepage-Homepage', 46),
#  ('Homepage-Career tracks-Career tracks-Career tracks-Homepage', 45),
#  ('Homepage-Course certificate-Course certificate-Course certificate-Course certificate',
#   44),
#  ('Courses-Courses-Courses-Courses-Pricing', 44),
#  ('Career tracks-Courses-Courses-Courses-Career tracks', 43),
#  ('Career tracks-Career tracks-Homepage-Homepage-Homepage', 42),
#  ('Career tracks-Career tracks-Career tracks-Career tracks-Pricing', 42),
#  ('Homepage-Sign up-Sign up-Log in-Log in', 42),
#  ('Log in-Log in-Log in-Sign up-Sign up', 41),
#  ('Other-Log in-Log in-Log in-Log in', 40),
#  ('Homepage-Homepage-Homepage-Homepage-Career tracks', 38),
#  ('Pricing-Log in-Log in-Log in-Log in', 38),
#  ('Career tracks-Career tracks-Career tracks-Career track certificate-Career track certificate',
#   38),
#  ('Pricing-Pricing-Career track certificate-Career track certificate-Career track certificate',
#   38),
#  ('Resources center-Resources center-Resources center-Other-Other', 38),
#  ('Log in-Log in-Log in-Log in-Sign up', 37),
#  ('Course certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   36),
#  ('Career tracks-Career tracks-Career track certificate-Career track certificate-Career track certificate',
#   36),
#  ('Course certificate-Course certificate-Career track certificate-Career track certificate-Career track certificate',
#   35),
#  ('Homepage-Pricing-Pricing-Sign up-Sign up', 35),
#  ('Career tracks-Career tracks-Career tracks-Pricing-Pricing', 35),
#  ('Homepage-Resources center-Resources center-Resources center-Resources center',
#   34),
#  ('Homepage-Pricing-Pricing-Checkout-Pricing', 34),
#  ('Pricing-Career tracks-Career tracks-Career tracks-Career tracks', 33),
#  ('Homepage-Pricing-Pricing-Checkout-Checkout', 33),
#  ('Courses-Courses-Courses-Pricing-Pricing', 33),
#  ('Career tracks-Homepage-Homepage-Homepage-Career tracks', 32),
#  ('Course certificate-Course certificate-Course certificate-Course certificate-Career track certificate',
#   32),
#  ('Courses-Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   31),
#  ('Courses-Courses-Courses-Career tracks-Courses', 31),
#  ('Course certificate-Course certificate-Course certificate-Career track certificate-Career track certificate',
#   31),
#  ('Resources center-Other-Other-Resources center-Resources center', 31),
#  ('Career tracks-Career tracks-Career tracks-Career tracks-Career track certificate',
#   31),
#  ('Career tracks-Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   29),
#  ('Courses-Career tracks-Courses-Courses-Courses', 29),
#  ('Courses-Courses-Courses-Career track certificate-Career track certificate',
#   28),
#  ('Career track certificate-Career track certificate-Career track certificate-Career track certificate-Pricing',
#   28),
#  ('Career track certificate-Career track certificate-Course certificate-Course certificate-Course certificate',
#   28),
#  ('Career track certificate-Career track certificate-Career track certificate-Career track certificate-Course certificate',
#   28),
#  ('Career track certificate-Career track certificate-Career track certificate-Course certificate-Course certificate',
#   28),
#  ('Courses-Courses-Homepage-Homepage-Homepage', 28),
#  ('Courses-Courses-Courses-Courses-Career track certificate', 27),
#  ('Pricing-Pricing-Log in-Log in-Log in', 27),
#  ('Courses-Courses-Career tracks-Courses-Courses', 27),
#  ('Career track certificate-Career track certificate-Career track certificate-Career track certificate-Sign up',
#   27),
#  ('Course certificate-Course certificate-Course certificate-Course certificate-Courses',
#   27),
#  ('Resources center-Resources center-Other-Other-Resources center', 27),
#  ('Career track certificate-Course certificate-Course certificate-Course certificate-Course certificate',
#   27),
#  ('Homepage-Homepage-Homepage-Pricing-Pricing', 26),
#  ('Pricing-Pricing-Career tracks-Career tracks-Career tracks', 26),
#  ('Career tracks-Homepage-Career tracks-Career tracks-Career tracks', 26),
#  ('Pricing-Pricing-Pricing-Courses-Courses', 26),
#  ('Career track certificate-Career track certificate-Career track certificate-Career track certificate-Courses',
#   26),
#  ('Career track certificate-Career track certificate-Career track certificate-Courses-Courses',
#   26),
#  ('Career track certificate-Courses-Courses-Courses-Courses', 26),
#  ('Courses-Courses-Courses-Homepage-Homepage', 26),
#  ('Course certificate-Course certificate-Course certificate-Courses-Courses',
#   25),
#  ('Pricing-Pricing-Pricing-Pricing-Courses', 25),
#  ('Courses-Courses-Career track certificate-Career track certificate-Career track certificate',
#   24),
#  ('Course certificate-Course certificate-Courses-Courses-Courses', 24),
#  ('Courses-Courses-Courses-Courses-Homepage', 24),
#  ('Other-Sign up-Sign up-Sign up-Sign up', 23),
#  ('Career track certificate-Career track certificate-Career track certificate-Pricing-Pricing',
#   23),
#  ('Other-Other-Other-Other-Coupon', 23),
#  ('Other-Other-Other-Coupon-Coupon', 23),
#  ('Other-Other-Resources center-Resources center-Resources center', 23),
#  ('Course certificate-Courses-Courses-Courses-Courses', 23),
#  ('Pricing-Pricing-Pricing-Pricing-Checkout', 22),
#  ('Career track certificate-Career track certificate-Sign up-Sign up-Sign up',
#   22),
#  ('Courses-Log in-Log in-Log in-Log in', 22),
#  ('Career track certificate-Career track certificate-Courses-Courses-Courses',
#   22),
#  ('Other-Other-Log in-Log in-Log in', 21),
#  ('Career track certificate-Career tracks-Career tracks-Career tracks-Career track certificate',
#   20),
#  ('Courses-Courses-Log in-Log in-Log in', 20),
#  ('Pricing-Resources center-Resources center-Resources center-Resources center',
#   20),
#  ('Career tracks-Career track certificate-Career track certificate-Career track certificate-Career tracks',
#   20),
#  ('Homepage-Homepage-Homepage-Homepage-Pricing', 19),
#  ('Other-Other-Coupon-Coupon-Coupon', 19),
#  ('Other-Coupon-Coupon-Coupon-Coupon', 19),
#  ('Pricing-Pricing-Checkout-Pricing-Checkout', 19),
#  ('Resources center-Courses-Courses-Courses-Courses', 19),
#  ('Career track certificate-Sign up-Sign up-Sign up-Sign up', 19),
#  ('Homepage-Pricing-Pricing-Log in-Log in', 19),
#  ('Courses-Homepage-Homepage-Homepage-Homepage', 19),
#  ('Career tracks-Courses-Career tracks-Career tracks-Career tracks', 18),
#  ('Career tracks-Career tracks-Career tracks-Courses-Career tracks', 18),
#  ('Career tracks-Career tracks-Career tracks-Career tracks-Homepage', 18),
#  ('Upcoming courses-Upcoming courses-Courses-Courses-Courses', 18),
#  ('Upcoming courses-Courses-Courses-Courses-Courses', 18),
#  ('Career tracks-Career tracks-Sign up-Career tracks-Career tracks', 18),
#  ('Courses-Courses-Courses-Courses-Log in', 18),
#  ('Courses-Courses-Courses-Log in-Log in', 18),
#  ('Upcoming courses-Career tracks-Career tracks-Career tracks-Career tracks',
#   18),
#  ('Pricing-Pricing-Resources center-Resources center-Resources center', 18),
#  ('Courses-Pricing-Pricing-Pricing-Pricing', 18),
#  ('Courses-Courses-Pricing-Pricing-Pricing', 18),
#  ('Instructors-Instructors-Instructors-Instructors-Instructors', 18),
#  ('Career tracks-Career tracks-Courses-Career tracks-Career tracks', 17),
#  ('Career tracks-Career track certificate-Career tracks-Career tracks-Career tracks',
#   17),
#  ('Pricing-Course certificate-Course certificate-Course certificate-Course certificate',
#   17),
#  ('Resources center-Resources center-Courses-Courses-Courses', 17),
#  ('Homepage-Pricing-Pricing-Courses-Courses', 17),
#  ('Homepage-Career tracks-Homepage-Career tracks-Career tracks', 17),
#  ('Homepage-Homepage-Log in-Log in-Log in', 16),
#  ('Homepage-Pricing-Pricing-Homepage-Homepage', 16),
#  ('Career tracks-Career tracks-Pricing-Pricing-Pricing', 16),
#  ('Courses-Course certificate-Course certificate-Course certificate-Course certificate',
#   16),
#  ('Other-Courses-Courses-Courses-Courses', 16),
#  ('Other-Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   16),
#  ('Career tracks-Log in-Log in-Log in-Log in', 15),
#  ('Resources center-Log in-Log in-Log in-Log in', 15),
#  ('Pricing-Homepage-Homepage-Homepage-Homepage', 15),
#  ('Career tracks-Career tracks-Career tracks-Log in-Log in', 15),
#  ('Career tracks-Career tracks-Log in-Log in-Log in', 15),
#  ('Homepage-Homepage-Courses-Courses-Courses', 15),
#  ('Career track certificate-Career track certificate-Resources center-Resources center-Resources center',
#   14),
#  ('Career track certificate-Resources center-Resources center-Resources center-Resources center',
#   14),
#  ('Homepage-Homepage-Pricing-Pricing-Pricing', 14),
#  ('Pricing-Pricing-Pricing-Pricing-Sign up', 14),
#  ('Courses-Sign up-Sign up-Log in-Log in', 14),
#  ('Career track certificate-Career track certificate-Career track certificate-Career tracks-Career track certificate',
#   14),
#  ('Homepage-Sign up-Homepage-Homepage-Homepage', 14),
#  ('Pricing-Pricing-Pricing-Pricing-Career track certificate', 14),
#  ('Pricing-Pricing-Pricing-Career track certificate-Career track certificate',
#   14),
#  ('Resources center-Resources center-Resources center-Resources center-Courses',
#   14),
#  ('Pricing-Pricing-Homepage-Homepage-Homepage', 14),
#  ('Courses-Courses-Courses-Courses-Upcoming courses', 14),
#  ('Career tracks-Sign up-Career tracks-Career tracks-Career tracks', 14),
#  ('Career tracks-Career tracks-Career tracks-Sign up-Career tracks', 14),
#  ('Career tracks-Pricing-Pricing-Pricing-Pricing', 14),
#  ('Upcoming courses-Upcoming courses-Career tracks-Career tracks-Career tracks',
#   14),
#  ('Courses-Courses-Courses-Courses-Course certificate', 14),
#  ('Courses-Courses-Courses-Course certificate-Course certificate', 14),
#  ('Log in-Homepage-Log in-Log in-Log in', 14),
#  ('Homepage-Homepage-Homepage-Courses-Courses', 14),
#  ('Courses-Courses-Courses-Resources center-Resources center', 14),
#  ('Sign up-Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   14),
#  ('Career tracks-Career tracks-Career tracks-Career tracks-Upcoming courses',
#   14),
#  ('Career tracks-Sign up-Sign up-Log in-Log in', 13),
#  ('Homepage-Pricing-Pricing-Career tracks-Career tracks', 13),
#  ('Log in-Log in-Log in-Other-Log in', 13),
#  ('Pricing-Checkout-Pricing-Checkout-Pricing', 13),
#  ('Courses-Courses-Courses-Courses-Resources center', 13),
#  ('Resources center-Resources center-Resources center-Courses-Courses', 13),
#  ('Pricing-Pricing-Pricing-Checkout-Checkout', 13),
#  ('Resources center-Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   13),
#  ('Career track certificate-Career track certificate-Career track certificate-Sign up-Sign up',
#   13),
#  ('Courses-Courses-Course certificate-Course certificate-Course certificate',
#   13),
#  ('Career track certificate-Career track certificate-Career track certificate-Career track certificate-Resources center',
#   13),
#  ('Career track certificate-Career track certificate-Career track certificate-Resources center-Resources center',
#   13),
#  ('Pricing-Pricing-Pricing-Pricing-Resources center', 13),
#  ('Log in-Sign up-Sign up-Log in-Log in', 13),
#  ('Homepage-Homepage-Homepage-Instructors-Homepage', 13),
#  ('Career tracks-Career tracks-Career tracks-Career track certificate-Career tracks',
#   12),
#  ('Career tracks-Career tracks-Career tracks-Homepage-Career tracks', 12),
#  ('Career tracks-Career tracks-Homepage-Career tracks-Career tracks', 12),
#  ('Sign up-Homepage-Homepage-Homepage-Homepage', 12),
#  ('Career tracks-Career tracks-Career tracks-Resources center-Resources center',
#   12),
#  ('Homepage-Homepage-Homepage-Homepage-Courses', 12),
#  ('Homepage-Instructors-Homepage-Homepage-Homepage', 12),
#  ('Homepage-Homepage-Homepage-Career tracks-Homepage', 11),
#  ('Career tracks-Career tracks-Sign up-Sign up-Log in', 11),
#  ('Pricing-Pricing-Pricing-Sign up-Sign up', 11),
#  ('Career tracks-Career tracks-Career track certificate-Career tracks-Career tracks',
#   11),
#  ('Log in-Log in-Other-Log in-Log in', 11),
#  ('Homepage-Homepage-Career track certificate-Career track certificate-Career track certificate',
#   11),
#  ('Checkout-Pricing-Checkout-Checkout-Checkout', 11),
#  ('Resources center-Resources center-Career track certificate-Career track certificate-Career track certificate',
#   11),
#  ('Other-Pricing-Pricing-Pricing-Pricing', 11),
#  ('Career tracks-Career tracks-Career tracks-Career tracks-Log in', 11),
#  ('Career tracks-Career tracks-Career tracks-Career tracks-Resources center',
#   11),
#  ('Other-Career tracks-Career tracks-Career tracks-Career tracks', 11),
#  ('Pricing-Pricing-Pricing-Career tracks-Career tracks', 11),
#  ('Other-Success stories-Success stories-Success stories-Success stories', 11),
#  ('Homepage-Career tracks-Career tracks-Sign up-Sign up', 11),
#  ('Career tracks-Career tracks-Career tracks-Upcoming courses-Upcoming courses',
#   11),
#  ('Career track certificate-Pricing-Pricing-Pricing-Pricing', 10),
#  ('Courses-Courses-Sign up-Sign up-Log in', 10),
#  ('Homepage-Homepage-Homepage-Career track certificate-Career track certificate',
#   10),
#  ('Sign up-Courses-Courses-Courses-Courses', 10),
#  ('Resources center-Career tracks-Career tracks-Career tracks-Career tracks',
#   10),
#  ('Career track certificate-Career track certificate-Log in-Log in-Log in',
#   10),
#  ('Career tracks-Career tracks-Courses-Courses-Sign up', 10),
#  ('Pricing-Checkout-Pricing-Checkout-Checkout', 10),
#  ('Courses-Courses-Courses-Upcoming courses-Upcoming courses', 10),
#  ('Other-Other-Other-Other-Log in', 10),
#  ('Course certificate-Course certificate-Course certificate-Course certificate-Sign up',
#   10),
#  ('Course certificate-Course certificate-Course certificate-Course certificate-Upcoming courses',
#   10),
#  ('Course certificate-Course certificate-Course certificate-Course certificate-Career tracks',
#   10),
#  ('Course certificate-Course certificate-Course certificate-Career tracks-Career tracks',
#   10),
#  ('Course certificate-Course certificate-Career tracks-Career tracks-Career tracks',
#   10),
#  ('Courses-Resources center-Resources center-Resources center-Resources center',
#   10),
#  ('Homepage-Homepage-Homepage-Resources center-Resources center', 10),
#  ('Resources center-Course certificate-Course certificate-Course certificate-Course certificate',
#   10),
#  ('Pricing-Pricing-Pricing-Pricing-Career tracks', 10),
#  ('Pricing-Pricing-Pricing-Resources center-Resources center', 10),
#  ('Homepage-Pricing-Pricing-Career track certificate-Career track certificate',
#   10),
#  ('Sign up-Career tracks-Career tracks-Career tracks-Career tracks', 10),
#  ('Pricing-Pricing-Checkout-Checkout-Homepage', 10),
#  ('Pricing-Pricing-Course certificate-Course certificate-Course certificate',
#   10),
#  ('Courses-Courses-Courses-Sign up-Courses', 10),
#  ('Homepage-Courses-Courses-Career tracks-Career tracks', 10),
#  ('Instructors-Homepage-Homepage-Homepage-Instructors', 10),
#  ('Career track certificate-Career track certificate-Pricing-Pricing-Pricing',
#   9),
#  ('Homepage-Other-Other-Other-Other', 9),
#  ('Log in-Other-Log in-Log in-Log in', 9),
#  ('Course certificate-Course certificate-Course certificate-Resources center-Resources center',
#   9),
#  ('Resources center-Resources center-Resources center-Resources center-Log in',
#   9),
#  ('Resources center-Resources center-Log in-Log in-Log in', 9),
#  ('Career track certificate-Career track certificate-Career track certificate-Sign up-Career track certificate',
#   9),
#  ('Other-Other-Other-Log in-Log in', 9),
#  ('Other-Course certificate-Course certificate-Course certificate-Course certificate',
#   9),
#  ('Course certificate-Career tracks-Career tracks-Career tracks-Career tracks',
#   9),
#  ('Career tracks-Career tracks-Resources center-Resources center-Resources center',
#   9),
#  ('Career tracks-Resources center-Resources center-Resources center-Resources center',
#   9),
#  ('Courses-Upcoming courses-Upcoming courses-Courses-Courses', 9),
#  ('Homepage-Homepage-Resources center-Resources center-Resources center', 9),
#  ('Resources center-Resources center-Resources center-Resources center-Course certificate',
#   9),
#  ('Resources center-Resources center-Resources center-Course certificate-Course certificate',
#   9),
#  ('Resources center-Resources center-Course certificate-Course certificate-Course certificate',
#   9),
#  ('Career track certificate-Sign up-Career track certificate-Career track certificate-Career track certificate',
#   9),
#  ('Course certificate-Course certificate-Course certificate-Course certificate-Pricing',
#   9),
#  ('Resources center-Resources center-Career tracks-Career tracks-Career tracks',
#   9),
#  ('Courses-Courses-Resources center-Resources center-Resources center', 9),
#  ('Pricing-Checkout-Checkout-Homepage-Homepage', 9),
#  ('Homepage-Homepage-Instructors-Homepage-Homepage', 9),
#  ('Course certificate-Course certificate-Sign up-Sign up-Sign up', 9),
#  ('Pricing-Checkout-Pricing-Pricing-Pricing', 9),
#  ('Career tracks-Homepage-Homepage-Homepage-Homepage', 8),
#  ('Homepage-Career tracks-Homepage-Career tracks-Homepage', 8),
#  ('Career track certificate-Career tracks-Career track certificate-Career track certificate-Career track certificate',
#   8),
#  ('Homepage-Sign up-Homepage-Pricing-Pricing', 8),
#  ('Resources center-Resources center-Resources center-Log in-Log in', 8),
#  ('Career tracks-Career tracks-Pricing-Pricing-Checkout', 8),
#  ('Career track certificate-Career track certificate-Career track certificate-Career track certificate-Log in',
#   8),
#  ('Career track certificate-Career track certificate-Career track certificate-Log in-Log in',
#   8),
#  ('Career tracks-Courses-Courses-Sign up-Sign up', 8),
#  ('Career track certificate-Career track certificate-Career tracks-Career tracks-Sign up',
#   8),
#  ('Career tracks-Course certificate-Course certificate-Course certificate-Course certificate',
#   8),
#  ('Homepage-Homepage-Homepage-Log in-Log in', 8),
#  ('Courses-Courses-Upcoming courses-Upcoming courses-Courses', 8),
#  ('Other-Other-Resources center-Resources center-Other', 8),
#  ('Homepage-Homepage-Homepage-Other-Other', 8),
#  ('Homepage-Log in-Homepage-Log in-Log in', 8),
#  ('Courses-Sign up-Courses-Courses-Courses', 8),
#  ('Homepage-Homepage-Sign up-Sign up-Sign up', 8),
#  ('Log in-Log in-Log in-Other-Other', 8),
#  ('Homepage-Homepage-Pricing-Pricing-Checkout', 8),
#  ('Course certificate-Course certificate-Course certificate-Pricing-Pricing',
#   8),
#  ('Log in-Log in-Log in-Log in-Homepage', 8),
#  ('Pricing-Pricing-Checkout-Pricing-Pricing', 8),
#  ('Course certificate-Course certificate-Course certificate-Course certificate-Resources center',
#   7),
#  ('Resources center-Resources center-Resources center-Resources center-Pricing',
#   7),
#  ('Resources center-Resources center-Resources center-Pricing-Pricing', 7),
#  ('Career track certificate-Career track certificate-Career tracks-Career track certificate-Career track certificate',
#   7),
#  ('Career track certificate-Log in-Log in-Log in-Log in', 7),
#  ('Career tracks-Career tracks-Career tracks-Career tracks-Course certificate',
#   7),
#  ('Career tracks-Career tracks-Career tracks-Course certificate-Course certificate',
#   7),
#  ('Checkout-Checkout-Checkout-Checkout-Homepage', 7),
#  ('Coupon-Coupon-Coupon-Coupon-Homepage', 7),
#  ('Courses-Courses-Pricing-Pricing-Checkout', 7),
#  ('Homepage-Career tracks-Career tracks-Pricing-Pricing', 7),
#  ('Other-Sign up-Sign up-Log in-Log in', 7),
#  ('Log in-Log in-Sign up-Sign up-Log in', 7),
#  ('Other-Other-Success stories-Success stories-Success stories', 7),
#  ('Course certificate-Course certificate-Course certificate-Sign up-Sign up',
#   7),
#  ('Career tracks-Homepage-Career tracks-Homepage-Career tracks', 7),
#  ('Courses-Pricing-Pricing-Courses-Courses', 7),
#  ('Course certificate-Sign up-Sign up-Sign up-Sign up', 7),
#  ('Upcoming courses-Upcoming courses-Career track certificate-Career track certificate-Career track certificate',
#   7),
#  ('Upcoming courses-Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   7),
#  ('Checkout-Pricing-Pricing-Pricing-Pricing', 7),
#  ('Instructors-Courses-Courses-Courses-Courses', 7),
#  ('Homepage-Homepage-Career tracks-Homepage-Homepage', 6),
#  ('Homepage-Career tracks-Homepage-Homepage-Homepage', 6),
#  ('Pricing-Pricing-Pricing-Pricing-Log in', 6),
#  ('Career tracks-Career tracks-Career tracks-Pricing-Career tracks', 6),
#  ('Pricing-Pricing-Checkout-Pricing-Courses', 6),
#  ('Pricing-Checkout-Pricing-Courses-Courses', 6),
#  ('Course certificate-Course certificate-Resources center-Resources center-Resources center',
#   6),
#  ('Course certificate-Resources center-Resources center-Resources center-Resources center',
#   6),
#  ('Sign up-Homepage-Log in-Log in-Log in', 6),
#  ('Other-Other-Pricing-Pricing-Pricing', 6),
#  ('Career tracks-Career tracks-Course certificate-Course certificate-Course certificate',
#   6),
#  ('Checkout-Checkout-Checkout-Homepage-Log in', 6),
#  ('Checkout-Homepage-Log in-Log in-Log in', 6),
#  ('Other-Resources center-Resources center-Other-Other', 6),
#  ('Homepage-Homepage-Homepage-Homepage-Resources center', 6),
#  ('Career tracks-Career tracks-Courses-Courses-Career tracks', 6),
#  ('Homepage-Homepage-Homepage-Homepage-Career track certificate', 6),
#  ('Pricing-Courses-Courses-Career tracks-Career tracks', 6),
#  ('Other-Other-Career tracks-Career tracks-Career tracks', 6),
#  ('Career tracks-Career tracks-Pricing-Pricing-Sign up', 6),
#  ('Course certificate-Course certificate-Course certificate-Course certificate-Log in',
#   6),
#  ('Course certificate-Course certificate-Log in-Log in-Log in', 6),
#  ('Courses-Homepage-Homepage-Homepage-Career tracks', 6),
#  ('Courses-Pricing-Pricing-Checkout-Checkout', 6),
#  ('Sign up-Sign up-Career track certificate-Career track certificate-Career track certificate',
#   6),
#  ('Homepage-Pricing-Homepage-Pricing-Pricing', 6),
#  ('Career track certificate-Career track certificate-Sign up-Career track certificate-Career track certificate',
#   6),
#  ('Log in-Log in-Log in-Homepage-Log in', 6),
#  ('Log in-Log in-Homepage-Log in-Log in', 6),
#  ('Resources center-Resources center-Pricing-Pricing-Pricing', 6),
#  ('Other-Other-Other-Other-Pricing', 6),
#  ('Other-Other-Other-Pricing-Pricing', 6),
#  ('Career track certificate-Career track certificate-Career tracks-Career track certificate-Career tracks',
#   6),
#  ('Career track certificate-Career tracks-Career track certificate-Career tracks-Career tracks',
#   6),
#  ('Resources center-Resources center-Resources center-Career tracks-Career tracks',
#   6),
#  ('Course certificate-Course certificate-Course certificate-Upcoming courses-Upcoming courses',
#   6),
#  ('Homepage-Homepage-Career tracks-Homepage-Career tracks', 5),
#  ('Checkout-Pricing-Courses-Courses-Courses', 5),
#  ('Career tracks-Career tracks-Pricing-Career tracks-Career tracks', 5),
#  ('Career tracks-Pricing-Career tracks-Career tracks-Career tracks', 5),
#  ('Resources center-Resources center-Resources center-Resources center-Homepage',
#   5),
#  ('Resources center-Resources center-Resources center-Homepage-Homepage', 5),
#  ('Resources center-Resources center-Homepage-Homepage-Homepage', 5),
#  ('Other-Other-Sign up-Sign up-Sign up', 5),
#  ('Pricing-Pricing-Pricing-Homepage-Homepage', 5),
#  ('Pricing-Checkout-Checkout-Checkout-Pricing', 5),
#  ('Upcoming courses-Upcoming courses-Resources center-Resources center-Resources center',
#   5),
#  ('Upcoming courses-Resources center-Resources center-Resources center-Resources center',
#   5),
#  ('Career track certificate-Career track certificate-Pricing-Pricing-Checkout',
#   5),
#  ('Checkout-Checkout-Homepage-Log in-Log in', 5),
#  ('Checkout-Pricing-Checkout-Pricing-Checkout', 5),
#  ('Pricing-Pricing-Homepage-Homepage-Courses', 5),
#  ('Pricing-Homepage-Homepage-Courses-Courses', 5),
#  ('Courses-Career tracks-Career tracks-Career tracks-Log in', 5),
#  ('Homepage-Pricing-Pricing-Resources center-Resources center', 5),
#  ('Courses-Courses-Sign up-Courses-Courses', 5),
#  ('Sign up-Sign up-Log in-Log in-Sign up', 5),
#  ('Sign up-Log in-Log in-Sign up-Sign up', 5),
#  ('Homepage-Homepage-Homepage-Sign up-Sign up', 5),
#  ('Resources center-Pricing-Pricing-Pricing-Pricing', 5),
#  ('Homepage-Career tracks-Career tracks-Sign up-Career tracks', 5),
#  ('Career tracks-Courses-Courses-Career tracks-Career tracks', 5),
#  ('Career tracks-Pricing-Pricing-Sign up-Sign up', 5),
#  ('Course certificate-Course certificate-Course certificate-Log in-Log in', 5),
#  ('Homepage-Course certificate-Course certificate-Career track certificate-Career track certificate',
#   5),
#  ('Career track certificate-Career tracks-Career tracks-Sign up-Sign up', 5),
#  ('Career track certificate-Career track certificate-Career tracks-Career tracks-Courses',
#   5),
#  ('Career track certificate-Career tracks-Career tracks-Courses-Courses', 5),
#  ('Career tracks-Pricing-Pricing-Career tracks-Career tracks', 5),
#  ('Courses-Courses-Career tracks-Career tracks-Upcoming courses', 5),
#  ('Courses-Pricing-Pricing-Sign up-Sign up', 5),
#  ('Career track certificate-Career track certificate-Sign up-Sign up-Log in',
#   5),
#  ('Homepage-Courses-Courses-Homepage-Homepage', 5),
#  ('Courses-Courses-Career tracks-Courses-Career tracks', 5),
#  ('Courses-Career tracks-Courses-Career tracks-Career tracks', 5),
#  ('Pricing-Courses-Courses-Courses-Homepage', 5),
#  ('Courses-Success stories-Success stories-Success stories-Success stories',
#   5),
#  ('Resources center-Resources center-Resources center-Resources center-Career tracks',
#   5),
#  ('Career tracks-Career tracks-Upcoming courses-Upcoming courses-Courses', 5),
#  ('Career tracks-Upcoming courses-Upcoming courses-Courses-Courses', 5),
#  ('Career tracks-Career tracks-Upcoming courses-Upcoming courses-Career tracks',
#   5),
#  ('Success stories-Success stories-Success stories-Success stories-Resources center',
#   5),
#  ('Pricing-Sign up-Pricing-Sign up-Sign up', 4),
#  ('Sign up-Pricing-Sign up-Sign up-Sign up', 4),
#  ('Career tracks-Homepage-Homepage-Homepage-Pricing', 4),
#  ('Pricing-Pricing-Pricing-Log in-Log in', 4),
#  ('Homepage-Success stories-Success stories-Success stories-Success stories',
#   4),
#  ('Sign up-Homepage-Pricing-Pricing-Sign up', 4),
#  ('Pricing-Upcoming courses-Upcoming courses-Courses-Courses', 4),
#  ('Homepage-Sign up-Homepage-Log in-Log in', 4),
#  ('Resources center-Homepage-Homepage-Homepage-Homepage', 4),
#  ('Sign up-Sign up-Courses-Courses-Courses', 4),
#  ('Courses-Sign up-Sign up-Sign up-Log in', 4),
#  ('Homepage-Sign up-Sign up-Sign up-Log in', 4),
#  ('Checkout-Checkout-Checkout-Pricing-Checkout', 4),
#  ('Resources center-Resources center-Resources center-Career track certificate-Career track certificate',
#   4),
#  ('Homepage-Courses-Courses-Log in-Log in', 4),
#  ('Resources center-Other-Other-Log in-Log in', 4),
#  ('Homepage-Sign up-Homepage-Career tracks-Career tracks', 4),
#  ('Sign up-Homepage-Career tracks-Career tracks-Career tracks', 4),
#  ('Homepage-Homepage-Homepage-Homepage-Other', 4),
#  ('Pricing-Success stories-Success stories-Success stories-Success stories',
#   4),
#  ('Course certificate-Course certificate-Course certificate-Sign up-Course certificate',
#   4),
#  ('Course certificate-Log in-Log in-Log in-Log in', 4),
#  ('Success stories-Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   4),
#  ('Career tracks-Success stories-Success stories-Success stories-Success stories',
#   4),
#  ('Courses-Career tracks-Career tracks-Career tracks-Pricing', 4),
#  ('Career track certificate-Pricing-Pricing-Career track certificate-Career track certificate',
#   4),
#  ('Pricing-Pricing-Courses-Courses-Career tracks', 4),
#  ('Other-Other-Courses-Courses-Courses', 4),
#  ('Courses-Courses-Career track certificate-Career track certificate-Sign up',
#   4),
#  ('Homepage-Homepage-Career tracks-Career tracks-Sign up', 4),
#  ('Courses-Sign up-Courses-Pricing-Pricing', 4),
#  ('Pricing-Pricing-Pricing-Pricing-Homepage', 4),
#  ('Courses-Career tracks-Career tracks-Courses-Courses', 4),
#  ('Career tracks-Pricing-Pricing-Checkout-Checkout', 4),
#  ('Course certificate-Course certificate-Pricing-Pricing-Pricing', 4),
#  ('Pricing-Pricing-Pricing-Course certificate-Course certificate', 4),
#  ('Checkout-Homepage-Homepage-Homepage-Homepage', 4),
#  ('Homepage-Homepage-Homepage-Homepage-Sign up', 4),
#  ('Homepage-Sign up-Homepage-Courses-Courses', 4),
#  ('Sign up-Homepage-Courses-Courses-Courses', 4),
#  ('Log in-Log in-Other-Other-Homepage', 4),
#  ('Courses-Pricing-Pricing-Career track certificate-Career track certificate',
#   4),
#  ('Homepage-Log in-Log in-Sign up-Sign up', 4),
#  ('Log in-Log in-Log in-Other-Sign up', 4),
#  ('Log in-Log in-Other-Sign up-Sign up', 4),
#  ('Pricing-Other-Other-Other-Other', 4),
#  ('Pricing-Pricing-Pricing-Pricing-Course certificate', 4),
#  ('Checkout-Pricing-Sign up-Sign up-Sign up', 4),
#  ('Courses-Courses-Career tracks-Career tracks-Career track certificate', 4),
#  ('Courses-Career tracks-Career tracks-Career track certificate-Career track certificate',
#   4),
#  ('Checkout-Pricing-Log in-Log in-Log in', 4),
#  ('Pricing-Homepage-Pricing-Pricing-Pricing', 4),
#  ('Career tracks-Career tracks-Career tracks-Other-Other', 4),
#  ('Career tracks-Career tracks-Pricing-Pricing-Career tracks', 4),
#  ('Other-Pricing-Pricing-Sign up-Sign up', 4),
#  ('Homepage-Course certificate-Course certificate-Sign up-Sign up', 4),
#  ('Courses-Courses-Career tracks-Career tracks-Sign up', 4),
#  ('Resources center-Sign up-Sign up-Sign up-Sign up', 4),
#  ('Courses-Courses-Pricing-Pricing-Courses', 4),
#  ('Career tracks-Career tracks-Sign up-Career tracks-Pricing', 4),
#  ('Courses-Courses-Pricing-Pricing-Sign up', 4),
#  ('Pricing-Checkout-Pricing-Career track certificate-Career track certificate',
#   4),
#  ('Checkout-Pricing-Career track certificate-Career track certificate-Career track certificate',
#   4),
#  ('Career track certificate-Sign up-Sign up-Log in-Log in', 4),
#  ('Homepage-Pricing-Pricing-Course certificate-Course certificate', 4),
#  ('Career track certificate-Career track certificate-Homepage-Homepage-Homepage',
#   4),
#  ('Homepage-Homepage-Instructors-Homepage-Instructors', 4),
#  ('Career track certificate-Career track certificate-Sign up-Career track certificate-Pricing',
#   4),
#  ('Pricing-Sign up-Sign up-Log in-Log in', 3),
#  ('Career tracks-Career tracks-Career tracks-Homepage-Sign up', 3),
#  ('Success stories-Success stories-Success stories-Success stories-Pricing',
#   3),
#  ('Success stories-Success stories-Success stories-Pricing-Pricing', 3),
#  ('Homepage-Sign up-Homepage-Course certificate-Course certificate', 3),
#  ('Career tracks-Career tracks-Courses-Career tracks-Courses', 3),
#  ('Sign up-Homepage-Homepage-Homepage-Career tracks', 3),
#  ('Sign up-Pricing-Pricing-Sign up-Sign up', 3),
#  ('Resources center-Other-Other-Sign up-Sign up', 3),
#  ('Sign up-Sign up-Sign up-Courses-Courses', 3),
#  ('Sign up-Courses-Courses-Courses-Sign up', 3),
#  ('Other-Pricing-Pricing-Log in-Log in', 3),
#  ('Log in-Courses-Courses-Courses-Courses', 3),
#  ('Resources center-Resources center-Resources center-Resources center-Career track certificate',
#   3),
#  ('Career track certificate-Pricing-Pricing-Checkout-Pricing', 3),
#  ('Pricing-Pricing-Pricing-Sign up-Pricing', 3),
#  ('Sign up-Pricing-Courses-Courses-Courses', 3),
#  ('Career track certificate-Career tracks-Career tracks-Sign up-Career tracks',
#   3),
#  ('Career tracks-Pricing-Pricing-Log in-Log in', 3),
#  ('Resources center-Resources center-Other-Other-Other', 3),
#  ('Homepage-Career track certificate-Career track certificate-Log in-Log in',
#   3),
#  ('Resources center-Resources center-Other-Other-Log in', 3),
#  ('Pricing-Pricing-Homepage-Homepage-Sign up', 3),
#  ('Other-Pricing-Pricing-Checkout-Checkout', 3),
#  ('Homepage-Homepage-Other-Other-Homepage', 3),
#  ('Homepage-Other-Other-Homepage-Homepage', 3),
#  ('Other-Other-Homepage-Homepage-Homepage', 3),
#  ('Other-Homepage-Homepage-Homepage-Homepage', 3),
#  ('Pricing-Pricing-Success stories-Success stories-Success stories', 3),
#  ('Success stories-Success stories-Success stories-Success stories-Homepage',
#   3),
#  ('Career track certificate-Career track certificate-Career track certificate-Career track certificate-Upcoming courses',
#   3),
#  ('Course certificate-Course certificate-Course certificate-Upcoming courses-Course certificate',
#   3),
#  ('Homepage-Resources center-Resources center-Courses-Courses', 3),
#  ('Pricing-Sign up-Sign up-Sign up-Log in', 3),
#  ('Courses-Courses-Upcoming courses-Upcoming courses-Resources center', 3),
#  ('Success stories-Success stories-Success stories-Success stories-Career track certificate',
#   3),
#  ('Success stories-Success stories-Success stories-Career track certificate-Career track certificate',
#   3),
#  ('Success stories-Success stories-Career track certificate-Career track certificate-Career track certificate',
#   3),
#  ('Career tracks-Career tracks-Pricing-Pricing-Homepage', 3),
#  ('Career tracks-Courses-Career tracks-Courses-Courses', 3),
#  ('Courses-Courses-Courses-Pricing-Courses', 3),
#  ('Courses-Courses-Pricing-Courses-Courses', 3),
#  ('Courses-Pricing-Courses-Courses-Courses', 3),
#  ('Courses-Courses-Courses-Courses-Other', 3),
#  ('Courses-Courses-Courses-Other-Other', 3),
#  ('Career track certificate-Career track certificate-Pricing-Pricing-Career track certificate',
#   3),
#  ('Career track certificate-Career track certificate-Pricing-Pricing-Courses',
#   3),
#  ('Career track certificate-Pricing-Pricing-Courses-Courses', 3),
#  ('Career tracks-Pricing-Pricing-Checkout-Pricing', 3),
#  ('Resources center-Other-Other-Pricing-Pricing', 3),
#  ('Courses-Career track certificate-Career track certificate-Sign up-Sign up',
#   3),
#  ('Pricing-Pricing-Sign up-Pricing-Sign up', 3),
#  ('Log in-Log in-Other-Other-Sign up', 3),
#  ('Log in-Other-Other-Sign up-Sign up', 3),
#  ('Pricing-Pricing-Checkout-Pricing-Career tracks', 3),
#  ('Pricing-Checkout-Pricing-Career tracks-Career tracks', 3),
#  ('Checkout-Pricing-Career tracks-Career tracks-Career tracks', 3),
#  ('Other-Pricing-Pricing-Career track certificate-Career track certificate',
#   3),
#  ('Resources center-Success stories-Success stories-Success stories-Success stories',
#   3),
#  ('Course certificate-Course certificate-Upcoming courses-Course certificate-Course certificate',
#   3),
#  ('Course certificate-Upcoming courses-Course certificate-Course certificate-Course certificate',
#   3),
#  ('Pricing-Pricing-Pricing-Pricing-Upcoming courses', 3),
#  ('Pricing-Upcoming courses-Upcoming courses-Career tracks-Career tracks', 3),
#  ('Courses-Courses-Career tracks-Career tracks-Courses', 3),
#  ('Career track certificate-Courses-Courses-Career tracks-Career tracks', 3),
#  ('Sign up-Homepage-Pricing-Pricing-Pricing', 3),
#  ('Pricing-Pricing-Sign up-Sign up-Log in', 3),
#  ('Checkout-Pricing-Checkout-Pricing-Pricing', 3),
#  ('Homepage-Log in-Homepage-Log in-Homepage', 3),
#  ('Homepage-Homepage-Homepage-Course certificate-Course certificate', 3),
#  ('Homepage-Homepage-Course certificate-Course certificate-Course certificate',
#   3),
#  ('Course certificate-Pricing-Pricing-Checkout-Pricing', 3),
#  ('Log in-Other-Other-Homepage-Homepage', 3),
#  ('Courses-Courses-Pricing-Pricing-Career track certificate', 3),
#  ('Log in-Other-Sign up-Sign up-Log in', 3),
#  ('Pricing-Pricing-Pricing-Other-Other', 3),
#  ('Pricing-Pricing-Other-Other-Other', 3),
#  ('Resources center-Resources center-Other-Other-Success stories', 3),
#  ('Resources center-Other-Other-Success stories-Success stories', 3),
#  ('Other-Sign up-Sign up-Sign up-Log in', 3),
#  ('Pricing-Pricing-Checkout-Pricing-Sign up', 3),
#  ('Pricing-Checkout-Pricing-Sign up-Sign up', 3),
#  ('Checkout-Checkout-Homepage-Homepage-Sign up', 3),
#  ('Upcoming courses-Other-Other-Other-Other', 3),
#  ('Sign up-Sign up-Sign up-Sign up-Homepage', 3),
#  ('Career tracks-Career tracks-Other-Other-Other', 3),
#  ('Homepage-Homepage-Pricing-Pricing-Sign up', 3),
#  ('Checkout-Checkout-Checkout-Checkout-Pricing', 3),
#  ('Courses-Pricing-Pricing-Checkout-Courses', 3),
#  ('Career track certificate-Pricing-Pricing-Sign up-Sign up', 3),
#  ('Courses-Career tracks-Career tracks-Sign up-Sign up', 3),
#  ('Career tracks-Career track certificate-Career track certificate-Career tracks-Career tracks',
#   3),
#  ('Courses-Courses-Courses-Upcoming courses-Courses', 3),
#  ('Course certificate-Course certificate-Pricing-Pricing-Courses', 3),
#  ('Homepage-Career track certificate-Career track certificate-Sign up-Sign up',
#   3),
#  ('Homepage-Courses-Courses-Pricing-Pricing', 3),
#  ('Homepage-Sign up-Sign up-Pricing-Pricing', 3),
#  ('Resources center-Resources center-Other-Other-Sign up', 3),
#  ('Career tracks-Sign up-Career tracks-Pricing-Pricing', 3),
#  ('Career tracks-Pricing-Pricing-Career track certificate-Career track certificate',
#   3),
#  ('Pricing-Pricing-Career tracks-Career tracks-Sign up', 3),
#  ('Pricing-Career tracks-Career tracks-Sign up-Sign up', 3),
#  ('Pricing-Pricing-Checkout-Pricing-Career track certificate', 3),
#  ('Course certificate-Course certificate-Career track certificate-Career track certificate-Sign up',
#   3),
#  ('Course certificate-Career track certificate-Career track certificate-Sign up-Sign up',
#   3),
#  ('Career tracks-Career tracks-Sign up-Career tracks-Career track certificate',
#   3),
#  ('Career tracks-Sign up-Career tracks-Career track certificate-Career track certificate',
#   3),
#  ('Sign up-Career tracks-Career track certificate-Career track certificate-Career track certificate',
#   3),
#  ('Upcoming courses-Upcoming courses-Courses-Courses-Career tracks', 3),
#  ('Upcoming courses-Courses-Courses-Career tracks-Career tracks', 3),
#  ('Homepage-Homepage-Homepage-Homepage-Instructors', 3),
#  ('Homepage-Instructors-Homepage-Instructors-Homepage', 3),
#  ('Instructors-Homepage-Instructors-Homepage-Homepage', 3),
#  ('Career tracks-Courses-Courses-Courses-Homepage', 3),
#  ('Homepage-Sign up-Homepage-Career track certificate-Career track certificate',
#   3),
#  ('Sign up-Homepage-Career track certificate-Career track certificate-Career track certificate',
#   3),
#  ('Courses-Courses-Courses-Courses-Success stories', 3),
#  ('Courses-Courses-Courses-Success stories-Success stories', 3),
#  ('Courses-Courses-Success stories-Success stories-Success stories', 3),
#  ('Success stories-Success stories-Success stories-Success stories-Sign up',
#   3),
#  ('Homepage-Sign up-Sign up-Career track certificate-Career track certificate',
#   3),
#  ('Homepage-Career track certificate-Career track certificate-Sign up-Career track certificate',
#   3),
#  ('Career track certificate-Career track certificate-Sign up-Career track certificate-Career tracks',
#   3),
#  ('Career track certificate-Sign up-Career track certificate-Career tracks-Career tracks',
#   3),
#  ('Sign up-Career track certificate-Career tracks-Career tracks-Career tracks',
#   3),
#  ('Career track certificate-Sign up-Career track certificate-Pricing-Pricing',
#   3),
#  ('Course certificate-Course certificate-Sign up-Course certificate-Pricing',
#   3),
#  ('Course certificate-Sign up-Course certificate-Pricing-Pricing', 3),
#  ('Career track certificate-Success stories-Success stories-Success stories-Success stories',
#   3),
#  ('Career tracks-Career tracks-Career tracks-Career tracks-Other', 3),
#  ('Homepage-Other-Other-Success stories-Success stories', 3),
#  ('Success stories-Career tracks-Career tracks-Career tracks-Career tracks',
#   3),
#  ('Pricing-Pricing-Upcoming courses-Upcoming courses-Courses', 3),
#  ('Success stories-Success stories-Success stories-Success stories-Other', 3),
#  ('Career tracks-Upcoming courses-Upcoming courses-Career tracks-Career tracks',
#   3),
#  ('Career tracks-Career tracks-Career tracks-Career tracks-Success stories',
#   3),
#  ('Courses-Log in-Log in-Sign up-Sign up', 3),
#  ('Career tracks-Career tracks-Upcoming courses-Upcoming courses-Career track certificate',
#   3),
#  ('Career tracks-Upcoming courses-Upcoming courses-Career track certificate-Career track certificate',
#   3),
#  ('Courses-Career tracks-Career tracks-Upcoming courses-Upcoming courses', 3),
#  ('Sign up-Sign up-Sign up-Homepage-Homepage', 3),
#  ('Career track certificate-Career track certificate-Sign up-Career track certificate-Courses',
#   3),
#  ('Career track certificate-Sign up-Career track certificate-Courses-Courses',
#   3),
#  ('Sign up-Sign up-Homepage-Homepage-Homepage', 3),
#  ('Success stories-Success stories-Success stories-Resources center-Resources center',
#   3),
#  ('Success stories-Success stories-Resources center-Resources center-Resources center',
#   3),
#  ('Success stories-Resources center-Resources center-Resources center-Resources center',
#   3),
#  ('Upcoming courses-Upcoming courses-Course certificate-Course certificate-Course certificate',
#   3),
#  ('Upcoming courses-Course certificate-Course certificate-Course certificate-Course certificate',
#   3),
#  ('Homepage-Career tracks-Homepage-Homepage-Career tracks', 2),
#  ('Career tracks-Homepage-Homepage-Career tracks-Career tracks', 2),
#  ('Homepage-Career tracks-Career tracks-Career tracks-Sign up', 2),
#  ('Homepage-Instructors-Instructors-Homepage-Homepage', 2),
#  ('Career tracks-Homepage-Career tracks-Homepage-Homepage', 2),
#  ('Sign up-Homepage-Homepage-Homepage-Pricing', 2),
#  ('Other-Other-Other-Other-Homepage', 2),
#  ('Other-Other-Other-Homepage-Log in', 2),
#  ('Other-Homepage-Log in-Log in-Log in', 2),
#  ('Pricing-Career tracks-Career tracks-Career tracks-Courses', 2),
#  ('Checkout-Pricing-Checkout-Pricing-Upcoming courses', 2),
#  ('Other-Pricing-Pricing-Career tracks-Career tracks', 2),
#  ('Other-Other-Courses-Courses-Sign up', 2),
#  ('Other-Courses-Courses-Sign up-Sign up', 2),
#  ('Sign up-Sign up-Pricing-Pricing-Sign up', 2),
#  ('Courses-Pricing-Pricing-Pricing-Homepage', 2),
#  ('Checkout-Checkout-Pricing-Checkout-Checkout', 2),
#  ('Upcoming courses-Pricing-Pricing-Pricing-Pricing', 2),
#  ('Log in-Log in-Log in-Courses-Courses', 2),
#  ('Log in-Log in-Courses-Courses-Courses', 2),
#  ('Resources center-Resources center-Homepage-Homepage-Other', 2),
#  ('Resources center-Homepage-Homepage-Other-Other', 2),
#  ('Pricing-Pricing-Sign up-Pricing-Courses', 2),
#  ('Pricing-Sign up-Pricing-Courses-Courses', 2),
#  ('Sign up-Career tracks-Career tracks-Career tracks-Sign up', 2),
#  ('Courses-Sign up-Log in-Log in-Log in', 2),
#  ('Resources center-Other-Other-Resources center-Other', 2),
#  ('Career track certificate-Course certificate-Course certificate-Sign up-Sign up',
#   2),
#  ('Course certificate-Course certificate-Sign up-Sign up-Log in', 2),
#  ('Course certificate-Sign up-Sign up-Log in-Log in', 2),
#  ('Pricing-Pricing-Pricing-Pricing-Blog', 2),
#  ('Pricing-Pricing-Pricing-Blog-Blog', 2),
#  ('Course certificate-Upcoming courses-Upcoming courses-Career tracks-Career tracks',
#   2),
#  ('Career tracks-Career tracks-Pricing-Pricing-Log in', 2),
#  ('Checkout-Pricing-Course certificate-Course certificate-Course certificate',
#   2),
#  ('Coupon-Coupon-Coupon-Homepage-Log in', 2),
#  ('Upcoming courses-Success stories-Success stories-Success stories-Success stories',
#   2),
#  ('Resources center-Resources center-Resources center-Resources center-About us',
#   2),
#  ('About us-About us-Other-Other-Other', 2),
#  ('Career tracks-Career tracks-Career tracks-Success stories-Success stories',
#   2),
#  ('Career tracks-Career tracks-Success stories-Success stories-Success stories',
#   2),
#  ('Success stories-Success stories-Success stories-Homepage-Homepage', 2),
#  ('Success stories-Success stories-Homepage-Homepage-Homepage', 2),
#  ('Homepage-Career tracks-Career tracks-Courses-Career tracks', 2),
#  ('Career tracks-Pricing-Pricing-Homepage-Homepage', 2),
#  ('Courses-Career tracks-Career tracks-Homepage-Homepage', 2),
#  ('Homepage-Career tracks-Career tracks-Career tracks-Courses', 2),
#  ('Pricing-Checkout-Pricing-Other-Other', 2),
#  ('Checkout-Pricing-Other-Other-Other', 2),
#  ('Resources center-Other-Other-Other-Other', 2),
#  ('Other-Other-Other-Other-Courses', 2),
#  ('Other-Other-Other-Other-Career tracks', 2),
#  ('Other-Other-Other-Career tracks-Career tracks', 2),
#  ('Pricing-Pricing-Courses-Courses-Sign up', 2),
#  ('Homepage-Resources center-Resources center-Resources center-Homepage', 2),
#  ('Homepage-Pricing-Pricing-Pricing-Homepage', 2),
# ...
#  ('Success stories-Success stories-Success stories-Log in-Log in', 2),
#  ('Success stories-Success stories-Log in-Log in-Log in', 2),
#  ('Success stories-Log in-Log in-Log in-Log in', 2),
#  ('Homepage-Homepage-Career track certificate-Career track certificate-Sign up',
#   2),
#  ('Course certificate-Course certificate-Courses-Courses-Upcoming courses', 2),
#  ('Course certificate-Courses-Courses-Upcoming courses-Upcoming courses', 2),
#  ('Career track certificate-Career track certificate-Career track certificate-Homepage-Homepage',
#   2),
#  ('Career tracks-Upcoming courses-Career tracks-Career tracks-Career tracks',
#   2),
#  ('Course certificate-Course certificate-Course certificate-Course certificate-Homepage',
#   2),
#  ('Instructors-Homepage-Homepage-Homepage-Homepage', 2),
#  ('Resources center-Resources center-Resources center-Resources center-Upcoming courses',
#   2),
#  ('Career track certificate-Career track certificate-Career track certificate-Upcoming courses-Upcoming courses',
#   2),
#  ('Courses-Career tracks-Career tracks-Career tracks-Sign up', 2),
#  ('Homepage-Career tracks-Career tracks-Courses-Courses', 2),
#  ('Courses-Upcoming courses-Upcoming courses-Resources center-Resources center',
#   2),
#  ('Sign up-Sign up-Pricing-Pricing-Checkout', 2),
#  ('Career tracks-Career tracks-Homepage-Sign up-Homepage', 2),
#  ('Coupon-Coupon-Coupon-Homepage-Homepage', 2),
#  ('Homepage-Homepage-Sign up-Homepage-Homepage', 2),
#  ('Courses-Courses-Upcoming courses-Courses-Upcoming courses', 2),
#  ('Career track certificate-Career track certificate-Career track certificate-Career track certificate-Homepage',
#   2),
#  ('Course certificate-Course certificate-Resources center-Resources center-Career tracks',
#   2),
#  ('Course certificate-Resources center-Resources center-Career tracks-Career tracks',
#   2),
#  ('Career track certificate-Career track certificate-Career track certificate-Career track certificate-Success stories',
#   2),
#  ('Career track certificate-Career track certificate-Career track certificate-Success stories-Success stories',
#   2),
#  ('Career track certificate-Career track certificate-Success stories-Success stories-Success stories',
#   2),
#  ('Pricing-Pricing-Upcoming courses-Upcoming courses-Resources center', 2),
#  ('Pricing-Upcoming courses-Upcoming courses-Resources center-Resources center',
#   2),
#  ('Career tracks-Career tracks-Career tracks-Other-Career tracks', 2),
#  ('Log in-Log in-Homepage-Homepage-Homepage', 2),
#  ('Log in-Homepage-Homepage-Homepage-Pricing', 2),
#  ('Checkout-Checkout-Homepage-Homepage-Log in', 2),
#  ('Checkout-Homepage-Homepage-Log in-Log in', 2),
#  ('Career tracks-Sign up-Career tracks-Courses-Courses', 2),
#  ('Sign up-Career tracks-Courses-Courses-Courses', 2),
#  ('Career tracks-Resources center-Resources center-Upcoming courses-Upcoming courses',
#   2),
#  ('Homepage-Resources center-Resources center-Homepage-Homepage', 2),
#  ('Homepage-Homepage-Other-Other-Success stories', 2),
#  ('Success stories-Success stories-Success stories-Success stories-Career tracks',
#   2),
#  ('Success stories-Success stories-Success stories-Career tracks-Career tracks',
#   2),
#  ('Success stories-Success stories-Career tracks-Career tracks-Career tracks',
#   2),
#  ('Homepage-Blog-Blog-Other-Other', 2),
#  ('Other-Other-Career track certificate-Career track certificate-Career track certificate',
#   2),
#  ('Homepage-Instructors-Homepage-Instructors-Instructors', 2),
#  ('Checkout-Checkout-Homepage-Homepage-Homepage', 2),
#  ('Homepage-Homepage-Other-Other-Other', 2),
#  ('Other-Other-Pricing-Pricing-Checkout', 2),
#  ('Upcoming courses-Upcoming courses-Courses-Courses-Sign up', 2),
#  ('Upcoming courses-Courses-Courses-Sign up-Sign up', 2),
#  ('Pricing-Pricing-Pricing-Checkout-Pricing', 2),
#  ('Course certificate-Course certificate-Upcoming courses-Upcoming courses-Other',
#   2),
#  ('Course certificate-Upcoming courses-Upcoming courses-Other-Other', 2),
#  ('Success stories-Success stories-Success stories-Other-Other', 2),
#  ('Success stories-Success stories-Other-Other-Other', 2),
#  ('Success stories-Other-Other-Other-Other', 2),
#  ('Career tracks-Other-Other-Other-Other', 2),
#  ('Career tracks-Career tracks-Courses-Courses-Pricing', 2),
#  ('Career tracks-Courses-Courses-Pricing-Pricing', 2),
#  ('Courses-Courses-Pricing-Pricing-Upcoming courses', 2),
#  ('Courses-Pricing-Pricing-Upcoming courses-Upcoming courses', 2),
#  ('Career track certificate-Career track certificate-Career track certificate-Sign up-Log in',
#   2),
#  ('Career track certificate-Career track certificate-Sign up-Log in-Log in',
#   2),
#  ('Homepage-Homepage-Homepage-Pricing-Homepage', 2),
#  ('Pricing-Homepage-Pricing-Pricing-Checkout', 2),
#  ('Sign up-Sign up-Sign up-Sign up-Pricing', 2),
#  ('Success stories-Success stories-Upcoming courses-Upcoming courses-Career tracks',
#   2),
#  ('Success stories-Upcoming courses-Upcoming courses-Career tracks-Career tracks',
#   2),
#  ('Instructors-Career track certificate-Career track certificate-Career track certificate-Career track certificate',
#   2),
#  ('Career tracks-Career tracks-Upcoming courses-Upcoming courses-Resources center',
#   2),
#  ('Career tracks-Upcoming courses-Upcoming courses-Resources center-Resources center',
#   2),
#  ('Other-Blog-Other-Blog-Other', 2),
#  ('Blog-Other-Blog-Other-Blog', 2),
#  ('Career tracks-Pricing-Pricing-Upcoming courses-Upcoming courses', 2),
#  ('Sign up-Career track certificate-Courses-Courses-Courses', 2),
#  ('Courses-Pricing-Pricing-Resources center-Resources center', 2),
#  ('Pricing-Pricing-Checkout-Courses-Courses', 2),
#  ('Courses-Homepage-Homepage-Homepage-Other', 2),
#  ('Career track certificate-Instructors-Instructors-Instructors-Instructors',
#   2),
#  ('Career track certificate-Career tracks-Career track certificate-Career tracks-Career track certificate',
#   2),
#  ('Homepage-Pricing-Homepage-Homepage-Homepage', 2),
#  ('Other-Other-Course certificate-Course certificate-Course certificate', 2),
#  ('Career track certificate-Career track certificate-Courses-Courses-Homepage',
#   2),
#  ('Career track certificate-Courses-Courses-Homepage-Homepage', 2),
#  ('Resources center-Resources center-Pricing-Pricing-Checkout', 2),
#  ('Instructors-Instructors-Courses-Courses-Courses', 2),
#  ('Sign up-Course certificate-Course certificate-Course certificate-Course certificate',
#   2),
#  ('Career tracks-Career track certificate-Career tracks-Career track certificate-Career track certificate',
#   2),
#  ('Career tracks-Upcoming courses-Courses-Courses-Courses', 2),
#  ('Career tracks-Career tracks-Pricing-Pricing-Career track certificate', 2),
#  ('Resources center-Resources center-Other-Other-Pricing', 2),
#  ('Sign up-Career tracks-Pricing-Pricing-Sign up', 2),
#  ('Log in-Log in-Log in-Homepage-Resources center', 2),
#  ('Log in-Log in-Homepage-Resources center-Resources center', 2),
#  ('Log in-Homepage-Resources center-Resources center-Resources center', 2),
#  ('Other-Other-Pricing-Pricing-Sign up', 2),
#  ('Course certificate-Pricing-Pricing-Pricing-Pricing', 2),
#  ('Course certificate-Pricing-Pricing-Courses-Courses', 2),
#  ('Courses-Sign up-Sign up-Sign up-Courses', 2),
#  ('Courses-Courses-Log in-Log in-Sign up', 2),
#  ('Courses-Courses-Resources center-Resources center-Career track certificate',
#   2),
#  ('Courses-Resources center-Resources center-Career track certificate-Career track certificate',
#   2),
#  ('Course certificate-Course certificate-Upcoming courses-Upcoming courses-Courses',
#   2),
#  ('Course certificate-Upcoming courses-Upcoming courses-Courses-Courses', 2),
#  ('Courses-Courses-Courses-Homepage-Career tracks', 2),
#  ('Courses-Courses-Homepage-Career tracks-Career tracks', 2),
#  ('Courses-Homepage-Career tracks-Career tracks-Career tracks', 2),
#  ('Courses-Courses-Upcoming courses-Upcoming courses-Course certificate', 2),
#  ('Courses-Upcoming courses-Upcoming courses-Course certificate-Course certificate',
#   2),
#  ('Resources center-Resources center-Other-Other-Courses', 2),
#  ('Resources center-Other-Other-Courses-Courses', 2),
#  ('Career tracks-Career tracks-Career tracks-Sign up-Log in', 1),
#  ('Career tracks-Career tracks-Sign up-Log in-Log in', 1),
#  ('Career tracks-Sign up-Log in-Log in-Log in', 1),
#  ('Other-Career track certificate-Career track certificate-Resources center-Resources center',
#   1),
#  ('Instructors-Instructors-Homepage-Homepage-Log in', 1),
#  ('Instructors-Homepage-Homepage-Log in-Log in', 1),
#  ('Homepage-Homepage-Pricing-Pricing-Career tracks', 1),
#  ('Homepage-Career tracks-Career tracks-Sign up-Homepage', 1),
#  ('Career tracks-Career tracks-Sign up-Homepage-Homepage', 1),
#  ('Career tracks-Sign up-Homepage-Homepage-Homepage', 1),
#  ('Career tracks-Career tracks-Pricing-Career tracks-Pricing', 1),
#  ('Career tracks-Career tracks-Homepage-Sign up-Sign up', 1),
#  ('Career tracks-Homepage-Sign up-Sign up-Log in', 1),
#  ('Pricing-Sign up-Pricing-Checkout-Checkout', 1),
#  ('Sign up-Pricing-Checkout-Checkout-Checkout', 1),
#  ('Other-Other-Homepage-Log in-Log in', 1),
#  ('Resources center-Resources center-Pricing-Pricing-Log in', 1),
#  ('Resources center-Pricing-Pricing-Log in-Log in', 1),
#  ('Success stories-Success stories-Pricing-Pricing-Pricing', 1),
#  ('Sign up-Homepage-Course certificate-Course certificate-Course certificate',
#   1),
#  ('Career tracks-Courses-Career tracks-Courses-Career tracks', 1),
#  ('Courses-Career tracks-Courses-Career tracks-Courses', 1),
#  ('Sign up-Homepage-Pricing-Pricing-Checkout', 1),
#  ('Homepage-Pricing-Pricing-Other-Other', 1),
#  ('Pricing-Pricing-Other-Other-Courses', 1),
#  ('Pricing-Other-Other-Courses-Courses', 1),
#  ('Courses-Courses-Sign up-Sign up-Pricing', 1),
#  ('Courses-Sign up-Sign up-Pricing-Pricing', 1),
#  ('Career track certificate-Career track certificate-Sign up-Career track certificate-Resources center',
#   1),
#  ('Resources center-Courses-Resources center-Courses-Courses', 1),
#  ('Courses-Resources center-Courses-Courses-Courses', 1),
#  ('Career track certificate-Career track certificate-Career track certificate-Pricing-Course certificate',
#   1),
#  ('Career track certificate-Career track certificate-Pricing-Course certificate-Course certificate',
#   1),
#  ('Career track certificate-Pricing-Course certificate-Course certificate-Course certificate',
#   1),
#  ('Sign up-Sign up-Sign up-Sign up-Courses', 1),
#  ('Homepage-Homepage-Homepage-Upcoming courses-Log in', 1),
#  ('Homepage-Homepage-Upcoming courses-Log in-Log in', 1),
#  ('Homepage-Upcoming courses-Log in-Log in-Log in', 1),
#  ('Upcoming courses-Log in-Log in-Log in-Log in', 1),
#  ('Sign up-Sign up-Sign up-Sign up-Upcoming courses', 1),
#  ('Sign up-Sign up-Sign up-Upcoming courses-Pricing', 1),
#  ('Sign up-Sign up-Upcoming courses-Pricing-Pricing', 1),
#  ('Sign up-Upcoming courses-Pricing-Pricing-Pricing', 1),
#  ('Courses-Log in-Log in-Log in-Courses', 1),
#  ('Courses-Courses-Upcoming courses-Upcoming courses-Upcoming courses', 1),
#  ('Courses-Upcoming courses-Upcoming courses-Upcoming courses-Resources center',
#   1),
#  ('Upcoming courses-Upcoming courses-Upcoming courses-Resources center-Resources center',
#   1),
#  ('Homepage-Homepage-Other-Other-Pricing', 1),
#  ('Homepage-Other-Other-Pricing-Pricing', 1),
#  ('Other-Other-Resources center-Other-Resources center', 1),
#  ('Other-Resources center-Other-Resources center-Resources center', 1),
#  ('Homepage-Courses-Courses-Upcoming courses-Upcoming courses', 1),
#  ('Pricing-Homepage-Homepage-Sign up-Homepage', 1),
#  ('Homepage-Homepage-Sign up-Homepage-Career tracks', 1),
#  ('Other-Career track certificate-Career track certificate-Course certificate-Course certificate',
#   1),
#  ('Career track certificate-Career track certificate-Course certificate-Course certificate-Sign up',
#   1),
#  ('Courses-Courses-Pricing-Pricing-Success stories', 1),
#  ('Courses-Pricing-Pricing-Success stories-Success stories', 1),
#  ('Success stories-Success stories-Success stories-Homepage-Pricing', 1),
#  ('Sign up-Sign up-Sign up-Sign up-Other', 1),
#  ('Sign up-Sign up-Sign up-Other-Sign up', 1),
#  ('Sign up-Sign up-Other-Sign up-Sign up', 1),
#  ('Sign up-Other-Sign up-Sign up-Sign up', 1),
#  ('Course certificate-Course certificate-Sign up-Course certificate-Log in',
#   1),
#  ('Course certificate-Sign up-Course certificate-Log in-Log in', 1),
#  ('Sign up-Course certificate-Log in-Log in-Log in', 1),
#  ('Homepage-Homepage-Pricing-Pricing-Log in', 1),
#  ('Pricing-Pricing-Blog-Blog-Other', 1),
#  ('Pricing-Blog-Blog-Other-Other', 1),
#  ('Blog-Blog-Other-Other-Other', 1),
#  ('Blog-Other-Other-Other-Other', 1),
#  ('Course certificate-Course certificate-Upcoming courses-Course certificate-Upcoming courses',
#   1),
#  ('Course certificate-Upcoming courses-Course certificate-Upcoming courses-Upcoming courses',
#   1),
#  ('Upcoming courses-Course certificate-Upcoming courses-Upcoming courses-Career tracks',
#   1),
#  ('Homepage-Career track certificate-Career track certificate-Course certificate-Course certificate',
#   1),
#  ('Homepage-Homepage-Resources center-Resources center-Courses', 1),
#  ('Checkout-Pricing-Checkout-Pricing-Course certificate', 1),
#  ('Pricing-Checkout-Pricing-Course certificate-Course certificate', 1),
#  ('Homepage-Log in-Log in-Pricing-Pricing', 1),
#  ('Log in-Log in-Pricing-Pricing-Pricing', 1),
#  ('Homepage-Upcoming courses-Upcoming courses-Pricing-Pricing', 1),
#  ('Upcoming courses-Upcoming courses-Pricing-Pricing-Checkout', 1),
#  ('Pricing-Resources center-Resources center-Log in-Log in', 1),
#  ('Coupon-Coupon-Homepage-Log in-Log in', 1),
#  ('Coupon-Homepage-Log in-Log in-Log in', 1),
#  ('Courses-Course certificate-Course certificate-Course certificate-Homepage',
#   1),
#  ('Course certificate-Course certificate-Course certificate-Homepage-Pricing',
#   1),
#  ('Course certificate-Course certificate-Homepage-Pricing-Pricing', 1),
#  ('Course certificate-Homepage-Pricing-Pricing-Homepage', 1),
#  ('Pricing-Courses-Courses-Upcoming courses-Upcoming courses', 1),
#  ('Courses-Upcoming courses-Upcoming courses-Resources center-Upcoming courses',
#   1),
#  ('Upcoming courses-Upcoming courses-Resources center-Upcoming courses-Success stories',
#   1),
#  ('Upcoming courses-Resources center-Upcoming courses-Success stories-Success stories',
#   1),
#  ('Resources center-Upcoming courses-Success stories-Success stories-Success stories',
#   1),
#  ('Resources center-Resources center-Resources center-About us-About us', 1),
#  ('Resources center-Resources center-About us-About us-Other', 1),
#  ('Resources center-About us-About us-Other-Other', 1),
#  ('About us-Other-Other-Other-Homepage', 1),
#  ('Career track certificate-Career track certificate-Course certificate-Course certificate-Other',
#   1),
#  ('Career track certificate-Course certificate-Course certificate-Other-Other',
#   1),
#  ('Course certificate-Course certificate-Other-Other-Courses', 1),
#  ('Course certificate-Other-Other-Courses-Courses', 1),
#  ('Success stories-Homepage-Homepage-Homepage-Career tracks', 1),
#  ('Courses-Pricing-Pricing-Checkout-Success stories', 1),
#  ('Pricing-Pricing-Checkout-Success stories-Success stories', 1),
#  ('Homepage-Homepage-Career tracks-Career tracks-Courses', 1),
#  ('Courses-Courses-Career tracks-Career tracks-Homepage', 1),
#  ('Pricing-Resources center-Resources center-Career track certificate-Career track certificate',
#   1),
#  ('Career tracks-Courses-Courses-Career tracks-Courses', 1),
#  ('Pricing-Pricing-Career track certificate-Career track certificate-Upcoming courses',
#   1),
#  ('Pricing-Career track certificate-Career track certificate-Upcoming courses-Upcoming courses',
#   1),
#  ('Career track certificate-Career track certificate-Upcoming courses-Upcoming courses-Career tracks',
#   1),
#  ('Career track certificate-Upcoming courses-Upcoming courses-Career tracks-Career tracks',
#   1),
#  ('Pricing-Pricing-Checkout-Pricing-Other', 1),
#  ('Other-Other-Pricing-Pricing-Career tracks', 1),
#  ('Courses-Homepage-Homepage-Homepage-Resources center', 1),
#  ('Other-Other-Other-Courses-Courses', 1),
#  ('Other-Career tracks-Career tracks-Career tracks-Sign up', 1),
#  ('Homepage-Resources center-Homepage-Resources center-Resources center', 1),
#  ('Resources center-Homepage-Resources center-Resources center-Resources center',
#   1),
#  ('Pricing-Courses-Courses-Sign up-Courses', 1),
#  ...]

# %%
journey_length(data)
# Out:
# 8.671363865123302
